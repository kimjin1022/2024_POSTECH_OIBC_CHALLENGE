# %%
import sys
import sktime
import tqdm as tq
import xgboost as xgb
import matplotlib
import seaborn as sns
import sklearn as skl
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
from tqdm import tqdm
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.utils.plotting import plot_series
from xgboost import XGBRegressor

pd.set_option('display.max_columns', 30)

# %%
base_path = "/home/jinjinjara1022/"

# weather_forecast_data_1 = pd.read_csv(base_path + "OBIC/data/기상예측데이터_1.csv")
# weather_forecast_data_2 = pd.read_csv(base_path + "OBIC/data/기상예측데이터_2.csv")  

# weather_observed_data_1 = pd.read_csv(base_path + "OBIC/data/기상실측데이터_1.csv")
# weather_observed_data_2 = pd.read_csv(base_path + "OBIC/data/기상실측데이터_2.csv")  
  
jeju_power_market_day_ahead = pd.read_csv(base_path + "OBIC/data/제주전력시장_시장전기가격_하루전가격.csv")
jeju_power_market_real_time = pd.read_csv(base_path + "OBIC/data/제주전력시장_시장전기가격_실시간가격.csv")

# jeju_power_market_status = pd.read_csv(base_path + "OBIC/data/제주전력시장_현황데이터.csv")

# %%
df = jeju_power_market_day_ahead

# %%
df['datetimes'] = pd.to_datetime(df['ts'], unit='s')
df['hour'] = df['datetimes'].dt.hour
df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)

df['month'] = df['datetimes'].dt.month
df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)
df['is_weekend'] = np.where(df['datetimes'].dt.dayofweek >= 5, 1, 0)

df = df.drop(['datetimes', 'ts', 'hour', 'month'], axis=1)
df = df[[col for col in df.columns if col != '하루전가격(원/kWh)'] + ['하루전가격(원/kWh)']]

df.rename(columns={
    '하루전가격(원/kWh)': 'previous_price_kwh'
}, inplace=True)

# %%
df['previous_hour_price'] = df['previous_price_kwh'].shift(1)
df['previous_day_price'] = df['previous_price_kwh'].shift(24)
df['previous_2day_price'] = df['previous_price_kwh'].shift(48)

# %%
df = df[48:]

# %%
df
# Out:
#           hour_sin      hour_cos  month_sin     month_cos  is_weekend  \
# 48   -7.071068e-01 -7.071068e-01   1.000000  6.123234e-17           1
# 49   -8.660254e-01 -5.000000e-01   1.000000  6.123234e-17           1
# 50   -9.659258e-01 -2.588190e-01   1.000000  6.123234e-17           1
# 51   -1.000000e+00 -1.836970e-16   1.000000  6.123234e-17           1
# 52   -9.659258e-01  2.588190e-01   1.000000  6.123234e-17           1
# ...            ...           ...        ...           ...         ...
# 5660  2.588190e-01 -9.659258e-01  -0.866025  5.000000e-01           0
# 5661  1.224647e-16 -1.000000e+00  -0.866025  5.000000e-01           0
# 5662 -2.588190e-01 -9.659258e-01  -0.866025  5.000000e-01           0
# 5663 -5.000000e-01 -8.660254e-01  -0.866025  5.000000e-01           0
# 5664 -7.071068e-01 -7.071068e-01  -0.866025  5.000000e-01           0
#
#       previous_price_kwh  previous_hour_price  previous_day_price  \
# 48                247.14               207.57              112.19
# 49                321.47               247.14              138.50
# 50                100.21               321.47               99.48
# 51                 82.66               100.21               95.38
# 52                 82.66                82.66               91.24
# ...                  ...                  ...                 ...
# 5660              156.68               156.68              158.38
# 5661              152.54               156.68              157.18
# 5662              106.92               152.54              105.63
# 5663              150.97               106.92              157.56
# 5664              121.78               150.97              155.51
#
#       previous_2day_price
# 48                 107.39
# 49                 107.39
# 50                  95.30
# 51                  87.89
# 52                   0.00
# ...                   ...
# 5660               109.15
# 5661               101.70
# 5662               101.75
# 5663               100.72
# 5664               100.72
#
# [5617 rows x 9 columns]

# %%
y = df['previous_price_kwh']
x = df.drop('previous_price_kwh', axis=1)

# %%
y_train, y_valid, x_train, x_valid = temporal_train_test_split(y = y, X = x, test_size = int(len(y) * 0.2))
print('train data shape\nx:{}, y:{}'.format(x_train.shape, y_train.shape))
# Out:
# train data shape
# x:(4494, 8), y:(4494,)

# %%
plot_series(y_train, y_valid, markers=[',' , ','])
plt.show()

# %%
# Define SMAPE loss function
def SMAPE(true, pred):
    return np.mean((np.abs(true-pred))/(np.abs(true) + np.abs(pred))) * 100

# %%
def weighted_mse(alpha = 1):
    def weighted_mse_fixed(label, pred):
        residual = (label - pred).astype("float")
        grad = np.where(residual>0, -2*alpha*residual, -2*residual)
        hess = np.where(residual>0, 2*alpha, 2.0)
        return grad, hess
    return weighted_mse_fixed

# %%
import xgboost as xgb
print(xgb.__version__)
# Out:
# 2.1.1

# %%
from xgboost import XGBRegressor

# XGBRegressor 모델 생성 (GPU 사용)
xgb_reg = XGBRegressor(
    n_estimators=1000, 
    learning_rate=0.01,      # 학습률
    min_child_weight=1,      # 최소 가중치
    max_depth=6,             # 최대 깊이
    colsample_bytree=0.8,    # 컬럼 샘플링 비율
    subsample=0.8,           # 데이터 샘플링 비율
    tree_method='hist',      # 'hist' 사용
    device='cuda',           # GPU 사용 설정
    seed=0
)

xgb_reg.fit(
    x_train, y_train, 
    eval_set=[(x_train, y_train), (x_valid, y_valid)], 
    #early_stopping_rounds=300, 
    verbose=False
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
x_valid
# Out:
#           hour_sin  hour_cos  month_sin     month_cos  is_weekend  \
# 4542 -7.071068e-01  0.707107  -1.000000 -1.836970e-16           0
# 4543 -5.000000e-01  0.866025  -1.000000 -1.836970e-16           0
# 4544 -2.588190e-01  0.965926  -1.000000 -1.836970e-16           0
# 4545  0.000000e+00  1.000000  -1.000000 -1.836970e-16           0
# 4546  2.588190e-01  0.965926  -1.000000 -1.836970e-16           0
# ...            ...       ...        ...           ...         ...
# 5660  2.588190e-01 -0.965926  -0.866025  5.000000e-01           0
# 5661  1.224647e-16 -1.000000  -0.866025  5.000000e-01           0
# 5662 -2.588190e-01 -0.965926  -0.866025  5.000000e-01           0
# 5663 -5.000000e-01 -0.866025  -0.866025  5.000000e-01           0
# 5664 -7.071068e-01 -0.707107  -0.866025  5.000000e-01           0
#
#       previous_hour_price  previous_day_price  previous_2day_price
# 4542               106.84              106.86               106.97
# 4543               106.84              106.85               134.88
# 4544               142.39              142.63               145.44
# 4545               143.91              145.30               145.91
# 4546               146.76              145.54               148.78
# ...                   ...                 ...                  ...
# 5660               156.68              158.38               109.15
# 5661               156.68              157.18               101.70
# 5662               152.54              105.63               101.75
# 5663               106.92              157.56               100.72
# 5664               150.97              155.51               100.72
#
# [1123 rows x 8 columns]

# %%
pred = xgb_reg.predict(x_valid)
pred = pd.Series(pred)
pred.index = np.arange(y_valid.index[0], y_valid.index[-1]+1)

# %%
plot_series(y_train, y_valid, pd.Series(pred), markers=[',' , ',', ','])

print('SMAPE : {}'.format(SMAPE(y_valid, pred)))
# Out:
# SMAPE : 4.658958875303157

# %%
plt.figure(figsize=(20, 5))
pred.plot(label='predict_price')
y_valid.plot()
plt.legend()
plt.show()
