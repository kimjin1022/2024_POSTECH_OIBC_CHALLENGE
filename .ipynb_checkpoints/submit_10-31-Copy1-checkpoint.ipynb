# %%
import sys
import sktime
import tqdm as tq
import xgboost as xgb
import matplotlib
import seaborn as sns
import sklearn as skl
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
from tqdm import tqdm
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.utils.plotting import plot_series
from xgboost import XGBRegressor

pd.set_option('display.max_columns', 30)

# %%
base_path = "/home/jinjinjara1022/"

# weather_forecast_data_1 = pd.read_csv(base_path + "OBIC/data/기상예측데이터_1.csv")
# weather_forecast_data_2 = pd.read_csv(base_path + "OBIC/data/기상예측데이터_2.csv")  

# weather_observed_data_1 = pd.read_csv(base_path + "OBIC/data/기상실측데이터_1.csv")
# weather_observed_data_2 = pd.read_csv(base_path + "OBIC/data/기상실측데이터_2.csv")  
  
jeju_power_market_day_ahead = pd.read_csv(base_path + "OBIC/data/제주전력시장_시장전기가격_하루전가격_10_31.csv")
jeju_power_market_real_time = pd.read_csv(base_path + "OBIC/data/제주전력시장_시장전기가격_실시간가격.csv")

# jeju_power_market_status = pd.read_csv(base_path + "OBIC/data/제주전력시장_현황데이터.csv")

# %%
df = jeju_power_market_day_ahead

df['datetimes'] = pd.to_datetime(df['ts'], unit='s')
df['hour'] = df['datetimes'].dt.hour
df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)

df['month'] = df['datetimes'].dt.month
df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)

df['day_of_week'] = df['datetimes'].dt.dayofweek
df['day_of_week_sin'] = np.sin(2 * np.pi * df['day_of_week'] / 7)
df['day_of_week_cos'] = np.cos(2 * np.pi * df['day_of_week'] / 7)


df = df.drop(['datetimes', 'ts', 'hour', 'month', 'day_of_week'], axis=1)
df = df[[col for col in df.columns if col != '하루전가격(원/kWh)'] + ['하루전가격(원/kWh)']]

df.rename(columns={
    '하루전가격(원/kWh)': 'previous_price_kwh'
}, inplace=True)

# %%
df['previous_hour_price1'] = df['previous_price_kwh'].shift(1)

df['previous_1day_price0'] = df['previous_price_kwh'].shift(23)
df['previous_1day_price1'] = df['previous_price_kwh'].shift(24)
df['previous_1day_price2'] = df['previous_price_kwh'].shift(25)

df['previous_2day_price0'] = df['previous_price_kwh'].shift(47)
df['previous_2day_price1'] = df['previous_price_kwh'].shift(48)
df['previous_2day_price2'] = df['previous_price_kwh'].shift(49)

df['previous_3day_price0'] = df['previous_price_kwh'].shift(71)
df['previous_3day_price1'] = df['previous_price_kwh'].shift(72)
df['previous_3day_price2'] = df['previous_price_kwh'].shift(73)

# %%
df = df[73:]

# %%
df
# Out:
#           hour_sin      hour_cos  month_sin     month_cos  day_of_week_sin  \
# 73   -8.660254e-01 -5.000000e-01   1.000000  6.123234e-17        -0.781831
# 74   -9.659258e-01 -2.588190e-01   1.000000  6.123234e-17        -0.781831
# 75   -1.000000e+00 -1.836970e-16   1.000000  6.123234e-17        -0.781831
# 76   -9.659258e-01  2.588190e-01   1.000000  6.123234e-17        -0.781831
# 77   -8.660254e-01  5.000000e-01   1.000000  6.123234e-17        -0.781831
# ...            ...           ...        ...           ...              ...
# 5876  2.588190e-01 -9.659258e-01  -0.866025  5.000000e-01         0.433884
# 5877  1.224647e-16 -1.000000e+00  -0.866025  5.000000e-01         0.433884
# 5878 -2.588190e-01 -9.659258e-01  -0.866025  5.000000e-01         0.433884
# 5879 -5.000000e-01 -8.660254e-01  -0.866025  5.000000e-01         0.433884
# 5880 -7.071068e-01 -7.071068e-01  -0.866025  5.000000e-01         0.433884
#
#       day_of_week_cos  previous_price_kwh  previous_hour_price1  \
# 73           0.623490              168.30                170.79
# 74           0.623490               86.82                168.30
# 75           0.623490               80.97                 86.82
# 76           0.623490               80.97                 80.97
# 77           0.623490               80.97                 80.97
# ...               ...                 ...                   ...
# 5876        -0.900969              135.30                135.30
# 5877        -0.900969              130.87                135.30
# 5878        -0.900969              132.91                130.87
# 5879        -0.900969              105.14                132.91
# 5880        -0.900969              105.14                105.14
#
#       previous_1day_price0  previous_1day_price1  previous_1day_price2  \
# 73                  100.21                321.47                247.14
# 74                   82.66                100.21                321.47
# 75                   82.66                 82.66                100.21
# 76                   82.66                 82.66                 82.66
# 77                   99.15                 82.66                 82.66
# ...                    ...                   ...                   ...
# 5876                117.33                116.32                117.12
# 5877                100.89                117.33                116.32
# 5878                116.03                100.89                117.33
# 5879                111.96                116.03                100.89
# 5880                100.68                111.96                116.03
#
#       previous_2day_price0  previous_2day_price1  previous_2day_price2  \
# 73                   99.48                138.50                112.19
# 74                   95.38                 99.48                138.50
# 75                   91.24                 95.38                 99.48
# 76                   91.24                 91.24                 95.38
# 77                  134.65                 91.24                 91.24
# ...                    ...                   ...                   ...
# 5876                133.00                133.00                138.00
# 5877                106.00                133.00                133.00
# 5878                 99.00                106.00                133.00
# 5879                 99.00                 99.00                106.00
# 5880                101.81                 99.00                 99.00
#
#       previous_3day_price0  previous_3day_price1  previous_3day_price2
# 73                   95.30                107.39                107.39
# 74                   87.89                 95.30                107.39
# 75                    0.00                 87.89                 95.30
# 76                    0.00                  0.00                 87.89
# 77                    0.00                  0.00                  0.00
# ...                    ...                   ...                   ...
# 5876                156.65                156.83                157.54
# 5877                156.65                156.65                156.83
# 5878                116.60                156.65                156.65
# 5879                153.59                116.60                156.65
# 5880                152.10                153.59                116.60
#
# [5808 rows x 17 columns]

# %%
y = df['previous_price_kwh']
x = df.drop('previous_price_kwh', axis=1)

# %%
import xgboost as xgb
print(xgb.__version__)
from xgboost import XGBRegressor

# XGBRegressor 모델 생성 (GPU 사용)
xgb_reg = XGBRegressor(
    n_estimators=2000, 
    learning_rate=0.01,      # 학습률
    min_child_weight=1,      # 최소 가중치
    max_depth=7,             # 최대 깊이
    colsample_bytree=0.8,    # 컬럼 샘플링 비율
    subsample=0.8,           # 데이터 샘플링 비율
    tree_method='hist',      # 'hist' 사용
    device='cuda',           # GPU 사용 설정
    seed=0,
    early_stopping_rounds = 1000
)
# Out:
# 2.1.1

# %%
import numpy as np

# 10등분한 데이터 인덱스 범위를 설정
n_splits = 5
split_size = len(x) // n_splits

trains = []
valids = []

# 각 타임 구간에 대해 훈련 및 검증 세트 생성
for i in range(n_splits):
    start_idx = i * split_size
    end_idx = (i + 1) * split_size if i != n_splits - 1 else len(x)
    
    x_split = x.iloc[start_idx:end_idx]
    y_split = y.iloc[start_idx:end_idx]
    
    split_point = int(len(x_split) * 0.9)
    x_train, x_valid = x_split.iloc[:split_point], x_split.iloc[split_point:]
    y_train, y_valid = y_split.iloc[:split_point], y_split.iloc[split_point:]
    
    trains.append([x_train, y_train])
    valids.append([x_valid, y_valid])

    xgb_reg.fit(
    x_train, y_train, 
    eval_set=[(x_train, y_train), (x_valid, y_valid)], 
    verbose=False
    )

# %% [markdown]
# ### SUBMIT

# %%
def predict(date, df): #2024-10-30
    
    for _ in range(24):
        new_row = df.iloc[-24].copy()
        new_row['month_sin'] = np.cos(int(date.split('-')[2])/12)
        new_row['month_cos'] = np.sin(int(date.split('-')[2])/12)
        new_row['day_of_week_sin'] = df.iloc[-24 * 7]['day_of_week_sin']
        new_row['day_of_week_cos'] = df.iloc[-24 * 7]['day_of_week_cos']
        
        new_row['previous_price_kwh'] = None
        
        new_row['previous_hour_price1'] = df.iloc[-1]['previous_price_kwh']

        new_row['previous_1day_price0'] = df.iloc[-23]['previous_price_kwh']
        new_row['previous_1day_price1'] = df.iloc[-24]['previous_price_kwh']
        new_row['previous_1day_price2'] = df.iloc[-25]['previous_price_kwh']

        new_row['previous_2day_price0'] = df.iloc[-47]['previous_price_kwh']
        new_row['previous_2day_price1'] = df.iloc[-48]['previous_price_kwh']
        new_row['previous_2day_price2'] = df.iloc[-49]['previous_price_kwh']

        new_row['previous_3day_price0'] = df.iloc[-71]['previous_price_kwh']
        new_row['previous_3day_price1'] = df.iloc[-72]['previous_price_kwh']
        new_row['previous_3day_price2'] = df.iloc[-73]['previous_price_kwh']

        df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)

    return df

# %%
pred_df = predict('2024-10-31', df)

# %%
pred_df.tail(25)
# Out:
#           hour_sin      hour_cos  month_sin  month_cos  day_of_week_sin  \
# 5807 -7.071068e-01 -7.071068e-01  -0.866025   0.500000         0.433884
# 5808 -8.660254e-01 -5.000000e-01  -0.848178   0.529711         0.433884
# 5809 -9.659258e-01 -2.588190e-01  -0.848178   0.529711         0.433884
# 5810 -1.000000e+00 -1.836970e-16  -0.848178   0.529711         0.433884
# 5811 -9.659258e-01  2.588190e-01  -0.848178   0.529711         0.433884
# 5812 -8.660254e-01  5.000000e-01  -0.848178   0.529711         0.433884
# 5813 -7.071068e-01  7.071068e-01  -0.848178   0.529711         0.433884
# 5814 -5.000000e-01  8.660254e-01  -0.848178   0.529711         0.433884
# 5815 -2.588190e-01  9.659258e-01  -0.848178   0.529711         0.433884
# 5816  0.000000e+00  1.000000e+00  -0.848178   0.529711        -0.433884
# 5817  2.588190e-01  9.659258e-01  -0.848178   0.529711        -0.433884
# 5818  5.000000e-01  8.660254e-01  -0.848178   0.529711        -0.433884
# 5819  7.071068e-01  7.071068e-01  -0.848178   0.529711        -0.433884
# 5820  8.660254e-01  5.000000e-01  -0.848178   0.529711        -0.433884
# 5821  9.659258e-01  2.588190e-01  -0.848178   0.529711        -0.433884
# 5822  1.000000e+00  6.123234e-17  -0.848178   0.529711        -0.433884
# 5823  9.659258e-01 -2.588190e-01  -0.848178   0.529711        -0.433884
# 5824  8.660254e-01 -5.000000e-01  -0.848178   0.529711        -0.433884
# 5825  7.071068e-01 -7.071068e-01  -0.848178   0.529711        -0.433884
# 5826  5.000000e-01 -8.660254e-01  -0.848178   0.529711        -0.433884
# 5827  2.588190e-01 -9.659258e-01  -0.848178   0.529711        -0.433884
# 5828  1.224647e-16 -1.000000e+00  -0.848178   0.529711        -0.433884
# 5829 -2.588190e-01 -9.659258e-01  -0.848178   0.529711        -0.433884
# 5830 -5.000000e-01 -8.660254e-01  -0.848178   0.529711        -0.433884
# 5831 -7.071068e-01 -7.071068e-01  -0.848178   0.529711        -0.433884
#
#       day_of_week_cos  previous_price_kwh  previous_hour_price1  \
# 5807        -0.900969              105.14                105.14
# 5808        -0.900969                 NaN                105.14
# 5809        -0.900969                 NaN                   NaN
# 5810        -0.900969                 NaN                   NaN
# 5811        -0.900969                 NaN                   NaN
# 5812        -0.900969                 NaN                   NaN
# 5813        -0.900969                 NaN                   NaN
# 5814        -0.900969                 NaN                   NaN
# 5815        -0.900969                 NaN                   NaN
# 5816        -0.900969                 NaN                   NaN
# 5817        -0.900969                 NaN                   NaN
# 5818        -0.900969                 NaN                   NaN
# 5819        -0.900969                 NaN                   NaN
# 5820        -0.900969                 NaN                   NaN
# 5821        -0.900969                 NaN                   NaN
# 5822        -0.900969                 NaN                   NaN
# 5823        -0.900969                 NaN                   NaN
# 5824        -0.900969                 NaN                   NaN
# 5825        -0.900969                 NaN                   NaN
# 5826        -0.900969                 NaN                   NaN
# 5827        -0.900969                 NaN                   NaN
# 5828        -0.900969                 NaN                   NaN
# 5829        -0.900969                 NaN                   NaN
# 5830        -0.900969                 NaN                   NaN
# 5831        -0.900969                 NaN                   NaN
#
#       previous_1day_price0  previous_1day_price1  previous_1day_price2  \
# 5807                100.68                111.96                116.03
# 5808                 92.24                100.68                111.96
# 5809                 91.76                 92.24                100.68
# 5810                 91.77                 91.76                 92.24
# 5811                 92.21                 91.77                 91.76
# 5812                 99.85                 92.21                 91.77
# 5813                100.65                 99.85                 92.21
# 5814                105.16                100.65                 99.85
# 5815                139.28                105.16                100.65
# 5816                139.33                139.28                105.16
# 5817                140.45                139.33                139.28
# 5818                133.11                140.45                139.33
# 5819                104.87                133.11                140.45
# 5820                128.34                104.87                133.11
# 5821                147.98                128.34                104.87
# 5822                152.55                147.98                128.34
# 5823                139.33                152.55                147.98
# 5824                135.29                139.33                152.55
# 5825                135.30                135.29                139.33
# 5826                135.30                135.30                135.29
# 5827                130.87                135.30                135.30
# 5828                132.91                130.87                135.30
# 5829                105.14                132.91                130.87
# 5830                105.14                105.14                132.91
# 5831                   NaN                105.14                105.14
#
#       previous_2day_price0  previous_2day_price1  previous_2day_price2  \
# 5807                101.81                 99.00                 99.00
# 5808                 76.90                101.81                 99.00
# 5809                 77.30                 76.90                101.81
# 5810                 78.08                 77.30                 76.90
# 5811                 99.38                 78.08                 77.30
# 5812                 87.14                 99.38                 78.08
# 5813                100.42                 87.14                 99.38
# 5814                109.13                100.42                 87.14
# 5815                139.31                109.13                100.42
# 5816                117.02                139.31                109.13
# 5817                116.97                117.02                139.31
# 5818                109.93                116.97                117.02
# 5819                100.40                109.93                116.97
# 5820                100.58                100.40                109.93
# 5821                110.68                100.58                100.40
# 5822                109.06                110.68                100.58
# 5823                116.86                109.06                110.68
# 5824                117.02                116.86                109.06
# 5825                117.12                117.02                116.86
# 5826                116.32                117.12                117.02
# 5827                117.33                116.32                117.12
# 5828                100.89                117.33                116.32
# 5829                116.03                100.89                117.33
# 5830                111.96                116.03                100.89
# 5831                100.68                111.96                116.03
#
#       previous_3day_price0  previous_3day_price1  previous_3day_price2
# 5807                152.10                153.59                116.60
# 5808                105.00                152.10                153.59
# 5809                152.73                105.00                152.10
# 5810                 91.00                152.73                105.00
# 5811                 92.00                 91.00                152.73
# 5812                105.00                 92.00                 91.00
# 5813                152.72                105.00                 92.00
# 5814                106.00                152.72                105.00
# 5815                152.51                106.00                152.72
# 5816                151.81                152.51                106.00
# 5817                151.67                151.81                152.51
# 5818                158.52                151.67                151.81
# 5819                155.47                158.52                151.67
# 5820                155.84                155.47                158.52
# 5821                156.62                155.84                155.47
# 5822                155.84                156.62                155.84
# 5823                155.72                155.84                156.62
# 5824                156.88                155.72                155.84
# 5825                138.00                156.88                155.72
# 5826                133.00                138.00                156.88
# 5827                133.00                133.00                138.00
# 5828                106.00                133.00                133.00
# 5829                 99.00                106.00                133.00
# 5830                 99.00                 99.00                106.00
# 5831                101.81                 99.00                 99.00

# %%
preds = []

for idx, i in enumerate(range(-24, 0, 1)):
    x = pred_df.iloc[i].drop('previous_price_kwh')
    pred = xgb_reg.predict([x])[0]
    preds.append(float(pred))
    
    pred_df.loc[5808+idx, 'previous_price_kwh'] = pred
    pred_df.loc[5809+idx, 'previous_hour_price1'] = pred

# %%
preds
# Out:
# [111.58560180664062,
#  112.77886962890625,
#  112.80117797851562,
#  109.12345886230469,
#  108.44062042236328,
#  111.90277862548828,
#  124.547119140625,
#  126.21125030517578,
#  135.42263793945312,
#  138.16700744628906,
#  140.02149963378906,
#  140.16859436035156,
#  140.78724670410156,
#  142.0712432861328,
#  144.922607421875,
#  144.00868225097656,
#  143.20225524902344,
#  140.14407348632812,
#  137.05343627929688,
#  134.23431396484375,
#  130.22573852539062,
#  121.1873779296875,
#  116.27983856201172,
#  119.09854125976562]

# %%
plt.plot(preds)

# %%
# 제주 전력시장 하루전가격 입찰
API_KEY = """eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJlcXpORXlBR1ZiNDdadUNpN2RLZ1hqIiwiaWF0IjoxNzMwMDcyODI2LCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.zsJAvYixxcUwz4ad-y2cWwi6oWdc1hmegSTFSbeMuzk"""

import json 
import requests

result = {
    'submit_result' : preds
}
success = requests.post('https://research-api.solarkim.com/submissions/cmpt-2024',
                    data=json.dumps(result),
                    headers={
                        'Authorization': f'Bearer {API_KEY}'
                    }).json()
print(success)
# Out:
# True
