# %% [markdown]
# # Import

# %%
import sys
import sktime
import tqdm as tq
import xgboost as xgb
import matplotlib
import seaborn as sns
import sklearn as skl
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from tqdm import tqdm
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.utils.plotting import plot_series
from xgboost import XGBRegressor

from evaluate import calculate_measure
from datetime import datetime, timedelta
import requests
import json 

API_KEY = """eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJlcXpORXlBR1ZiNDdadUNpN2RLZ1hqIiwiaWF0IjoxNzMwMDcyODI2LCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.zsJAvYixxcUwz4ad-y2cWwi6oWdc1hmegSTFSbeMuzk"""

# %% [markdown]
# # Data Preprocess

# %%
base_path = "/home/jinjinjara1022/"

weather_forecast_data_1 = pd.read_csv(base_path + "OBIC/data2/기상예측데이터_1_11-7.csv")
jeju_power_market_day_ahead = pd.read_csv(base_path + "OBIC/data2/제주전력시장_시장전기가격_하루전가격_11-7.csv")

# %%
weather_forecast_data_1 = weather_forecast_data_1[weather_forecast_data_1['location'] != 'location']
weather_forecast_data_1['ts'] =  pd.to_datetime(weather_forecast_data_1['ts'], unit='s')
weather_forecast_data_1['base_ts'] = pd.to_datetime(weather_forecast_data_1['base_ts'], unit='s')
# Out:
# /tmp/ipykernel_2595802/796732019.py:2: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   weather_forecast_data_1['ts'] =  pd.to_datetime(weather_forecast_data_1['ts'], unit='s')
# /tmp/ipykernel_2595802/796732019.py:3: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   weather_forecast_data_1['base_ts'] = pd.to_datetime(weather_forecast_data_1['base_ts'], unit='s')

# %%
# 평균을 구할 열 리스트
columns_to_average = [
    'temp', 'real_feel_temp', 'wet_bulb_temp', 'dew_point', 
    'wind_dir', 'wind_spd', 'wind_gust_spd', 'rel_hum', 'vis', 
    'ceiling', 'uv_idx', 'precip_prob', 'rain_prob', 'snow_prob', 
    'ice_prob', 'total_liq', 'rain', 'snow', 'ice', 'cld_cvr'
]

# 숫자형으로 변환할 수 있는 값만 변환
weather_forecast_data_1[columns_to_average] = weather_forecast_data_1[columns_to_average].apply(pd.to_numeric, errors='coerce')

# %%
# 'ts'로 그룹화하여 각 열의 평균 계산
average_df = weather_forecast_data_1.groupby('ts', as_index=False)[columns_to_average].mean()

weather_df = average_df

ahead_df = jeju_power_market_day_ahead

ahead_df['ts'] = pd.to_datetime(ahead_df['ts'], unit='s')

# %%
df = pd.merge(weather_df, ahead_df, on='ts')

# %%
df['hour'] = df['ts'].dt.hour
df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)

df['month'] = df['ts'].dt.month
df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)

df['day_of_week'] = df['ts'].dt.dayofweek
df['day_of_week_sin'] = np.sin(2 * np.pi * df['day_of_week'] / 7)
df['day_of_week_cos'] = np.cos(2 * np.pi * df['day_of_week'] / 7)

# %%
df.rename(columns={
    '하루전가격(원/kWh)': 'previous_price_kwh'
}, inplace=True)

# %%
df = df.drop(['ts','hour', 'month', 'day_of_week'], axis=1)

# %%
df['previous_day_price'] = df['previous_price_kwh'].shift(24)
df['previous_2day_price'] = df['previous_price_kwh'].shift(48)
df['previous_3day_price'] = df['previous_price_kwh'].shift(72)

# %%
df = df[72:]
df = df[[ 
    'previous_day_price', 'previous_2day_price', 'previous_3day_price', 
    'uv_idx', 'month_cos', 'month_sin','day_of_week_cos',
    'day_of_week_sin', 'rel_hum', 'hour_cos', 'wind_spd', 'cld_cvr',
    'hour_sin', 'wind_gust_spd', 'dew_point', 'real_feel_temp', 'ceiling',
    'wind_dir', 'wet_bulb_temp', 'temp', 'precip_prob', 'vis', 'rain_prob',
    'rain', 'total_liq', 'previous_price_kwh'
    ]]

# %%
y = df['previous_price_kwh']
x = df.drop(['previous_price_kwh'], axis=1)

# %%
y_train, y_valid, x_train, x_valid = temporal_train_test_split(y = y, X = x, test_size = int(len(y) * 0.1))
print('train data shape\nx:{}, y:{}'.format(x_train.shape, y_train.shape))
# Out:
# train data shape
# x:(5337, 25), y:(5337,)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# 스케일링할 열 선택
columns_to_scale = ['uv_idx', 'rel_hum', 'wind_spd', 'cld_cvr',
                        'wind_gust_spd', 'dew_point', 'real_feel_temp', 'ceiling',
                        'wind_dir', 'wet_bulb_temp', 'temp', 'precip_prob', 'vis', 
                    'rain_prob', 'rain', 'total_liq']

# %%
scaler1 = StandardScaler()

x_train[columns_to_scale] = scaler1.fit_transform(x_train[columns_to_scale])
x_valid[columns_to_scale] = scaler1.transform(x_valid[columns_to_scale])

# scaler2 = StandardScaler()

# x_train[columns_to_scale] = scaler2.fit_transform(x_train[columns_to_scale])
# x_valid[columns_to_scale] = scaler2.transform(x_valid[columns_to_scale])

# %% [markdown]
# # Train

# %%
import xgboost as xgb
print(xgb.__version__)
# Out:
# 2.1.1

# %%
xgb_reg = XGBRegressor(
    n_estimators=900,
    learning_rate=0.01, 
    min_child_weight=0.5,
    max_depth=6,
    colsample_bytree=0.8,
    subsample=0.8,
    tree_method='hist',
    device='cuda:0',
    seed=0,
    early_stopping_rounds=500 
)

xgb_reg.fit(
    x_train, y_train, 
    eval_set=[(x_train, y_train), (x_valid, y_valid)], 
    verbose=False
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda:0', early_stopping_rounds=500,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=0.5, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=900, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
def SMAPE(true, pred):
    return np.mean((np.abs(true-pred))/(np.abs(true) + np.abs(pred))) * 100

pred = xgb_reg.predict(x_valid)
pred = pd.Series(pred)
pred.index = np.arange(y_valid.index[0], y_valid.index[-1]+1)

plot_series(y_train, y_valid, pd.Series(pred), markers=[',' , ',', ','])

print('SMAPE : {}'.format(SMAPE(y_valid, pred)))
# Out:
# SMAPE : 12.022158434677067
# /home/jinjinjara1022/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [10:35:40] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)

# %%
plt.figure(figsize=(20, 5))
pred.plot(label='predict_price')
y_valid.plot()
plt.legend()
plt.show()

# %%
# 피쳐 중요도 시각화
xgb.plot_importance(xgb_reg, importance_type='weight')
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# # Parameter Tuning

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

def objective(trial):
    # 파라미터 제안 범위 설정
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1.0),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'tree_method': 'hist',
        'device': 'cuda:0',
        'seed': 0,
        'early_stopping_rounds' : 50
    }
    
    model = XGBRegressor(**param)
    
    eval_set = [(x_train, y_train), (x_valid, y_valid)]  # 학습 데이터와 검증 데이터 설정
    model.fit(x_train, y_train, 
              eval_set=eval_set,  # eval_set 사용
              verbose=False)
    
    preds = model.predict(x_valid)
    mse = SMAPE(y_valid, preds)
    return mse

# Optuna 스터디 생성
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2024-11-07 10:36:08,506] A new study created in memory with name: no-name-c7f8b7c0-29ef-41fe-aeee-1c9833019378
# [I 2024-11-07 10:36:09,662] Trial 0 finished with value: 11.96077628400253 and parameters: {'n_estimators': 240, 'learning_rate': 0.013303504103396188, 'max_depth': 8, 'min_child_weight': 2, 'colsample_bytree': 0.5345693142115154, 'subsample': 0.5011944718609722}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:10,178] Trial 1 finished with value: 12.029017211105305 and parameters: {'n_estimators': 138, 'learning_rate': 0.03808286660957895, 'max_depth': 3, 'min_child_weight': 5, 'colsample_bytree': 0.890267793723349, 'subsample': 0.860616242222217}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:10,824] Trial 2 finished with value: 12.525670558598193 and parameters: {'n_estimators': 482, 'learning_rate': 0.12271834143263738, 'max_depth': 7, 'min_child_weight': 8, 'colsample_bytree': 0.4190514736286595, 'subsample': 0.8238740175062124}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:11,615] Trial 3 finished with value: 12.263399493040056 and parameters: {'n_estimators': 346, 'learning_rate': 0.07112470924058756, 'max_depth': 8, 'min_child_weight': 9, 'colsample_bytree': 0.3671345985770861, 'subsample': 0.908805795964603}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:12,120] Trial 4 finished with value: 12.821435802763418 and parameters: {'n_estimators': 971, 'learning_rate': 0.20677280851757382, 'max_depth': 4, 'min_child_weight': 8, 'colsample_bytree': 0.4758768324999681, 'subsample': 0.6778897788072668}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:12,569] Trial 5 finished with value: 12.692965609478637 and parameters: {'n_estimators': 790, 'learning_rate': 0.16572878178941788, 'max_depth': 5, 'min_child_weight': 9, 'colsample_bytree': 0.307649472853119, 'subsample': 0.8736048898508169}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:13,138] Trial 6 finished with value: 13.262894616696228 and parameters: {'n_estimators': 274, 'learning_rate': 0.2827221075685154, 'max_depth': 9, 'min_child_weight': 1, 'colsample_bytree': 0.7478902255479682, 'subsample': 0.6065737809190033}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:13,747] Trial 7 finished with value: 13.080521586009835 and parameters: {'n_estimators': 443, 'learning_rate': 0.26204810323152994, 'max_depth': 9, 'min_child_weight': 3, 'colsample_bytree': 0.6723312658280369, 'subsample': 0.7416756051775606}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:14,434] Trial 8 finished with value: 12.561406131379222 and parameters: {'n_estimators': 167, 'learning_rate': 0.16574368515141846, 'max_depth': 7, 'min_child_weight': 7, 'colsample_bytree': 0.5117690873017628, 'subsample': 0.7957585272679168}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:14,880] Trial 9 finished with value: 12.713698095003206 and parameters: {'n_estimators': 380, 'learning_rate': 0.27739006766540514, 'max_depth': 5, 'min_child_weight': 2, 'colsample_bytree': 0.9339092454231821, 'subsample': 0.9919903262025742}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:17,020] Trial 10 finished with value: 12.143890314616232 and parameters: {'n_estimators': 706, 'learning_rate': 0.015599779116723797, 'max_depth': 10, 'min_child_weight': 4, 'colsample_bytree': 0.5825837659069646, 'subsample': 0.5256622685742212}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:17,506] Trial 11 finished with value: 12.593512303203838 and parameters: {'n_estimators': 142, 'learning_rate': 0.018113998992473408, 'max_depth': 3, 'min_child_weight': 5, 'colsample_bytree': 0.9858096979034914, 'subsample': 0.5061499447852843}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:18,081] Trial 12 finished with value: 12.042818634583917 and parameters: {'n_estimators': 116, 'learning_rate': 0.07687034736752998, 'max_depth': 6, 'min_child_weight': 6, 'colsample_bytree': 0.8146623387026795, 'subsample': 0.6935822839648718}. Best is trial 0 with value: 11.96077628400253.
# [I 2024-11-07 10:36:18,638] Trial 13 finished with value: 11.93845794857083 and parameters: {'n_estimators': 269, 'learning_rate': 0.06070799189264248, 'max_depth': 3, 'min_child_weight': 4, 'colsample_bytree': 0.8497639091750578, 'subsample': 0.9530597412936515}. Best is trial 13 with value: 11.93845794857083.
# [I 2024-11-07 10:36:19,412] Trial 14 finished with value: 12.229680054947806 and parameters: {'n_estimators': 591, 'learning_rate': 0.08440502019466617, 'max_depth': 8, 'min_child_weight': 3, 'colsample_bytree': 0.6402098150710103, 'subsample': 0.9843796217602326}. Best is trial 13 with value: 11.93845794857083.
# [I 2024-11-07 10:36:19,989] Trial 15 finished with value: 12.204485780467508 and parameters: {'n_estimators': 289, 'learning_rate': 0.11324120677651386, 'max_depth': 6, 'min_child_weight': 1, 'colsample_bytree': 0.776349969266602, 'subsample': 0.58590166501222}. Best is trial 13 with value: 11.93845794857083.
# [I 2024-11-07 10:36:20,767] Trial 16 finished with value: 11.827184420641505 and parameters: {'n_estimators': 596, 'learning_rate': 0.046930637737781944, 'max_depth': 5, 'min_child_weight': 3, 'colsample_bytree': 0.5750457843260723, 'subsample': 0.6351425447850192}. Best is trial 16 with value: 11.827184420641505.
# [I 2024-11-07 10:36:21,419] Trial 17 finished with value: 11.785246291830227 and parameters: {'n_estimators': 612, 'learning_rate': 0.05462060799873388, 'max_depth': 4, 'min_child_weight': 4, 'colsample_bytree': 0.6766420127653037, 'subsample': 0.6392194329239554}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:21,901] Trial 18 finished with value: 11.970156415318128 and parameters: {'n_estimators': 648, 'learning_rate': 0.10679554825118792, 'max_depth': 5, 'min_child_weight': 6, 'colsample_bytree': 0.699738898098127, 'subsample': 0.625684330970728}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:22,353] Trial 19 finished with value: 13.045963113527268 and parameters: {'n_estimators': 819, 'learning_rate': 0.20674860172120835, 'max_depth': 4, 'min_child_weight': 4, 'colsample_bytree': 0.6034011692001899, 'subsample': 0.6609012317592964}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:22,904] Trial 20 finished with value: 11.91565398371809 and parameters: {'n_estimators': 532, 'learning_rate': 0.059687578659299426, 'max_depth': 4, 'min_child_weight': 2, 'colsample_bytree': 0.6971170846810847, 'subsample': 0.7390874718726698}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:23,346] Trial 21 finished with value: 11.871014465863947 and parameters: {'n_estimators': 547, 'learning_rate': 0.06110349670289029, 'max_depth': 4, 'min_child_weight': 3, 'colsample_bytree': 0.7193494744471618, 'subsample': 0.7146082092698316}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:23,856] Trial 22 finished with value: 12.098203549123243 and parameters: {'n_estimators': 620, 'learning_rate': 0.04566163927219755, 'max_depth': 4, 'min_child_weight': 3, 'colsample_bytree': 0.5807379208152128, 'subsample': 0.564806235941391}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:24,094] Trial 23 finished with value: 12.030708039469653 and parameters: {'n_estimators': 693, 'learning_rate': 0.13803099189657123, 'max_depth': 5, 'min_child_weight': 4, 'colsample_bytree': 0.7074811166155417, 'subsample': 0.7089772963041129}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:24,384] Trial 24 finished with value: 12.204916176560413 and parameters: {'n_estimators': 535, 'learning_rate': 0.09889011640372523, 'max_depth': 6, 'min_child_weight': 3, 'colsample_bytree': 0.7655543594909946, 'subsample': 0.6336909744362221}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:24,845] Trial 25 finished with value: 11.904719334095413 and parameters: {'n_estimators': 753, 'learning_rate': 0.04057190819794182, 'max_depth': 4, 'min_child_weight': 5, 'colsample_bytree': 0.6130504180999203, 'subsample': 0.7753607619640333}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:25,413] Trial 26 finished with value: 12.544883317638778 and parameters: {'n_estimators': 868, 'learning_rate': 0.0870825104388676, 'max_depth': 5, 'min_child_weight': 2, 'colsample_bytree': 0.45362375870627003, 'subsample': 0.551704937778071}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:25,975] Trial 27 finished with value: 12.38039300585646 and parameters: {'n_estimators': 448, 'learning_rate': 0.14114118987372612, 'max_depth': 3, 'min_child_weight': 1, 'colsample_bytree': 0.5476399296465475, 'subsample': 0.654237845332099}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:26,524] Trial 28 finished with value: 12.09077801857293 and parameters: {'n_estimators': 584, 'learning_rate': 0.05096959825873688, 'max_depth': 4, 'min_child_weight': 4, 'colsample_bytree': 0.6535012312347824, 'subsample': 0.7274105772257098}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:27,631] Trial 29 finished with value: 11.893350254894466 and parameters: {'n_estimators': 512, 'learning_rate': 0.01099962452435456, 'max_depth': 6, 'min_child_weight': 3, 'colsample_bytree': 0.5186147753343661, 'subsample': 0.5990957168288487}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:28,313] Trial 30 finished with value: 11.887586851763423 and parameters: {'n_estimators': 669, 'learning_rate': 0.028232687827176042, 'max_depth': 5, 'min_child_weight': 6, 'colsample_bytree': 0.8177648803246196, 'subsample': 0.7726965306943343}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:29,041] Trial 31 finished with value: 11.96183679508424 and parameters: {'n_estimators': 662, 'learning_rate': 0.030396277947496098, 'max_depth': 5, 'min_child_weight': 6, 'colsample_bytree': 0.808643575571995, 'subsample': 0.7745259200359302}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:29,773] Trial 32 finished with value: 12.038504071911664 and parameters: {'n_estimators': 727, 'learning_rate': 0.03084274904355013, 'max_depth': 3, 'min_child_weight': 5, 'colsample_bytree': 0.8496142419470423, 'subsample': 0.6994357869010385}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:30,189] Trial 33 finished with value: 12.143101910675446 and parameters: {'n_estimators': 575, 'learning_rate': 0.06363644880068942, 'max_depth': 4, 'min_child_weight': 7, 'colsample_bytree': 0.7327485171312245, 'subsample': 0.8048727818039667}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:30,763] Trial 34 finished with value: 12.054616685532093 and parameters: {'n_estimators': 469, 'learning_rate': 0.035413507969253806, 'max_depth': 5, 'min_child_weight': 7, 'colsample_bytree': 0.9086821811911392, 'subsample': 0.6477030700793798}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:31,140] Trial 35 finished with value: 12.153074959191853 and parameters: {'n_estimators': 389, 'learning_rate': 0.08940664249970942, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.8037391798486634, 'subsample': 0.8488927663297909}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:31,552] Trial 36 finished with value: 12.090986832317467 and parameters: {'n_estimators': 631, 'learning_rate': 0.051189765020812496, 'max_depth': 6, 'min_child_weight': 5, 'colsample_bytree': 0.8558590933422415, 'subsample': 0.6799169869416632}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:31,961] Trial 37 finished with value: 12.02838671449528 and parameters: {'n_estimators': 864, 'learning_rate': 0.07254515081582083, 'max_depth': 4, 'min_child_weight': 2, 'colsample_bytree': 0.4052967246218422, 'subsample': 0.7626511232106878}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:32,669] Trial 38 finished with value: 12.032030026593246 and parameters: {'n_estimators': 990, 'learning_rate': 0.0263808544207378, 'max_depth': 3, 'min_child_weight': 4, 'colsample_bytree': 0.6429544203088372, 'subsample': 0.7175840314308553}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:32,994] Trial 39 finished with value: 12.799288556782514 and parameters: {'n_estimators': 773, 'learning_rate': 0.19448611432664778, 'max_depth': 5, 'min_child_weight': 6, 'colsample_bytree': 0.7317338863288005, 'subsample': 0.6152674103680313}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:33,315] Trial 40 finished with value: 11.98900378915151 and parameters: {'n_estimators': 492, 'learning_rate': 0.09860244776724866, 'max_depth': 4, 'min_child_weight': 8, 'colsample_bytree': 0.6804016017512134, 'subsample': 0.8836391219386935}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:34,440] Trial 41 finished with value: 11.988475881513757 and parameters: {'n_estimators': 513, 'learning_rate': 0.011247143270478233, 'max_depth': 6, 'min_child_weight': 3, 'colsample_bytree': 0.5095699502369286, 'subsample': 0.5908493600632602}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:35,341] Trial 42 finished with value: 12.016034825981183 and parameters: {'n_estimators': 419, 'learning_rate': 0.02104021282217721, 'max_depth': 6, 'min_child_weight': 3, 'colsample_bytree': 0.556745113934201, 'subsample': 0.6703450116997072}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:35,930] Trial 43 finished with value: 12.414997169265792 and parameters: {'n_estimators': 557, 'learning_rate': 0.04888091516191258, 'max_depth': 7, 'min_child_weight': 2, 'colsample_bytree': 0.4908459148301683, 'subsample': 0.5570407533202464}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:36,151] Trial 44 finished with value: 12.71841499355973 and parameters: {'n_estimators': 678, 'learning_rate': 0.240949487083532, 'max_depth': 5, 'min_child_weight': 3, 'colsample_bytree': 0.6149078105093875, 'subsample': 0.6004614882304348}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:37,486] Trial 45 finished with value: 11.787827608957727 and parameters: {'n_estimators': 610, 'learning_rate': 0.010024798004890458, 'max_depth': 6, 'min_child_weight': 4, 'colsample_bytree': 0.45356748852371664, 'subsample': 0.8366522075850416}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:37,876] Trial 46 finished with value: 12.1428100112249 and parameters: {'n_estimators': 634, 'learning_rate': 0.0677129638297334, 'max_depth': 5, 'min_child_weight': 5, 'colsample_bytree': 0.38980959382496694, 'subsample': 0.8350952548111782}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:38,468] Trial 47 finished with value: 12.030904742659596 and parameters: {'n_estimators': 721, 'learning_rate': 0.036951482321839375, 'max_depth': 7, 'min_child_weight': 4, 'colsample_bytree': 0.35292697590059663, 'subsample': 0.9128164928304376}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:38,875] Trial 48 finished with value: 12.84379647199444 and parameters: {'n_estimators': 604, 'learning_rate': 0.12614623593771504, 'max_depth': 8, 'min_child_weight': 5, 'colsample_bytree': 0.4435124381158075, 'subsample': 0.7948140625682923}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:39,247] Trial 49 finished with value: 12.161011744930274 and parameters: {'n_estimators': 337, 'learning_rate': 0.0778792932066167, 'max_depth': 3, 'min_child_weight': 4, 'colsample_bytree': 0.30506249781778555, 'subsample': 0.8167401157591929}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:39,438] Trial 50 finished with value: 12.338792105025533 and parameters: {'n_estimators': 832, 'learning_rate': 0.2964165578448852, 'max_depth': 5, 'min_child_weight': 6, 'colsample_bytree': 0.9794784053528469, 'subsample': 0.8806010024472987}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:40,509] Trial 51 finished with value: 11.870468489215359 and parameters: {'n_estimators': 494, 'learning_rate': 0.014794405488477456, 'max_depth': 6, 'min_child_weight': 3, 'colsample_bytree': 0.5167033920383383, 'subsample': 0.6329244922235767}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:41,394] Trial 52 finished with value: 12.008281718294635 and parameters: {'n_estimators': 553, 'learning_rate': 0.022140314355156024, 'max_depth': 6, 'min_child_weight': 2, 'colsample_bytree': 0.4422710822182307, 'subsample': 0.7498729946303143}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:41,872] Trial 53 finished with value: 12.105581373331587 and parameters: {'n_estimators': 601, 'learning_rate': 0.05530053421192597, 'max_depth': 5, 'min_child_weight': 3, 'colsample_bytree': 0.5734767792880656, 'subsample': 0.6891254175950987}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:42,610] Trial 54 finished with value: 12.092795165640409 and parameters: {'n_estimators': 470, 'learning_rate': 0.04009107408559956, 'max_depth': 6, 'min_child_weight': 4, 'colsample_bytree': 0.5394179212282706, 'subsample': 0.6358280476031921}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:43,855] Trial 55 finished with value: 11.892599241018821 and parameters: {'n_estimators': 658, 'learning_rate': 0.020228913457078376, 'max_depth': 7, 'min_child_weight': 1, 'colsample_bytree': 0.4773079736124622, 'subsample': 0.7317059209019929}. Best is trial 17 with value: 11.785246291830227.
# [I 2024-11-07 10:36:44,430] Trial 56 finished with value: 11.76457290458802 and parameters: {'n_estimators': 564, 'learning_rate': 0.03290157491233224, 'max_depth': 4, 'min_child_weight': 3, 'colsample_bytree': 0.7827122849378103, 'subsample': 0.9068219162669544}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:45,131] Trial 57 finished with value: 12.025260700414172 and parameters: {'n_estimators': 433, 'learning_rate': 0.011037389561766198, 'max_depth': 4, 'min_child_weight': 3, 'colsample_bytree': 0.34770996104868, 'subsample': 0.9107957195407684}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:45,520] Trial 58 finished with value: 11.918971305353573 and parameters: {'n_estimators': 507, 'learning_rate': 0.06060849298622032, 'max_depth': 4, 'min_child_weight': 2, 'colsample_bytree': 0.7220395796399769, 'subsample': 0.9597566664471937}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:45,886] Trial 59 finished with value: 11.853116148374356 and parameters: {'n_estimators': 552, 'learning_rate': 0.04383848635384865, 'max_depth': 4, 'min_child_weight': 3, 'colsample_bytree': 0.6015190886414076, 'subsample': 0.9343963162498842}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:47,126] Trial 60 finished with value: 12.281620692875595 and parameters: {'n_estimators': 560, 'learning_rate': 0.044875039503088285, 'max_depth': 10, 'min_child_weight': 4, 'colsample_bytree': 0.6617878469864997, 'subsample': 0.9381189466962633}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:47,687] Trial 61 finished with value: 11.94767722276128 and parameters: {'n_estimators': 605, 'learning_rate': 0.03811785232174678, 'max_depth': 4, 'min_child_weight': 3, 'colsample_bytree': 0.6300160145624422, 'subsample': 0.9698120292573476}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:47,991] Trial 62 finished with value: 11.931912389138185 and parameters: {'n_estimators': 532, 'learning_rate': 0.0767371101113759, 'max_depth': 3, 'min_child_weight': 2, 'colsample_bytree': 0.7681952591600246, 'subsample': 0.8599106542168624}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:48,342] Trial 63 finished with value: 11.845446587928649 and parameters: {'n_estimators': 581, 'learning_rate': 0.0545207177831635, 'max_depth': 4, 'min_child_weight': 3, 'colsample_bytree': 0.5952190134734631, 'subsample': 0.9304858774665625}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:48,527] Trial 64 finished with value: 12.083786167096818 and parameters: {'n_estimators': 580, 'learning_rate': 0.17806625856028307, 'max_depth': 4, 'min_child_weight': 4, 'colsample_bytree': 0.5919822782038271, 'subsample': 0.9243016792369311}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:49,149] Trial 65 finished with value: 12.073157174707623 and parameters: {'n_estimators': 695, 'learning_rate': 0.026748509674848348, 'max_depth': 3, 'min_child_weight': 3, 'colsample_bytree': 0.5212489705409267, 'subsample': 0.9739613720386885}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:50,064] Trial 66 finished with value: 12.061358656181067 and parameters: {'n_estimators': 631, 'learning_rate': 0.046169276428089705, 'max_depth': 9, 'min_child_weight': 4, 'colsample_bytree': 0.5656781178146739, 'subsample': 0.8967865150426662}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:50,959] Trial 67 finished with value: 11.887960911446697 and parameters: {'n_estimators': 482, 'learning_rate': 0.01967430122405462, 'max_depth': 5, 'min_child_weight': 2, 'colsample_bytree': 0.6082806475746995, 'subsample': 0.5761499397928318}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:51,199] Trial 68 finished with value: 12.620910073950888 and parameters: {'n_estimators': 404, 'learning_rate': 0.23414330800377206, 'max_depth': 4, 'min_child_weight': 3, 'colsample_bytree': 0.5014221986980882, 'subsample': 0.9965225049612609}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:51,553] Trial 69 finished with value: 11.830920351356587 and parameters: {'n_estimators': 339, 'learning_rate': 0.057752097748085644, 'max_depth': 6, 'min_child_weight': 3, 'colsample_bytree': 0.6830386852792054, 'subsample': 0.9267949621471481}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:51,910] Trial 70 finished with value: 11.981160032666276 and parameters: {'n_estimators': 221, 'learning_rate': 0.06832844167932069, 'max_depth': 4, 'min_child_weight': 1, 'colsample_bytree': 0.6773135851168517, 'subsample': 0.9421993943158632}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:52,430] Trial 71 finished with value: 11.829449810688473 and parameters: {'n_estimators': 370, 'learning_rate': 0.05507950952304383, 'max_depth': 6, 'min_child_weight': 3, 'colsample_bytree': 0.6264498338250171, 'subsample': 0.9305041280064056}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:52,981] Trial 72 finished with value: 11.995793795893354 and parameters: {'n_estimators': 359, 'learning_rate': 0.05824360353124888, 'max_depth': 6, 'min_child_weight': 3, 'colsample_bytree': 0.6325971224214685, 'subsample': 0.9258275974911963}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:53,331] Trial 73 finished with value: 11.987579130931628 and parameters: {'n_estimators': 304, 'learning_rate': 0.09347153637569316, 'max_depth': 7, 'min_child_weight': 2, 'colsample_bytree': 0.6975251569153184, 'subsample': 0.8987211150971863}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:53,765] Trial 74 finished with value: 12.036639426365946 and parameters: {'n_estimators': 220, 'learning_rate': 0.08338967891879427, 'max_depth': 5, 'min_child_weight': 4, 'colsample_bytree': 0.7538459901757779, 'subsample': 0.950446847437272}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:54,200] Trial 75 finished with value: 12.190072766719048 and parameters: {'n_estimators': 323, 'learning_rate': 0.0533465607836282, 'max_depth': 6, 'min_child_weight': 3, 'colsample_bytree': 0.6614092723274427, 'subsample': 0.8700250845403976}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:54,522] Trial 76 finished with value: 12.091090747894881 and parameters: {'n_estimators': 573, 'learning_rate': 0.11112414988972591, 'max_depth': 5, 'min_child_weight': 4, 'colsample_bytree': 0.5914310593287795, 'subsample': 0.9278744778784497}. Best is trial 56 with value: 11.76457290458802.
# [I 2024-11-07 10:36:54,861] Trial 77 finished with value: 11.569184360225066 and parameters: {'n_estimators': 186, 'learning_rate': 0.03287787591504163, 'max_depth': 4, 'min_child_weight': 2, 'colsample_bytree': 0.7914546192500185, 'subsample': 0.8913592280893505}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:36:55,630] Trial 78 finished with value: 11.78635246299665 and parameters: {'n_estimators': 143, 'learning_rate': 0.031177280264559196, 'max_depth': 8, 'min_child_weight': 2, 'colsample_bytree': 0.8273034231199492, 'subsample': 0.8912567843832488}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:36:56,603] Trial 79 finished with value: 12.060428443847753 and parameters: {'n_estimators': 153, 'learning_rate': 0.03352785045319429, 'max_depth': 9, 'min_child_weight': 2, 'colsample_bytree': 0.7951748848003505, 'subsample': 0.8409056267248309}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:36:57,107] Trial 80 finished with value: 11.880473325201777 and parameters: {'n_estimators': 104, 'learning_rate': 0.03035562198171052, 'max_depth': 8, 'min_child_weight': 1, 'colsample_bytree': 0.8772524241483629, 'subsample': 0.893653764842887}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:36:57,546] Trial 81 finished with value: 12.059703177365735 and parameters: {'n_estimators': 242, 'learning_rate': 0.0673785412529154, 'max_depth': 7, 'min_child_weight': 2, 'colsample_bytree': 0.8252860615261253, 'subsample': 0.8616749368830044}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:36:57,879] Trial 82 finished with value: 11.81294740861243 and parameters: {'n_estimators': 127, 'learning_rate': 0.052561015522926025, 'max_depth': 6, 'min_child_weight': 2, 'colsample_bytree': 0.7492104124222716, 'subsample': 0.9037848763718058}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:36:58,330] Trial 83 finished with value: 11.883734413094164 and parameters: {'n_estimators': 181, 'learning_rate': 0.03784950021473579, 'max_depth': 6, 'min_child_weight': 1, 'colsample_bytree': 0.7864183902281086, 'subsample': 0.9129060281163887}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:36:58,671] Trial 84 finished with value: 11.8586592016791 and parameters: {'n_estimators': 125, 'learning_rate': 0.025477452275269832, 'max_depth': 6, 'min_child_weight': 2, 'colsample_bytree': 0.7468283940992818, 'subsample': 0.8885651049068864}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:36:59,365] Trial 85 finished with value: 12.162296055361086 and parameters: {'n_estimators': 185, 'learning_rate': 0.04819083684224369, 'max_depth': 8, 'min_child_weight': 2, 'colsample_bytree': 0.7151740303598371, 'subsample': 0.904747454223583}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:36:59,724] Trial 86 finished with value: 12.056072829487585 and parameters: {'n_estimators': 205, 'learning_rate': 0.07258375883451249, 'max_depth': 7, 'min_child_weight': 2, 'colsample_bytree': 0.8354269076141546, 'subsample': 0.8241344821432034}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:00,317] Trial 87 finished with value: 12.06424474763442 and parameters: {'n_estimators': 255, 'learning_rate': 0.031327419369460895, 'max_depth': 6, 'min_child_weight': 1, 'colsample_bytree': 0.6918048901919571, 'subsample': 0.5339979434413732}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:00,741] Trial 88 finished with value: 11.894151857416068 and parameters: {'n_estimators': 163, 'learning_rate': 0.017521881471135044, 'max_depth': 6, 'min_child_weight': 2, 'colsample_bytree': 0.7816004337293835, 'subsample': 0.8777233018770059}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:01,040] Trial 89 finished with value: 11.73057338098332 and parameters: {'n_estimators': 137, 'learning_rate': 0.059847212563400407, 'max_depth': 5, 'min_child_weight': 5, 'colsample_bytree': 0.7610205753949572, 'subsample': 0.9544813767767703}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:01,330] Trial 90 finished with value: 11.91652158228077 and parameters: {'n_estimators': 126, 'learning_rate': 0.042233733198211026, 'max_depth': 5, 'min_child_weight': 5, 'colsample_bytree': 0.8703833751881542, 'subsample': 0.9790349376585369}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:01,703] Trial 91 finished with value: 11.9898138094264 and parameters: {'n_estimators': 147, 'learning_rate': 0.06323563881978475, 'max_depth': 6, 'min_child_weight': 5, 'colsample_bytree': 0.7463911734788704, 'subsample': 0.9648207901225275}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:01,993] Trial 92 finished with value: 11.902605183043198 and parameters: {'n_estimators': 101, 'learning_rate': 0.08074445655634144, 'max_depth': 6, 'min_child_weight': 3, 'colsample_bytree': 0.7640181982168739, 'subsample': 0.951884581222538}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:02,565] Trial 93 finished with value: 11.799345108952991 and parameters: {'n_estimators': 270, 'learning_rate': 0.04980753217523107, 'max_depth': 5, 'min_child_weight': 4, 'colsample_bytree': 0.7324458378251475, 'subsample': 0.916040430222519}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:03,189] Trial 94 finished with value: 11.946688907722988 and parameters: {'n_estimators': 191, 'learning_rate': 0.05080494034621975, 'max_depth': 5, 'min_child_weight': 4, 'colsample_bytree': 0.7312502835688035, 'subsample': 0.8656537760879828}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:03,864] Trial 95 finished with value: 11.882643654270481 and parameters: {'n_estimators': 271, 'learning_rate': 0.038268920222181334, 'max_depth': 5, 'min_child_weight': 5, 'colsample_bytree': 0.8051433430918216, 'subsample': 0.8472001002922074}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:04,278] Trial 96 finished with value: 11.918310951816105 and parameters: {'n_estimators': 142, 'learning_rate': 0.023524611299945312, 'max_depth': 5, 'min_child_weight': 5, 'colsample_bytree': 0.8322445377783781, 'subsample': 0.909609369797175}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:04,585] Trial 97 finished with value: 12.639942853625252 and parameters: {'n_estimators': 165, 'learning_rate': 0.010560194999260347, 'max_depth': 4, 'min_child_weight': 4, 'colsample_bytree': 0.7851441009097876, 'subsample': 0.9441639992301905}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:04,854] Trial 98 finished with value: 12.153529424699071 and parameters: {'n_estimators': 294, 'learning_rate': 0.15672376382972836, 'max_depth': 4, 'min_child_weight': 4, 'colsample_bytree': 0.7107926228175866, 'subsample': 0.9858238093054692}. Best is trial 77 with value: 11.569184360225066.
# [I 2024-11-07 10:37:05,519] Trial 99 finished with value: 12.057834748974788 and parameters: {'n_estimators': 219, 'learning_rate': 0.044383627801344576, 'max_depth': 10, 'min_child_weight': 3, 'colsample_bytree': 0.7630562575678256, 'subsample': 0.6131601052995479}. Best is trial 77 with value: 11.569184360225066.

# %%
print("Best parameters:", study.best_params)
print("Best MSE:", study.best_value)
# Out:
# Best parameters: {'n_estimators': 186, 'learning_rate': 0.03287787591504163, 'max_depth': 4, 'min_child_weight': 2, 'colsample_bytree': 0.7914546192500185, 'subsample': 0.8913592280893505}
# Best MSE: 11.569184360225066

# %%
xgb_reg = XGBRegressor(**study.best_params)

xgb_reg.fit(
    x_train, y_train, 
    eval_set=[(x_train, y_train), (x_valid, y_valid)], 
    verbose=False
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7914546192500185, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.03287787591504163, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=2, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=186, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
pred = xgb_reg.predict(x_valid)
pred = pd.Series(pred)
pred.index = np.arange(y_valid.index[0], y_valid.index[-1]+1)

plot_series(y_train, y_valid, pd.Series(pred), markers=[',' , ',', ','])

print('SMAPE : {}'.format(SMAPE(y_valid, pred)))
# Out:
# SMAPE : 11.842232193590714

# %%
plt.figure(figsize=(20, 5))
pred.plot(label='predict_price')
y_valid.plot()
plt.legend()
plt.show()

# %%
# 피쳐 중요도 시각화
xgb.plot_importance(xgb_reg, importance_type='weight')
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# # SUBMIT DATA

# %%
def submit_df(date): #2024-11-05 <- str # 제출하는 날짜 입력
    year, month, day = map(int, date.split('-'))
    date_object = datetime(year, month, day)

    
    API_KEY = """eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJlcXpORXlBR1ZiNDdadUNpN2RLZ1hqIiwiaWF0IjoxNzMwMDcyODI2LCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.zsJAvYixxcUwz4ad-y2cWwi6oWdc1hmegSTFSbeMuzk"""
    
    columns = [
    'previous_day_price', 'previous_2day_price', 'previous_3day_price',
    'uv_idx', 'month_cos', 'month_sin','day_of_week_cos',
    'day_of_week_sin', 'rel_hum', 'hour_cos', 'wind_spd', 'cld_cvr',
    'hour_sin', 'wind_gust_spd', 'dew_point', 'real_feel_temp', 'ceiling',
    'wind_dir', 'wet_bulb_temp', 'temp', 'precip_prob', 'vis', 'rain_prob',
    'rain', 'total_liq'
    ]

    none_dataframe = pd.DataFrame(columns=columns)
    none_dataframe = none_dataframe.reindex(range(24))

    
    none_dataframe['hour_cos'] = [np.cos(2 * np.pi * hour / 24) for hour in range(1, 25)]
    none_dataframe['hour_sin'] = [np.sin(2 * np.pi * hour / 24) for hour in range(1, 25)]

    none_dataframe['month_sin'] = np.sin(2 * np.pi * int(date.split('-')[1]) / 12)
    none_dataframe['month_cos'] = np.cos(2 * np.pi * int(date.split('-')[1]) / 12)

    none_dataframe['day_of_week_sin'] = np.sin(2 * np.pi * int(date.split('-')[2]) / 7)
    none_dataframe['day_of_week_cos'] = np.cos(2 * np.pi * int(date.split('-')[2]) / 7)

    forecast_date = date
    weather_forecast = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/weather-forecast/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()

    weather_forecast_df = pd.DataFrame(weather_forecast['weather_forecast_1'])
    weather_forecast_df = weather_forecast_df.drop(['location'], axis=1)

    weather_forecast_df_grouped = weather_forecast_df.groupby('ts').mean().reset_index()
    weather_forecast_df_grouped = weather_forecast_df_grouped.drop(index=0).reset_index(drop=True)


    weather_col = [
        'uv_idx', 'rel_hum',  'wind_spd', 'cld_cvr',
        'wind_gust_spd', 'dew_point', 'real_feel_temp', 'ceiling',
        'wind_dir', 'wet_bulb_temp', 'temp', 'precip_prob', 
        'vis', 'rain_prob', 'rain', 'total_liq'
        ]    

    for col in weather_col:
        none_dataframe[col] = weather_forecast_df_grouped[col]

    smp_preday_1 = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                                'Authorization': f'Bearer {API_KEY}'
                            }).json()
    
    none_dataframe['previous_day_price'] = pd.DataFrame(smp_preday_1)['smp_da']
    
    
    previous_day = date_object - timedelta(days=1)
    date = f"{previous_day.year}-{previous_day.month:02d}-{previous_day.day:02d}"

    
    smp_preday_2 = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                                'Authorization': f'Bearer {API_KEY}'
                            }).json()

    none_dataframe['previous_2day_price'] = pd.DataFrame(smp_preday_2)['smp_da']


    previous_day = date_object - timedelta(days=2)
    date = f"{previous_day.year}-{previous_day.month:02d}-{previous_day.day:02d}"

    smp_preday_3 = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                                'Authorization': f'Bearer {API_KEY}'
                            }).json()

    none_dataframe['previous_3day_price'] = pd.DataFrame(smp_preday_3)['smp_da']

     
    return none_dataframe

# %%
submit_data = submit_df('2024-11-07')

# %%
submit_data[columns_to_scale] = scaler1.transform(submit_data[columns_to_scale])
#submit_data[columns_to_scale] = scaler2.transform(submit_data[columns_to_scale])

# %%
pred = xgb_reg.predict(submit_data)
pred_float = list(map(float, pred))

# %%
result = {
    'submit_result' : pred_float
}
success = requests.post('https://research-api.solarkim.com/submissions/cmpt-2024',
                    data=json.dumps(result),
                    headers={
                        'Authorization': f'Bearer {API_KEY}'
                    }).json()
print(success)
# Out:
# True

# %% [markdown]
# # CHECK

# %%
submit_data = submit_df('2024-11-04') # 제출일
submit_data[columns_to_scale] = scaler1.transform(submit_data[columns_to_scale])
#submit_data[columns_to_scale] = scaler2.transform(submit_data[columns_to_scale])
pred = xgb_reg.predict(submit_data)
pred_float = list(map(float, pred))

# %%
date = '2024-11-05'
smp_da = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()
real = []

for i in smp_da:
    real.append(i['smp_da'])

# %%
plt.plot(real, label='real')
plt.plot(pred, label='pred')
#plt.ylim(-100, 200)

plt.legend()
plt.title(f"score : {calculate_measure(real, pred)}")
plt.show()
