# %% [markdown]
# # Import

# %%
import sys
import sktime
import tqdm as tq
import xgboost as xgb
import matplotlib
import seaborn as sns
import sklearn as skl
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from tqdm import tqdm
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.utils.plotting import plot_series
from xgboost import XGBRegressor

from evaluate import calculate_measure
from datetime import datetime, timedelta
import requests
import json 

API_KEY = """eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJlcXpORXlBR1ZiNDdadUNpN2RLZ1hqIiwiaWF0IjoxNzMwMDcyODI2LCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.zsJAvYixxcUwz4ad-y2cWwi6oWdc1hmegSTFSbeMuzk"""

# %% [markdown]
# # Data Preprocess

# %%
base_path = "/home/jinjinjara1022/"

weather_forecast_data_1 = pd.read_csv(base_path + "OBIC/data2/기상예측데이터_1_11-7.csv")
jeju_power_market_day_ahead = pd.read_csv(base_path + "OBIC/data2/제주전력시장_시장전기가격_하루전가격_11-7.csv")

# %%
weather_forecast_data_1 = weather_forecast_data_1[weather_forecast_data_1['location'] != 'location']
weather_forecast_data_1['ts'] =  pd.to_datetime(weather_forecast_data_1['ts'], unit='s')
weather_forecast_data_1['base_ts'] = pd.to_datetime(weather_forecast_data_1['base_ts'], unit='s')
# Out:
# /tmp/ipykernel_2571168/796732019.py:2: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   weather_forecast_data_1['ts'] =  pd.to_datetime(weather_forecast_data_1['ts'], unit='s')
# /tmp/ipykernel_2571168/796732019.py:3: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   weather_forecast_data_1['base_ts'] = pd.to_datetime(weather_forecast_data_1['base_ts'], unit='s')

# %%
# 평균을 구할 열 리스트
columns_to_average = [
    'temp', 'real_feel_temp', 'wet_bulb_temp', 'dew_point', 
    'wind_dir', 'wind_spd', 'wind_gust_spd', 'rel_hum', 'vis', 
    'ceiling', 'uv_idx', 'precip_prob', 'rain_prob', 'snow_prob', 
    'ice_prob', 'total_liq', 'rain', 'snow', 'ice', 'cld_cvr'
]

# 숫자형으로 변환할 수 있는 값만 변환
weather_forecast_data_1[columns_to_average] = weather_forecast_data_1[columns_to_average].apply(pd.to_numeric, errors='coerce')

# %%
# 'ts'로 그룹화하여 각 열의 평균 계산
average_df = weather_forecast_data_1.groupby('ts', as_index=False)[columns_to_average].mean()

weather_df = average_df

ahead_df = jeju_power_market_day_ahead

ahead_df['ts'] = pd.to_datetime(ahead_df['ts'], unit='s')

# %%
df = pd.merge(weather_df, ahead_df, on='ts')

# %%
df['hour'] = df['ts'].dt.hour
df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)

df['month'] = df['ts'].dt.month
df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)

df['day_of_week'] = df['ts'].dt.dayofweek
df['day_of_week_sin'] = np.sin(2 * np.pi * df['day_of_week'] / 7)
df['day_of_week_cos'] = np.cos(2 * np.pi * df['day_of_week'] / 7)

# %%
df.rename(columns={
    '하루전가격(원/kWh)': 'previous_price_kwh'
}, inplace=True)

# %%
df = df.drop(['ts','hour', 'month', 'day_of_week'], axis=1)

# %%
df['previous_day_price'] = df['previous_price_kwh'].shift(24)
df['previous_2day_price'] = df['previous_price_kwh'].shift(48)
df['previous_3day_price'] = df['previous_price_kwh'].shift(72)

# %%
df = df[72:]

# %%
y = df['previous_price_kwh']
x = df.drop(['previous_price_kwh'], axis=1)

# %%
y_train, y_valid, x_train, x_valid = temporal_train_test_split(y = y, X = x, test_size = int(len(y) * 0.1))
print('train data shape\nx:{}, y:{}'.format(x_train.shape, y_train.shape))
# Out:
# train data shape
# x:(5337, 29), y:(5337,)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# 스케일링할 열 선택
columns_to_scale = ['uv_idx', 'rel_hum', 'wind_spd', 'cld_cvr',
                        'wind_gust_spd', 'dew_point', 'real_feel_temp', 'ceiling',
                        'wind_dir', 'wet_bulb_temp', 'temp', 'precip_prob', 'vis', 
                    'rain_prob', 'rain', 'total_liq']

# %%
scaler1 = StandardScaler()

x_train[columns_to_scale] = scaler1.fit_transform(x_train[columns_to_scale])
x_valid[columns_to_scale] = scaler1.transform(x_valid[columns_to_scale])

# scaler2 = StandardScaler()

# x_train[columns_to_scale] = scaler2.fit_transform(x_train[columns_to_scale])
# x_valid[columns_to_scale] = scaler2.transform(x_valid[columns_to_scale])

# %% [markdown]
# # Train

# %%
import xgboost as xgb
print(xgb.__version__)
# Out:
# 2.1.1

# %%
xgb_reg = XGBRegressor(
    n_estimators=900,
    learning_rate=0.05,
    min_child_weight=1,
    max_depth=7,
    colsample_bytree=0.7,
    subsample=0.7,
    tree_method='hist',
    device='cuda:0',
    seed=0,
    early_stopping_rounds=500
)

xgb_reg.fit(
    x_train, y_train,
    eval_set=[(x_train, y_train), (x_valid, y_valid)],
    verbose=False
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device='cuda:0', early_stopping_rounds=500,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=900, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

def objective(trial):
    # 파라미터 제안 범위 설정
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1.0),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'tree_method': 'hist',
        'device': 'cuda:0',
        'seed': 0,
        'early_stopping_rounds' : 50
    }
    
    model = XGBRegressor(**param)
    
    eval_set = [(x_train, y_train), (x_valid, y_valid)]  # 학습 데이터와 검증 데이터 설정
    model.fit(x_train, y_train, 
              eval_set=eval_set,  # eval_set 사용
              verbose=False)
    
    preds = model.predict(x_valid)
    mse = mean_squared_error(y_valid, preds)
    return mse

# Optuna 스터디 생성
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=1000)

print("Best parameters:", study.best_params)
print("Best MSE:", study.best_value)
# Out:
# [I 2024-11-07 09:51:55,445] A new study created in memory with name: no-name-3650d1af-87e3-49de-8dad-86221652b0c5
# [I 2024-11-07 09:51:55,659] Trial 0 finished with value: 1298.9305500330045 and parameters: {'n_estimators': 288, 'learning_rate': 0.28931295334890517, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.40563878941448395, 'subsample': 0.6156475762151309}. Best is trial 0 with value: 1298.9305500330045.
# [I 2024-11-07 09:51:55,851] Trial 1 finished with value: 1306.091970727038 and parameters: {'n_estimators': 266, 'learning_rate': 0.27700753169122183, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.36554871577978043, 'subsample': 0.8056987474193904}. Best is trial 0 with value: 1298.9305500330045.
# [I 2024-11-07 09:51:56,032] Trial 2 finished with value: 1213.5392357943922 and parameters: {'n_estimators': 518, 'learning_rate': 0.13060172723730792, 'max_depth': 4, 'min_child_weight': 1, 'colsample_bytree': 0.6738462950192952, 'subsample': 0.8470265267920358}. Best is trial 2 with value: 1213.5392357943922.
# [I 2024-11-07 09:51:56,215] Trial 3 finished with value: 1249.929560527675 and parameters: {'n_estimators': 495, 'learning_rate': 0.14854918806096928, 'max_depth': 3, 'min_child_weight': 7, 'colsample_bytree': 0.495768849542467, 'subsample': 0.600824665694287}. Best is trial 2 with value: 1213.5392357943922.
# [I 2024-11-07 09:51:56,550] Trial 4 finished with value: 1231.0977049026558 and parameters: {'n_estimators': 604, 'learning_rate': 0.20082666451697181, 'max_depth': 9, 'min_child_weight': 10, 'colsample_bytree': 0.6168491267291413, 'subsample': 0.9600135254205004}. Best is trial 2 with value: 1213.5392357943922.
# [I 2024-11-07 09:51:56,773] Trial 5 finished with value: 1328.2016224729055 and parameters: {'n_estimators': 331, 'learning_rate': 0.26830456856631135, 'max_depth': 9, 'min_child_weight': 9, 'colsample_bytree': 0.7134475163112668, 'subsample': 0.7838393640810666}. Best is trial 2 with value: 1213.5392357943922.
# [I 2024-11-07 09:51:57,134] Trial 6 finished with value: 1154.5169643949216 and parameters: {'n_estimators': 286, 'learning_rate': 0.06118033338587755, 'max_depth': 4, 'min_child_weight': 8, 'colsample_bytree': 0.9392500751507082, 'subsample': 0.9455298794896227}. Best is trial 6 with value: 1154.5169643949216.
# [I 2024-11-07 09:51:57,438] Trial 7 finished with value: 1325.0928526088435 and parameters: {'n_estimators': 980, 'learning_rate': 0.28028315105486856, 'max_depth': 10, 'min_child_weight': 9, 'colsample_bytree': 0.5420620037248121, 'subsample': 0.6374339825870412}. Best is trial 6 with value: 1154.5169643949216.
# [I 2024-11-07 09:51:58,399] Trial 8 finished with value: 1268.133258911253 and parameters: {'n_estimators': 294, 'learning_rate': 0.07697840716051339, 'max_depth': 10, 'min_child_weight': 10, 'colsample_bytree': 0.37786003628441867, 'subsample': 0.8320750201849332}. Best is trial 6 with value: 1154.5169643949216.
# [I 2024-11-07 09:51:59,117] Trial 9 finished with value: 1278.599477897589 and parameters: {'n_estimators': 460, 'learning_rate': 0.06613390480241302, 'max_depth': 10, 'min_child_weight': 8, 'colsample_bytree': 0.36667044731033116, 'subsample': 0.7402535318071439}. Best is trial 6 with value: 1154.5169643949216.
# [I 2024-11-07 09:51:59,551] Trial 10 finished with value: 1304.2220358647028 and parameters: {'n_estimators': 119, 'learning_rate': 0.018640775833852624, 'max_depth': 7, 'min_child_weight': 4, 'colsample_bytree': 0.9877979878656661, 'subsample': 0.9860078001647512}. Best is trial 6 with value: 1154.5169643949216.
# [I 2024-11-07 09:51:59,924] Trial 11 finished with value: 1202.7371064242238 and parameters: {'n_estimators': 708, 'learning_rate': 0.13311691708130396, 'max_depth': 5, 'min_child_weight': 1, 'colsample_bytree': 0.8481199964765265, 'subsample': 0.8961748207179038}. Best is trial 6 with value: 1154.5169643949216.
# [I 2024-11-07 09:52:00,391] Trial 12 finished with value: 1216.4131163858053 and parameters: {'n_estimators': 724, 'learning_rate': 0.09558460928660273, 'max_depth': 5, 'min_child_weight': 4, 'colsample_bytree': 0.9197596509816255, 'subsample': 0.8875781970411981}. Best is trial 6 with value: 1154.5169643949216.
# [I 2024-11-07 09:52:02,056] Trial 13 finished with value: 1192.7008747734826 and parameters: {'n_estimators': 827, 'learning_rate': 0.011734865004100058, 'max_depth': 6, 'min_child_weight': 2, 'colsample_bytree': 0.8240652746549098, 'subsample': 0.9189288793362557}. Best is trial 6 with value: 1154.5169643949216.
# [I 2024-11-07 09:52:03,527] Trial 14 finished with value: 1190.26057285311 and parameters: {'n_estimators': 958, 'learning_rate': 0.012409261704239671, 'max_depth': 7, 'min_child_weight': 5, 'colsample_bytree': 0.8091015013443551, 'subsample': 0.7242085471821047}. Best is trial 6 with value: 1154.5169643949216.
# [I 2024-11-07 09:52:04,255] Trial 15 finished with value: 1155.45568315432 and parameters: {'n_estimators': 959, 'learning_rate': 0.045850827147088505, 'max_depth': 7, 'min_child_weight': 6, 'colsample_bytree': 0.7895802258198291, 'subsample': 0.7014433910775778}. Best is trial 6 with value: 1154.5169643949216.
# [I 2024-11-07 09:52:04,817] Trial 16 finished with value: 1159.8698387041475 and parameters: {'n_estimators': 407, 'learning_rate': 0.057745686176529504, 'max_depth': 8, 'min_child_weight': 6, 'colsample_bytree': 0.9862982758884788, 'subsample': 0.5093471470447197}. Best is trial 6 with value: 1154.5169643949216.
# [I 2024-11-07 09:52:05,032] Trial 17 finished with value: 1221.9502841351969 and parameters: {'n_estimators': 123, 'learning_rate': 0.19491465280985923, 'max_depth': 3, 'min_child_weight': 6, 'colsample_bytree': 0.7445019760486372, 'subsample': 0.6934291184449747}. Best is trial 6 with value: 1154.5169643949216.
# [I 2024-11-07 09:52:05,664] Trial 18 finished with value: 1131.7130439547861 and parameters: {'n_estimators': 628, 'learning_rate': 0.044938275439912065, 'max_depth': 8, 'min_child_weight': 7, 'colsample_bytree': 0.8960190256358946, 'subsample': 0.6696971049503663}. Best is trial 18 with value: 1131.7130439547861.
# [I 2024-11-07 09:52:06,272] Trial 19 finished with value: 1151.5914662391726 and parameters: {'n_estimators': 614, 'learning_rate': 0.1046157336613995, 'max_depth': 8, 'min_child_weight': 8, 'colsample_bytree': 0.90347873300591, 'subsample': 0.5511074637304161}. Best is trial 18 with value: 1131.7130439547861.
# [I 2024-11-07 09:52:07,042] Trial 20 finished with value: 1250.5195915412867 and parameters: {'n_estimators': 624, 'learning_rate': 0.11120713152695498, 'max_depth': 8, 'min_child_weight': 7, 'colsample_bytree': 0.8866124950124279, 'subsample': 0.5038403174034556}. Best is trial 18 with value: 1131.7130439547861.
# [I 2024-11-07 09:52:07,644] Trial 21 finished with value: 1192.1434088656683 and parameters: {'n_estimators': 713, 'learning_rate': 0.0910489020363823, 'max_depth': 8, 'min_child_weight': 8, 'colsample_bytree': 0.9197820031797808, 'subsample': 0.5583152357302635}. Best is trial 18 with value: 1131.7130439547861.
# [I 2024-11-07 09:52:08,489] Trial 22 finished with value: 1219.9676343218755 and parameters: {'n_estimators': 605, 'learning_rate': 0.04970323753074391, 'max_depth': 9, 'min_child_weight': 7, 'colsample_bytree': 0.9970970340976629, 'subsample': 0.6562300783966459}. Best is trial 18 with value: 1131.7130439547861.
# [I 2024-11-07 09:52:08,981] Trial 23 finished with value: 1199.1078953294173 and parameters: {'n_estimators': 794, 'learning_rate': 0.1818651332626263, 'max_depth': 8, 'min_child_weight': 9, 'colsample_bytree': 0.9031503792677412, 'subsample': 0.5747246852198664}. Best is trial 18 with value: 1131.7130439547861.
# [I 2024-11-07 09:52:09,594] Trial 24 finished with value: 1252.1051879965423 and parameters: {'n_estimators': 567, 'learning_rate': 0.11124391928830643, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.8659398133627412, 'subsample': 0.6718816854349541}. Best is trial 18 with value: 1131.7130439547861.
# [I 2024-11-07 09:52:10,518] Trial 25 finished with value: 1178.5297951072507 and parameters: {'n_estimators': 422, 'learning_rate': 0.034677072455906635, 'max_depth': 5, 'min_child_weight': 5, 'colsample_bytree': 0.7720108495135953, 'subsample': 0.5408235898159874}. Best is trial 18 with value: 1131.7130439547861.
# [I 2024-11-07 09:52:11,335] Trial 26 finished with value: 1167.653414376734 and parameters: {'n_estimators': 223, 'learning_rate': 0.08019835970165214, 'max_depth': 9, 'min_child_weight': 7, 'colsample_bytree': 0.9379925618483858, 'subsample': 0.7676062539829672}. Best is trial 18 with value: 1131.7130439547861.
# [I 2024-11-07 09:52:11,974] Trial 27 finished with value: 1150.5875029305294 and parameters: {'n_estimators': 389, 'learning_rate': 0.1102152799826153, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.6323187673998967, 'subsample': 0.5768829228917802}. Best is trial 18 with value: 1131.7130439547861.
# [I 2024-11-07 09:52:12,541] Trial 28 finished with value: 1336.7282562632258 and parameters: {'n_estimators': 358, 'learning_rate': 0.16580697566664773, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.593134859572056, 'subsample': 0.596348858061331}. Best is trial 18 with value: 1131.7130439547861.
# [I 2024-11-07 09:52:13,068] Trial 29 finished with value: 1356.0410574726857 and parameters: {'n_estimators': 645, 'learning_rate': 0.2188332612855654, 'max_depth': 8, 'min_child_weight': 8, 'colsample_bytree': 0.48271457873894713, 'subsample': 0.6245785274470514}. Best is trial 18 with value: 1131.7130439547861.
# [I 2024-11-07 09:52:13,702] Trial 30 finished with value: 1126.2254297885488 and parameters: {'n_estimators': 844, 'learning_rate': 0.1052838984883387, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.6882358485046876, 'subsample': 0.5427270900867684}. Best is trial 30 with value: 1126.2254297885488.
# [I 2024-11-07 09:52:14,291] Trial 31 finished with value: 1128.6804196951048 and parameters: {'n_estimators': 877, 'learning_rate': 0.1105609948296328, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.6988906525237446, 'subsample': 0.5329014997341602}. Best is trial 30 with value: 1126.2254297885488.
# [I 2024-11-07 09:52:14,847] Trial 32 finished with value: 1173.7349228471796 and parameters: {'n_estimators': 833, 'learning_rate': 0.1365743068705122, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.6687037277385404, 'subsample': 0.5304532348101773}. Best is trial 30 with value: 1126.2254297885488.
# [I 2024-11-07 09:52:15,552] Trial 33 finished with value: 1120.0142369991554 and parameters: {'n_estimators': 863, 'learning_rate': 0.11864502216348302, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.7176462424471064, 'subsample': 0.5797428156465227}. Best is trial 33 with value: 1120.0142369991554.
# [I 2024-11-07 09:52:16,134] Trial 34 finished with value: 1077.7194956964427 and parameters: {'n_estimators': 895, 'learning_rate': 0.14732699320501513, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.7083925774366985, 'subsample': 0.6040592595740041}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:16,664] Trial 35 finished with value: 1244.9837627518502 and parameters: {'n_estimators': 920, 'learning_rate': 0.15952934269936847, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7143781832811202, 'subsample': 0.6034859383795663}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:17,294] Trial 36 finished with value: 1111.9776362339142 and parameters: {'n_estimators': 886, 'learning_rate': 0.14348145888708802, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7016626845708307, 'subsample': 0.5239976794422243}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:17,778] Trial 37 finished with value: 1166.3043170435099 and parameters: {'n_estimators': 899, 'learning_rate': 0.14664575346381864, 'max_depth': 5, 'min_child_weight': 10, 'colsample_bytree': 0.5890274281768659, 'subsample': 0.5841395263072394}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:18,312] Trial 38 finished with value: 1249.4927113038582 and parameters: {'n_estimators': 775, 'learning_rate': 0.23316363859539033, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7598805793368931, 'subsample': 0.6248362887499853}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:18,847] Trial 39 finished with value: 1278.0364792573625 and parameters: {'n_estimators': 859, 'learning_rate': 0.18064934849472314, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.677552283984899, 'subsample': 0.5167142158977217}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:19,339] Trial 40 finished with value: 1233.7086123973138 and parameters: {'n_estimators': 778, 'learning_rate': 0.17117415405749314, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7357136866101766, 'subsample': 0.5549194363555097}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:19,987] Trial 41 finished with value: 1250.6048290374467 and parameters: {'n_estimators': 896, 'learning_rate': 0.13242666062865502, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.6692370467177391, 'subsample': 0.5281962620189469}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:20,606] Trial 42 finished with value: 1177.195612614472 and parameters: {'n_estimators': 866, 'learning_rate': 0.12317757618992103, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.6925964773592984, 'subsample': 0.5019941747296557}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:21,143] Trial 43 finished with value: 1239.5654468822097 and parameters: {'n_estimators': 931, 'learning_rate': 0.14803581348757994, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.555050051209993, 'subsample': 0.5657315047199166}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:21,602] Trial 44 finished with value: 1229.0832251430088 and parameters: {'n_estimators': 992, 'learning_rate': 0.12194523070614227, 'max_depth': 5, 'min_child_weight': 10, 'colsample_bytree': 0.6187363264305126, 'subsample': 0.5995951283561743}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:22,206] Trial 45 finished with value: 1166.2392529468577 and parameters: {'n_estimators': 819, 'learning_rate': 0.07884742383935414, 'max_depth': 7, 'min_child_weight': 8, 'colsample_bytree': 0.7182863860924799, 'subsample': 0.6463692019551939}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:22,638] Trial 46 finished with value: 1163.0663300787014 and parameters: {'n_estimators': 748, 'learning_rate': 0.09353801703285813, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.6358521041547727, 'subsample': 0.5381058746736335}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:23,187] Trial 47 finished with value: 1199.746744549658 and parameters: {'n_estimators': 865, 'learning_rate': 0.14614759113476242, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.6974826650660196, 'subsample': 0.6169509390888901}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:23,458] Trial 48 finished with value: 1167.534007326376 and parameters: {'n_estimators': 674, 'learning_rate': 0.12002555528608928, 'max_depth': 5, 'min_child_weight': 8, 'colsample_bytree': 0.7857249493265392, 'subsample': 0.8205265999779316}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:23,708] Trial 49 finished with value: 1346.9727304697408 and parameters: {'n_estimators': 921, 'learning_rate': 0.1409098780188355, 'max_depth': 7, 'min_child_weight': 3, 'colsample_bytree': 0.8206518776464298, 'subsample': 0.5268179392910386}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:23,927] Trial 50 finished with value: 1224.9171958343102 and parameters: {'n_estimators': 954, 'learning_rate': 0.1576851914937995, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.5476752716753823, 'subsample': 0.5719374808552202}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:24,718] Trial 51 finished with value: 1218.6976005892188 and parameters: {'n_estimators': 876, 'learning_rate': 0.030113074200648765, 'max_depth': 8, 'min_child_weight': 7, 'colsample_bytree': 0.4244827100858487, 'subsample': 0.6825374854070547}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:25,109] Trial 52 finished with value: 1175.5864162488615 and parameters: {'n_estimators': 506, 'learning_rate': 0.07292054359054609, 'max_depth': 7, 'min_child_weight': 8, 'colsample_bytree': 0.7368149117814816, 'subsample': 0.6641137497376799}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:25,533] Trial 53 finished with value: 1274.7091365091799 and parameters: {'n_estimators': 759, 'learning_rate': 0.08498193138033985, 'max_depth': 9, 'min_child_weight': 7, 'colsample_bytree': 0.649964451984414, 'subsample': 0.6372883635029832}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:26,279] Trial 54 finished with value: 1221.1923133274013 and parameters: {'n_estimators': 809, 'learning_rate': 0.10082517255219281, 'max_depth': 8, 'min_child_weight': 9, 'colsample_bytree': 0.5887978066421082, 'subsample': 0.5497013867202872}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:26,728] Trial 55 finished with value: 1178.5602331088662 and parameters: {'n_estimators': 839, 'learning_rate': 0.0645285998352745, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.8502803246937862, 'subsample': 0.7146385190776747}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:27,056] Trial 56 finished with value: 1216.6833003766014 and parameters: {'n_estimators': 997, 'learning_rate': 0.12637362408683087, 'max_depth': 9, 'min_child_weight': 8, 'colsample_bytree': 0.7968941678678264, 'subsample': 0.5925433979485325}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:27,341] Trial 57 finished with value: 1269.8508316484665 and parameters: {'n_estimators': 696, 'learning_rate': 0.17407820142970817, 'max_depth': 8, 'min_child_weight': 10, 'colsample_bytree': 0.7660706347910018, 'subsample': 0.6050828469120905}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:27,678] Trial 58 finished with value: 1310.9011923236653 and parameters: {'n_estimators': 562, 'learning_rate': 0.19734319527140598, 'max_depth': 7, 'min_child_weight': 6, 'colsample_bytree': 0.3159348966566356, 'subsample': 0.5607596840970314}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:28,122] Trial 59 finished with value: 1141.5547126219574 and parameters: {'n_estimators': 737, 'learning_rate': 0.11570464277787146, 'max_depth': 6, 'min_child_weight': 7, 'colsample_bytree': 0.7017721754318084, 'subsample': 0.5173243345289511}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:28,781] Trial 60 finished with value: 1216.934141477893 and parameters: {'n_estimators': 894, 'learning_rate': 0.050165986213143075, 'max_depth': 8, 'min_child_weight': 9, 'colsample_bytree': 0.5106358618833737, 'subsample': 0.7342659016570752}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:29,097] Trial 61 finished with value: 1204.6255964041306 and parameters: {'n_estimators': 728, 'learning_rate': 0.11379802229511383, 'max_depth': 6, 'min_child_weight': 5, 'colsample_bytree': 0.7110010489129326, 'subsample': 0.5167250106270994}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:29,359] Trial 62 finished with value: 1164.7929853978053 and parameters: {'n_estimators': 795, 'learning_rate': 0.13391204201815277, 'max_depth': 6, 'min_child_weight': 7, 'colsample_bytree': 0.6565578049772475, 'subsample': 0.5430045945790093}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:29,624] Trial 63 finished with value: 1182.715442764736 and parameters: {'n_estimators': 675, 'learning_rate': 0.1013138888659697, 'max_depth': 5, 'min_child_weight': 6, 'colsample_bytree': 0.6933614040185105, 'subsample': 0.5166058619535792}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:30,076] Trial 64 finished with value: 1183.1114723421406 and parameters: {'n_estimators': 960, 'learning_rate': 0.1550695644605285, 'max_depth': 7, 'min_child_weight': 8, 'colsample_bytree': 0.962726371325016, 'subsample': 0.5802728101354018}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:30,341] Trial 65 finished with value: 1126.587254320976 and parameters: {'n_estimators': 849, 'learning_rate': 0.114933115001619, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.7464460484962626, 'subsample': 0.539829766852954}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:30,698] Trial 66 finished with value: 1131.3364155502227 and parameters: {'n_estimators': 916, 'learning_rate': 0.09100678155681743, 'max_depth': 5, 'min_child_weight': 8, 'colsample_bytree': 0.7477575943302857, 'subsample': 0.5654082123372237}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:31,024] Trial 67 finished with value: 1117.9904356473967 and parameters: {'n_estimators': 934, 'learning_rate': 0.08894232583046041, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.738388262473578, 'subsample': 0.8724426891918231}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:31,345] Trial 68 finished with value: 1155.0251847618956 and parameters: {'n_estimators': 841, 'learning_rate': 0.1049155170695803, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.7817132430742484, 'subsample': 0.7889365579622335}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:31,710] Trial 69 finished with value: 1191.3145081027496 and parameters: {'n_estimators': 945, 'learning_rate': 0.08705764603129652, 'max_depth': 3, 'min_child_weight': 9, 'colsample_bytree': 0.7262169083462358, 'subsample': 0.8545449333766887}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:32,056] Trial 70 finished with value: 1162.9642365803033 and parameters: {'n_estimators': 884, 'learning_rate': 0.07431882384072043, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.8146097487649246, 'subsample': 0.9833509347578873}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:32,355] Trial 71 finished with value: 1177.4593855596743 and parameters: {'n_estimators': 920, 'learning_rate': 0.0956814096971889, 'max_depth': 5, 'min_child_weight': 8, 'colsample_bytree': 0.7506448889642935, 'subsample': 0.929977690620485}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:32,629] Trial 72 finished with value: 1111.6050777784824 and parameters: {'n_estimators': 907, 'learning_rate': 0.1274263024891979, 'max_depth': 5, 'min_child_weight': 9, 'colsample_bytree': 0.7499150271160349, 'subsample': 0.8942622551777286}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:32,928] Trial 73 finished with value: 1181.018409313869 and parameters: {'n_estimators': 973, 'learning_rate': 0.1402386217012206, 'max_depth': 3, 'min_child_weight': 9, 'colsample_bytree': 0.6882958664386111, 'subsample': 0.8768996664166397}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:33,193] Trial 74 finished with value: 1135.8616627932342 and parameters: {'n_estimators': 852, 'learning_rate': 0.1271917665644192, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.6564000444985701, 'subsample': 0.9054101420516671}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:33,586] Trial 75 finished with value: 1193.9347465726723 and parameters: {'n_estimators': 812, 'learning_rate': 0.10740559068937262, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.7334762700788784, 'subsample': 0.8515637053598953}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:33,871] Trial 76 finished with value: 1185.6730848688537 and parameters: {'n_estimators': 902, 'learning_rate': 0.11528700965421232, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7627388524287423, 'subsample': 0.9591450325842154}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:34,105] Trial 77 finished with value: 1205.2457053522558 and parameters: {'n_estimators': 935, 'learning_rate': 0.13221145568208661, 'max_depth': 5, 'min_child_weight': 9, 'colsample_bytree': 0.8387834499854618, 'subsample': 0.8674356133527291}. Best is trial 34 with value: 1077.7194956964427.
# [I 2024-11-07 09:52:34,409] Trial 78 finished with value: 1074.8634183542222 and parameters: {'n_estimators': 973, 'learning_rate': 0.14968710588628523, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.7998957224076872, 'subsample': 0.7629996573651106}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:34,647] Trial 79 finished with value: 1182.4873756673355 and parameters: {'n_estimators': 974, 'learning_rate': 0.16347029938731236, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.8021662539125303, 'subsample': 0.7993096545823544}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:34,823] Trial 80 finished with value: 1174.3988241110396 and parameters: {'n_estimators': 942, 'learning_rate': 0.29780071855873436, 'max_depth': 5, 'min_child_weight': 9, 'colsample_bytree': 0.770729102708612, 'subsample': 0.9082997329601947}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:35,096] Trial 81 finished with value: 1166.9752952958756 and parameters: {'n_estimators': 882, 'learning_rate': 0.14994183952648973, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.7111917111867413, 'subsample': 0.7538876824458449}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:35,342] Trial 82 finished with value: 1243.3757203527396 and parameters: {'n_estimators': 859, 'learning_rate': 0.12074065072178386, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.6763002143390676, 'subsample': 0.5320598729797891}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:35,600] Trial 83 finished with value: 1177.5780444679324 and parameters: {'n_estimators': 908, 'learning_rate': 0.14075513767874992, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.7265088693233288, 'subsample': 0.8395275721228161}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:35,905] Trial 84 finished with value: 1159.5582521416557 and parameters: {'n_estimators': 789, 'learning_rate': 0.09955969350193533, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.6363098733446787, 'subsample': 0.5010650463667707}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:36,139] Trial 85 finished with value: 1291.222890634613 and parameters: {'n_estimators': 830, 'learning_rate': 0.2618750182493988, 'max_depth': 7, 'min_child_weight': 8, 'colsample_bytree': 0.7431956551546718, 'subsample': 0.9392140174536058}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:36,442] Trial 86 finished with value: 1148.867747561264 and parameters: {'n_estimators': 998, 'learning_rate': 0.12872431198148238, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.7840447959998261, 'subsample': 0.5493982670789299}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:36,649] Trial 87 finished with value: 1178.1309239569566 and parameters: {'n_estimators': 881, 'learning_rate': 0.18694466080072158, 'max_depth': 5, 'min_child_weight': 4, 'colsample_bytree': 0.616957408688142, 'subsample': 0.7720417687942902}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:36,935] Trial 88 finished with value: 1300.3280356361054 and parameters: {'n_estimators': 975, 'learning_rate': 0.15190273442452368, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.8685637184585369, 'subsample': 0.8282614295878512}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:37,241] Trial 89 finished with value: 1178.6124935675007 and parameters: {'n_estimators': 762, 'learning_rate': 0.14305456782354, 'max_depth': 6, 'min_child_weight': 2, 'colsample_bytree': 0.6709173072135481, 'subsample': 0.8916970293312426}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:37,698] Trial 90 finished with value: 1174.3662299701548 and parameters: {'n_estimators': 950, 'learning_rate': 0.1631789466236917, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.8293904392680013, 'subsample': 0.539788000983245}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:38,236] Trial 91 finished with value: 1157.99486364879 and parameters: {'n_estimators': 911, 'learning_rate': 0.0888529611950815, 'max_depth': 5, 'min_child_weight': 8, 'colsample_bytree': 0.7498140561104571, 'subsample': 0.564841673536816}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:38,585] Trial 92 finished with value: 1164.5449016909433 and parameters: {'n_estimators': 929, 'learning_rate': 0.10935259211877821, 'max_depth': 5, 'min_child_weight': 8, 'colsample_bytree': 0.7119469466115393, 'subsample': 0.5813279049529819}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:38,922] Trial 93 finished with value: 1195.3916206004205 and parameters: {'n_estimators': 863, 'learning_rate': 0.08210044326952255, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.7508037613882642, 'subsample': 0.5868869099130529}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:39,279] Trial 94 finished with value: 1235.334030377279 and parameters: {'n_estimators': 897, 'learning_rate': 0.09373321358915276, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.7257306670381736, 'subsample': 0.5555740256738019}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:39,522] Trial 95 finished with value: 1214.5469642486212 and parameters: {'n_estimators': 168, 'learning_rate': 0.12015310796835482, 'max_depth': 5, 'min_child_weight': 9, 'colsample_bytree': 0.6866547368733457, 'subsample': 0.5263440513046319}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:39,946] Trial 96 finished with value: 1125.6816220425367 and parameters: {'n_estimators': 839, 'learning_rate': 0.05858454692690211, 'max_depth': 7, 'min_child_weight': 8, 'colsample_bytree': 0.7032468195102708, 'subsample': 0.5716398472566254}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:40,424] Trial 97 finished with value: 1163.3320870971047 and parameters: {'n_estimators': 826, 'learning_rate': 0.05575305676616108, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.7010831587447834, 'subsample': 0.6191371873705355}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:40,845] Trial 98 finished with value: 1134.073587546711 and parameters: {'n_estimators': 458, 'learning_rate': 0.13472582739548808, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.6598343802923026, 'subsample': 0.6076165006586826}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:41,502] Trial 99 finished with value: 1219.434992068401 and parameters: {'n_estimators': 845, 'learning_rate': 0.03726750397456864, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.7717593597850627, 'subsample': 0.5726881690359222}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:41,826] Trial 100 finished with value: 1175.9312851682482 and parameters: {'n_estimators': 814, 'learning_rate': 0.07275350560054136, 'max_depth': 7, 'min_child_weight': 8, 'colsample_bytree': 0.600681408801285, 'subsample': 0.5122174655810428}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:42,114] Trial 101 finished with value: 1137.6943670235898 and parameters: {'n_estimators': 915, 'learning_rate': 0.11648065211220847, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.7994200116719338, 'subsample': 0.6339813878225231}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:42,583] Trial 102 finished with value: 1142.7658136336627 and parameters: {'n_estimators': 881, 'learning_rate': 0.06722235754418678, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.7415374350260154, 'subsample': 0.5703391973210249}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:42,914] Trial 103 finished with value: 1187.8737123879243 and parameters: {'n_estimators': 960, 'learning_rate': 0.10582253696045338, 'max_depth': 3, 'min_child_weight': 7, 'colsample_bytree': 0.7588006431306693, 'subsample': 0.5431427143522918}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:43,322] Trial 104 finished with value: 1147.2368012828663 and parameters: {'n_estimators': 801, 'learning_rate': 0.09746554179181208, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.6865059849272442, 'subsample': 0.5591033210110705}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:43,612] Trial 105 finished with value: 1205.162736893921 and parameters: {'n_estimators': 870, 'learning_rate': 0.12931667348594378, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.7251898337051281, 'subsample': 0.5252484530037709}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:43,926] Trial 106 finished with value: 1199.8282700251493 and parameters: {'n_estimators': 935, 'learning_rate': 0.17262699124199374, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.642349425165331, 'subsample': 0.5967202008140262}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:44,241] Trial 107 finished with value: 1208.2584057561571 and parameters: {'n_estimators': 851, 'learning_rate': 0.12295885867899667, 'max_depth': 7, 'min_child_weight': 8, 'colsample_bytree': 0.7108472660797164, 'subsample': 0.5468931460148795}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:44,526] Trial 108 finished with value: 1160.2868709485854 and parameters: {'n_estimators': 982, 'learning_rate': 0.13890965341282493, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7804545809854885, 'subsample': 0.8123791010979664}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:44,898] Trial 109 finished with value: 1195.3525112572129 and parameters: {'n_estimators': 909, 'learning_rate': 0.09010473819468898, 'max_depth': 7, 'min_child_weight': 7, 'colsample_bytree': 0.7560148923814249, 'subsample': 0.7028807856167283}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:45,151] Trial 110 finished with value: 1211.4312499837197 and parameters: {'n_estimators': 888, 'learning_rate': 0.1029367076675523, 'max_depth': 5, 'min_child_weight': 9, 'colsample_bytree': 0.679347350222645, 'subsample': 0.8774867122526164}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:45,633] Trial 111 finished with value: 1217.7907818370645 and parameters: {'n_estimators': 582, 'learning_rate': 0.1111553097290134, 'max_depth': 8, 'min_child_weight': 8, 'colsample_bytree': 0.734489350522095, 'subsample': 0.6458066096925517}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:46,271] Trial 112 finished with value: 1178.8220718867997 and parameters: {'n_estimators': 780, 'learning_rate': 0.04931666218179889, 'max_depth': 10, 'min_child_weight': 7, 'colsample_bytree': 0.7005337447473584, 'subsample': 0.5321858764652093}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:47,223] Trial 113 finished with value: 1218.6951619244367 and parameters: {'n_estimators': 294, 'learning_rate': 0.017049479555589553, 'max_depth': 8, 'min_child_weight': 6, 'colsample_bytree': 0.8728644991237572, 'subsample': 0.6776963837612453}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:47,774] Trial 114 finished with value: 1230.839949460346 and parameters: {'n_estimators': 538, 'learning_rate': 0.04174034266064702, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.6652347803292085, 'subsample': 0.5891085773849454}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:48,685] Trial 115 finished with value: 1159.084844148024 and parameters: {'n_estimators': 833, 'learning_rate': 0.031924853525141454, 'max_depth': 8, 'min_child_weight': 9, 'colsample_bytree': 0.8920151420284249, 'subsample': 0.5598083663999202}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:49,092] Trial 116 finished with value: 1260.1111265904324 and parameters: {'n_estimators': 928, 'learning_rate': 0.06638939401123424, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.9486945691492645, 'subsample': 0.918317649134228}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:49,390] Trial 117 finished with value: 1257.337261901131 and parameters: {'n_estimators': 954, 'learning_rate': 0.1553452980343354, 'max_depth': 9, 'min_child_weight': 10, 'colsample_bytree': 0.7124502435151132, 'subsample': 0.5742632446526672}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:49,871] Trial 118 finished with value: 1135.9141328599524 and parameters: {'n_estimators': 872, 'learning_rate': 0.0548005442769055, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.6976956230144732, 'subsample': 0.6061773655889894}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:50,142] Trial 119 finished with value: 1215.3939220299283 and parameters: {'n_estimators': 895, 'learning_rate': 0.1453591128566706, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.9229498819025115, 'subsample': 0.6922961964398212}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:50,816] Trial 120 finished with value: 1169.5662623915227 and parameters: {'n_estimators': 857, 'learning_rate': 0.021183146945913923, 'max_depth': 5, 'min_child_weight': 7, 'colsample_bytree': 0.8098121058404232, 'subsample': 0.6614252151600579}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:51,110] Trial 121 finished with value: 1243.9380450930323 and parameters: {'n_estimators': 470, 'learning_rate': 0.13179702109242042, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.6569848076184259, 'subsample': 0.6102044850340179}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:51,434] Trial 122 finished with value: 1196.513762288274 and parameters: {'n_estimators': 380, 'learning_rate': 0.12621287073878287, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.6273581946750147, 'subsample': 0.6318914442720092}. Best is trial 78 with value: 1074.8634183542222.
# [I 2024-11-07 09:52:51,855] Trial 123 finished with value: 1051.2679791197802 and parameters: {'n_estimators': 644, 'learning_rate': 0.13841787640025643, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.7394650551278316, 'subsample': 0.6488107135886416}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:52,226] Trial 124 finished with value: 1179.7889468418791 and parameters: {'n_estimators': 644, 'learning_rate': 0.14945373526830608, 'max_depth': 8, 'min_child_weight': 10, 'colsample_bytree': 0.7342373320197813, 'subsample': 0.5376036870726549}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:52,584] Trial 125 finished with value: 1185.644386555294 and parameters: {'n_estimators': 707, 'learning_rate': 0.11716067343772005, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.7225275656699701, 'subsample': 0.6515895591973458}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:53,187] Trial 126 finished with value: 1239.2325057949788 and parameters: {'n_estimators': 589, 'learning_rate': 0.136385866721615, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.764926703838628, 'subsample': 0.7221979292607379}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:53,669] Trial 127 finished with value: 1209.1110865143623 and parameters: {'n_estimators': 665, 'learning_rate': 0.06046698390365563, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7464595775885435, 'subsample': 0.554206844729981}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:53,945] Trial 128 finished with value: 1246.6743794532986 and parameters: {'n_estimators': 629, 'learning_rate': 0.15969596728136667, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.7896026247020151, 'subsample': 0.7415539483589658}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:54,267] Trial 129 finished with value: 1253.7370654273295 and parameters: {'n_estimators': 919, 'learning_rate': 0.11083151651247791, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.6861694252161055, 'subsample': 0.5847205807031159}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:54,551] Trial 130 finished with value: 1239.2889222773745 and parameters: {'n_estimators': 966, 'learning_rate': 0.1683471939252884, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.8506556509411206, 'subsample': 0.5082834302444545}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:54,834] Trial 131 finished with value: 1201.8961439846948 and parameters: {'n_estimators': 353, 'learning_rate': 0.13757684596965497, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.6639841104087209, 'subsample': 0.6169172789352929}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:55,152] Trial 132 finished with value: 1209.6810494899712 and parameters: {'n_estimators': 510, 'learning_rate': 0.14541293082925674, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.705401519712233, 'subsample': 0.598090355236311}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:55,478] Trial 133 finished with value: 1257.6009958374611 and parameters: {'n_estimators': 940, 'learning_rate': 0.12424268872175756, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.6488105054341483, 'subsample': 0.5673173111791155}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:55,842] Trial 134 finished with value: 1194.9741101192624 and parameters: {'n_estimators': 409, 'learning_rate': 0.1331627364051697, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.721353446366412, 'subsample': 0.8615263990091774}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:56,274] Trial 135 finished with value: 1134.4240426149267 and parameters: {'n_estimators': 446, 'learning_rate': 0.0788719453418368, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.6817547958148015, 'subsample': 0.6233919055073723}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:56,651] Trial 136 finished with value: 1213.1340333088424 and parameters: {'n_estimators': 486, 'learning_rate': 0.09921925768384918, 'max_depth': 8, 'min_child_weight': 9, 'colsample_bytree': 0.7370398552082753, 'subsample': 0.9983156229224244}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:56,992] Trial 137 finished with value: 1168.0965571646595 and parameters: {'n_estimators': 900, 'learning_rate': 0.1516347603399894, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.6730425813322205, 'subsample': 0.5189173864137433}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:57,285] Trial 138 finished with value: 1273.8661175267578 and parameters: {'n_estimators': 841, 'learning_rate': 0.11788594240998057, 'max_depth': 3, 'min_child_weight': 9, 'colsample_bytree': 0.771020620478435, 'subsample': 0.6676870448936805}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:57,616] Trial 139 finished with value: 1142.4876670830363 and parameters: {'n_estimators': 812, 'learning_rate': 0.10695451906508015, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.6975271128418081, 'subsample': 0.9024730501155094}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:57,979] Trial 140 finished with value: 1242.9518979032387 and parameters: {'n_estimators': 867, 'learning_rate': 0.12675449062972094, 'max_depth': 7, 'min_child_weight': 8, 'colsample_bytree': 0.7515415316534889, 'subsample': 0.5493751467737883}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:58,552] Trial 141 finished with value: 1094.5680223170823 and parameters: {'n_estimators': 450, 'learning_rate': 0.0819165784639711, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.6797895024710839, 'subsample': 0.6279065137243917}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:58,878] Trial 142 finished with value: 1181.6909811550076 and parameters: {'n_estimators': 559, 'learning_rate': 0.09369761707722143, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7233063473246231, 'subsample': 0.6084783811690323}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:59,378] Trial 143 finished with value: 1110.6428497847169 and parameters: {'n_estimators': 888, 'learning_rate': 0.08497283906093905, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7126730650965385, 'subsample': 0.5787815456530393}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:52:59,703] Trial 144 finished with value: 1158.2442228771604 and parameters: {'n_estimators': 915, 'learning_rate': 0.08459996131976098, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7068760293194699, 'subsample': 0.5772300286712565}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:53:00,109] Trial 145 finished with value: 1182.3635649138446 and parameters: {'n_estimators': 887, 'learning_rate': 0.06982357811509354, 'max_depth': 5, 'min_child_weight': 10, 'colsample_bytree': 0.6931390869945586, 'subsample': 0.6278192962949091}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:53:00,396] Trial 146 finished with value: 1149.9223233710534 and parameters: {'n_estimators': 532, 'learning_rate': 0.07713899818061107, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.7383393408928153, 'subsample': 0.5896013895357136}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:53:00,670] Trial 147 finished with value: 1186.8452895273324 and parameters: {'n_estimators': 257, 'learning_rate': 0.08547268786860805, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.7216107742804919, 'subsample': 0.6390410561178976}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:53:00,976] Trial 148 finished with value: 1189.2525573110265 and parameters: {'n_estimators': 847, 'learning_rate': 0.09375714528161992, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.9723429878320288, 'subsample': 0.8836792022214627}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:53:01,572] Trial 149 finished with value: 1170.4851940401463 and parameters: {'n_estimators': 875, 'learning_rate': 0.04157794648949878, 'max_depth': 6, 'min_child_weight': 1, 'colsample_bytree': 0.7810852489967149, 'subsample': 0.5319713848151222}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:53:02,140] Trial 150 finished with value: 1117.0846955861584 and parameters: {'n_estimators': 824, 'learning_rate': 0.10168898764235833, 'max_depth': 5, 'min_child_weight': 10, 'colsample_bytree': 0.7571133181870315, 'subsample': 0.565425181697671}. Best is trial 123 with value: 1051.2679791197802.
# ...
# [I 2024-11-07 09:57:39,664] Trial 775 finished with value: 1148.9282298758417 and parameters: {'n_estimators': 706, 'learning_rate': 0.1045901194246567, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.8508405562312087, 'subsample': 0.5139380537504681}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:39,950] Trial 776 finished with value: 1151.7850188411055 and parameters: {'n_estimators': 665, 'learning_rate': 0.14472010016951914, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7895157535103638, 'subsample': 0.5998647797514722}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:40,297] Trial 777 finished with value: 1116.628514883881 and parameters: {'n_estimators': 607, 'learning_rate': 0.125453282864196, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.8219316276540036, 'subsample': 0.5437667585219167}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:40,696] Trial 778 finished with value: 1237.1187315608943 and parameters: {'n_estimators': 640, 'learning_rate': 0.10979347546059216, 'max_depth': 6, 'min_child_weight': 7, 'colsample_bytree': 0.7489179188717114, 'subsample': 0.5303046008111296}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:41,086] Trial 779 finished with value: 1144.108306936436 and parameters: {'n_estimators': 682, 'learning_rate': 0.09833912911372518, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.7340093324751022, 'subsample': 0.5404493000185158}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:41,392] Trial 780 finished with value: 1190.3897275513193 and parameters: {'n_estimators': 700, 'learning_rate': 0.1167129208947699, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.881489320960499, 'subsample': 0.510214741385888}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:41,733] Trial 781 finished with value: 1141.0662216683681 and parameters: {'n_estimators': 656, 'learning_rate': 0.1022292451179783, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7617571114815898, 'subsample': 0.5202782362265148}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:42,111] Trial 782 finished with value: 1159.3340808804733 and parameters: {'n_estimators': 675, 'learning_rate': 0.11190230248332642, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.7687821437580669, 'subsample': 0.5300699066434844}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:42,694] Trial 783 finished with value: 1147.7322283491098 and parameters: {'n_estimators': 632, 'learning_rate': 0.09666617065694612, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7450538133138576, 'subsample': 0.593224204470363}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:43,082] Trial 784 finished with value: 1160.6744781178863 and parameters: {'n_estimators': 653, 'learning_rate': 0.12147593286973933, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.7996661511508478, 'subsample': 0.5370490451531125}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:43,430] Trial 785 finished with value: 1192.7428897076454 and parameters: {'n_estimators': 986, 'learning_rate': 0.10584373785423129, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.820714708216067, 'subsample': 0.5088180016035222}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:43,699] Trial 786 finished with value: 1305.314558101191 and parameters: {'n_estimators': 623, 'learning_rate': 0.14177251587824907, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.34820522662325215, 'subsample': 0.5429802781210769}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:44,056] Trial 787 finished with value: 1134.3724352356523 and parameters: {'n_estimators': 692, 'learning_rate': 0.102902765270101, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.8358451350562852, 'subsample': 0.6300156446511194}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:44,409] Trial 788 finished with value: 1193.882548722846 and parameters: {'n_estimators': 745, 'learning_rate': 0.1317167803926978, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7846080055928323, 'subsample': 0.6119696631345982}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:44,786] Trial 789 finished with value: 1221.5905341340483 and parameters: {'n_estimators': 727, 'learning_rate': 0.11536530859548634, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7325081325651175, 'subsample': 0.5251100851465065}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:45,343] Trial 790 finished with value: 1124.2133778396217 and parameters: {'n_estimators': 666, 'learning_rate': 0.09457441297585963, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.775477640667718, 'subsample': 0.5435052451194702}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:45,722] Trial 791 finished with value: 1244.6452226599145 and parameters: {'n_estimators': 643, 'learning_rate': 0.11090928295508971, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.7493328125434429, 'subsample': 0.5002848985442598}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:46,105] Trial 792 finished with value: 1109.7014451270495 and parameters: {'n_estimators': 585, 'learning_rate': 0.12204970912971104, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.8056315908942501, 'subsample': 0.5181249959731288}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:46,405] Trial 793 finished with value: 1186.1528659576384 and parameters: {'n_estimators': 686, 'learning_rate': 0.09936795429911766, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7312278193198984, 'subsample': 0.5320833916005913}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:46,714] Trial 794 finished with value: 1171.9501084778717 and parameters: {'n_estimators': 972, 'learning_rate': 0.10827142431597729, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.8589305042502423, 'subsample': 0.5868799362398777}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:47,018] Trial 795 finished with value: 1161.1058648687613 and parameters: {'n_estimators': 1000, 'learning_rate': 0.11710225557127847, 'max_depth': 6, 'min_child_weight': 1, 'colsample_bytree': 0.7627432837155091, 'subsample': 0.7617548084904008}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:47,449] Trial 796 finished with value: 1186.1898945707485 and parameters: {'n_estimators': 598, 'learning_rate': 0.10330252612158378, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.7957052178683295, 'subsample': 0.543534678873263}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:47,694] Trial 797 finished with value: 1278.2122131372575 and parameters: {'n_estimators': 716, 'learning_rate': 0.20756520365701786, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7231768129377303, 'subsample': 0.5142522565909153}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:48,121] Trial 798 finished with value: 1137.607738736287 and parameters: {'n_estimators': 672, 'learning_rate': 0.09480651728258484, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.7555928264460671, 'subsample': 0.5305822956737488}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:48,537] Trial 799 finished with value: 1182.5815639607454 and parameters: {'n_estimators': 622, 'learning_rate': 0.11154456226089492, 'max_depth': 6, 'min_child_weight': 4, 'colsample_bytree': 0.7796148838058509, 'subsample': 0.5488869134569052}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:48,873] Trial 800 finished with value: 1123.1368372873403 and parameters: {'n_estimators': 659, 'learning_rate': 0.1054081260923502, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7372255200648254, 'subsample': 0.6406010842671925}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:49,251] Trial 801 finished with value: 1149.3056050729 and parameters: {'n_estimators': 648, 'learning_rate': 0.12951929656575134, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.6995935039785912, 'subsample': 0.5265937793861902}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:49,638] Trial 802 finished with value: 1160.9524580669786 and parameters: {'n_estimators': 702, 'learning_rate': 0.09898695455001572, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.7913088780154174, 'subsample': 0.5192896903801103}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:49,935] Trial 803 finished with value: 1143.7487943735462 and parameters: {'n_estimators': 639, 'learning_rate': 0.1494495085728156, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7679419724950161, 'subsample': 0.5368067401201796}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:50,392] Trial 804 finished with value: 1156.4708490837716 and parameters: {'n_estimators': 810, 'learning_rate': 0.1195404365861778, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.7196257449065562, 'subsample': 0.5104036991184979}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:50,831] Trial 805 finished with value: 1174.0209031635343 and parameters: {'n_estimators': 963, 'learning_rate': 0.09307424187774091, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7432499116566245, 'subsample': 0.74801201682934}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:51,130] Trial 806 finished with value: 1195.8790488365094 and parameters: {'n_estimators': 678, 'learning_rate': 0.1399666868642421, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.81984925544178, 'subsample': 0.6026365593838342}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:51,408] Trial 807 finished with value: 1190.695257342662 and parameters: {'n_estimators': 609, 'learning_rate': 0.11315571708178257, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.8447140621076141, 'subsample': 0.5504188881760347}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:51,720] Trial 808 finished with value: 1165.9621806391856 and parameters: {'n_estimators': 976, 'learning_rate': 0.10736559950429368, 'max_depth': 6, 'min_child_weight': 3, 'colsample_bytree': 0.7112268687853742, 'subsample': 0.5000369953604387}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:52,026] Trial 809 finished with value: 1157.7493568853895 and parameters: {'n_estimators': 695, 'learning_rate': 0.10082986900629916, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.8105327148117438, 'subsample': 0.5406239392988575}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:52,457] Trial 810 finished with value: 1154.3428928624758 and parameters: {'n_estimators': 765, 'learning_rate': 0.12456861156155988, 'max_depth': 6, 'min_child_weight': 10, 'colsample_bytree': 0.7576831761229275, 'subsample': 0.8385556238839533}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:52,825] Trial 811 finished with value: 1092.061306987483 and parameters: {'n_estimators': 669, 'learning_rate': 0.09433689714738755, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.8710625498020155, 'subsample': 0.5832059993091313}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:53,203] Trial 812 finished with value: 1220.9848145047133 and parameters: {'n_estimators': 726, 'learning_rate': 0.09106550206925919, 'max_depth': 7, 'min_child_weight': 8, 'colsample_bytree': 0.9292454078278112, 'subsample': 0.5877783308206601}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:53,477] Trial 813 finished with value: 1414.4713448641469 and parameters: {'n_estimators': 675, 'learning_rate': 0.24238679412690284, 'max_depth': 6, 'min_child_weight': 7, 'colsample_bytree': 0.9140992131591069, 'subsample': 0.5944203057401853}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:53,888] Trial 814 finished with value: 1238.5656951941194 and parameters: {'n_estimators': 129, 'learning_rate': 0.09336352236079642, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.8522405162990377, 'subsample': 0.9271762233550226}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:54,271] Trial 815 finished with value: 1150.9733920834287 and parameters: {'n_estimators': 1000, 'learning_rate': 0.09604642952374126, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.6980025957316474, 'subsample': 0.5851200633598477}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:54,652] Trial 816 finished with value: 1166.9632338953802 and parameters: {'n_estimators': 700, 'learning_rate': 0.09694029915418166, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.8494043878874461, 'subsample': 0.6036007303367062}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:55,012] Trial 817 finished with value: 1203.837748734776 and parameters: {'n_estimators': 966, 'learning_rate': 0.09021044042858861, 'max_depth': 7, 'min_child_weight': 9, 'colsample_bytree': 0.9039757659397537, 'subsample': 0.5828147283818294}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:55,429] Trial 818 finished with value: 1167.7822319011866 and parameters: {'n_estimators': 985, 'learning_rate': 0.08982981435301063, 'max_depth': 6, 'min_child_weight': 7, 'colsample_bytree': 0.8852662304639092, 'subsample': 0.6206615581682408}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:55,778] Trial 819 finished with value: 1206.3159957689938 and parameters: {'n_estimators': 685, 'learning_rate': 0.09832868785243266, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.8606795892322233, 'subsample': 0.5946804731371986}. Best is trial 123 with value: 1051.2679791197802.
# [I 2024-11-07 09:57:56,202] Trial 820 finished with value: 1132.1261505345112 and parameters: {'n_estimators': 634, 'learning_rate': 0.08625514509995755, 'max_depth': 6, 'min_child_weight': 6, 'colsample_bytree': 0.8705334961162089, 'subsample': 0.5262008724526205}. Best is trial 123 with value: 1051.2679791197802.
# [W 2024-11-07 09:57:56,357] Trial 821 failed with parameters: {'n_estimators': 718, 'learning_rate': 0.09209446948691125, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.8955421512065855, 'subsample': 0.6074515239407159} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/jinjinjara1022/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_2571168/3826353377.py", line 23, in objective
#     model.fit(x_train, y_train,
#   File "/home/jinjinjara1022/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/jinjinjara1022/.local/lib/python3.10/site-packages/xgboost/sklearn.py", line 1108, in fit
#     self._Booster = train(
#   File "/home/jinjinjara1022/.local/lib/python3.10/site-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/home/jinjinjara1022/.local/lib/python3.10/site-packages/xgboost/training.py", line 181, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/home/jinjinjara1022/.local/lib/python3.10/site-packages/xgboost/core.py", line 2101, in update
#     _LIB.XGBoosterUpdateOneIter(
# KeyboardInterrupt
# [W 2024-11-07 09:57:56,377] Trial 821 failed with value None.
#
# KeyboardInterrupt

# %%
xgb_reg = XGBRegressor(
    n_estimators=644,
    learning_rate = 0.13841787640025643,
    min_child_weight=10,
    max_depth=7,
    colsample_bytree=0.7394650551278316,
    subsample=0.6488107135886416,
    tree_method='hist',
    device='cuda:0',
    seed=0,
    early_stopping_rounds=500
)

xgb_reg.fit(
    x_train, y_train,
    eval_set=[(x_train, y_train), (x_valid, y_valid)],
    verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7394650551278316, device='cuda:0',
#              early_stopping_rounds=500, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.13841787640025643, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=10, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=644, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
def SMAPE(true, pred):
    return np.mean((np.abs(true-pred))/(np.abs(true) + np.abs(pred))) * 100

pred = xgb_reg.predict(x_valid)
pred = pd.Series(pred)
pred.index = np.arange(y_valid.index[0], y_valid.index[-1]+1)

plot_series(y_train, y_valid, pd.Series(pred), markers=[',' , ',', ','])

print('SMAPE : {}'.format(SMAPE(y_valid, pred)))
# Out:
# SMAPE : 11.984839762706324

# %%
plt.figure(figsize=(20, 5))
pred.plot(label='predict_price')
y_valid.plot()
plt.legend()
plt.show()

# %% [markdown]
# # SUBMIT DATA

# %%
x_train.columns
# Out:
# Index(['temp', 'real_feel_temp', 'wet_bulb_temp', 'dew_point', 'wind_dir',
#        'wind_spd', 'wind_gust_spd', 'rel_hum', 'vis', 'ceiling', 'uv_idx',
#        'precip_prob', 'rain_prob', 'snow_prob', 'ice_prob', 'total_liq',
#        'rain', 'snow', 'ice', 'cld_cvr', 'hour_sin', 'hour_cos', 'month_sin',
#        'month_cos', 'day_of_week_sin', 'day_of_week_cos', 'previous_day_price',
#        'previous_2day_price', 'previous_3day_price'],
#       dtype='object')

# %%
def submit_df(date): #2024-11-05 <- str # 제출하는 날짜 입력
    year, month, day = map(int, date.split('-'))
    date_object = datetime(year, month, day)

    
    API_KEY = """eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJlcXpORXlBR1ZiNDdadUNpN2RLZ1hqIiwiaWF0IjoxNzMwMDcyODI2LCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.zsJAvYixxcUwz4ad-y2cWwi6oWdc1hmegSTFSbeMuzk"""
    
    columns = ['temp', 'real_feel_temp', 'wet_bulb_temp', 'dew_point', 'wind_dir',
       'wind_spd', 'wind_gust_spd', 'rel_hum', 'vis', 'ceiling', 'uv_idx',
       'precip_prob', 'rain_prob', 'snow_prob', 'ice_prob', 'total_liq',
       'rain', 'snow', 'ice', 'cld_cvr', 'hour_sin', 'hour_cos', 'month_sin',
       'month_cos', 'day_of_week_sin', 'day_of_week_cos', 'previous_day_price',
       'previous_2day_price', 'previous_3day_price']

    none_dataframe = pd.DataFrame(columns=columns)
    none_dataframe = none_dataframe.reindex(range(24))

    
    none_dataframe['hour_cos'] = [np.cos(2 * np.pi * hour / 24) for hour in range(1, 25)]
    none_dataframe['hour_sin'] = [np.sin(2 * np.pi * hour / 24) for hour in range(1, 25)]

    none_dataframe['month_sin'] = np.sin(2 * np.pi * int(date.split('-')[1]) / 12)
    none_dataframe['month_cos'] = np.cos(2 * np.pi * int(date.split('-')[1]) / 12)

    none_dataframe['day_of_week_sin'] = np.sin(2 * np.pi * int(date.split('-')[2]) / 7)
    none_dataframe['day_of_week_cos'] = np.cos(2 * np.pi * int(date.split('-')[2]) / 7)

    forecast_date = date
    weather_forecast = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/weather-forecast/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()

    weather_forecast_df = pd.DataFrame(weather_forecast['weather_forecast_1'])
    weather_forecast_df = weather_forecast_df.drop(['location'], axis=1)

    weather_forecast_df_grouped = weather_forecast_df.groupby('ts').mean().reset_index()
    weather_forecast_df_grouped = weather_forecast_df_grouped.drop(index=0).reset_index(drop=True)


    weather_col = [
        'uv_idx', 'rel_hum',  'wind_spd', 'cld_cvr',
        'wind_gust_spd', 'dew_point', 'real_feel_temp', 'ceiling',
        'wind_dir', 'wet_bulb_temp', 'temp', 'precip_prob', 
        'vis', 'rain_prob', 'rain', 'total_liq',
        'snow', 'snow_prob', 'ice', 'ice_prob'
        ]    

    for col in weather_col:
        none_dataframe[col] = weather_forecast_df_grouped[col]

    smp_preday_1 = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                                'Authorization': f'Bearer {API_KEY}'
                            }).json()
    
    none_dataframe['previous_day_price'] = pd.DataFrame(smp_preday_1)['smp_da']
    
    
    previous_day = date_object - timedelta(days=1)
    date = f"{previous_day.year}-{previous_day.month:02d}-{previous_day.day:02d}"

    
    smp_preday_2 = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                                'Authorization': f'Bearer {API_KEY}'
                            }).json()

    none_dataframe['previous_2day_price'] = pd.DataFrame(smp_preday_2)['smp_da']


    previous_day = date_object - timedelta(days=2)
    date = f"{previous_day.year}-{previous_day.month:02d}-{previous_day.day:02d}"

    smp_preday_3 = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                                'Authorization': f'Bearer {API_KEY}'
                            }).json()

    none_dataframe['previous_3day_price'] = pd.DataFrame(smp_preday_3)['smp_da']

     
    return none_dataframe

# %%
submit_data = submit_df('2024-11-06')

# %%
submit_data[columns_to_scale] = scaler1.transform(submit_data[columns_to_scale])
#submit_data[columns_to_scale] = scaler2.transform(submit_data[columns_to_scale])

# %%
pred = xgb_reg.predict(submit_data)
pred_float = list(map(float, pred))

# %%
result = {
    'submit_result' : pred_float
}
success = requests.post('https://research-api.solarkim.com/submissions/cmpt-2024',
                    data=json.dumps(result),
                    headers={
                        'Authorization': f'Bearer {API_KEY}'
                    }).json()
print(success)
# Out:
# True

# %% [markdown]
# # CHECK

# %%
submit_data = submit_df('2024-11-05') # 제출일
submit_data[columns_to_scale] = scaler1.transform(submit_data[columns_to_scale])
#submit_data[columns_to_scale] = scaler2.transform(submit_data[columns_to_scale])
pred = xgb_reg.predict(submit_data)
pred_float = list(map(float, pred))

# %%
date = '2024-11-06'
smp_da = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()
real = []

for i in smp_da:
    real.append(i['smp_da'])

# %%
plt.figure(figsize=(10, 5))
plt.plot(real, label='real')
plt.plot(pred, label='pred')
plt.ylim(-100, 200)

plt.legend()
plt.title(f"score : {calculate_measure(real, pred)}")
plt.show()
