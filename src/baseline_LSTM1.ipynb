# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import random
import os

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader 

from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Fixed Random Seed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(42)

# %% [markdown]
# ## Data Load

# %%
base_path = "/home/jinjinjara1022/"

weather_forecast_data_1 = pd.read_csv(base_path + "OBIC/data/기상예측데이터_1.csv")
weather_forecast_data_2 = pd.read_csv(base_path + "OBIC/data/기상예측데이터_2.csv")  

weather_observed_data_1 = pd.read_csv(base_path + "OBIC/data/기상실측데이터_1.csv")
weather_observed_data_2 = pd.read_csv(base_path + "OBIC/data/기상실측데이터_2.csv")  
  
jeju_power_market_day_ahead = pd.read_csv(base_path + "OBIC/data/제주전력시장_시장전기가격_하루전가격.csv")
jeju_power_market_real_time = pd.read_csv(base_path + "OBIC/data/제주전력시장_시장전기가격_실시간가격.csv")

jeju_power_market_status = pd.read_csv(base_path + "OBIC/data/제주전력시장_현황데이터.csv")

# %% [markdown]
# ## Data preprocessing

# %%
df = jeju_power_market_day_ahead

# %%
df['datetimes'] = pd.to_datetime(df['ts'], unit='s')

# 3. 월, 일, 시각 열 추가
df['hour'] = df['datetimes'].dt.hour

df = df[[col for col in df.columns if col != '하루전가격(원/kWh)'] + ['하루전가격(원/kWh)']]

# %%
df
# Out:
#               ts           datetimes  hour  하루전가격(원/kWh)
# 0     1709218800 2024-02-29 15:00:00    15        107.39
# 1     1709222400 2024-02-29 16:00:00    16        107.39
# 2     1709226000 2024-02-29 17:00:00    17         95.30
# 3     1709229600 2024-02-29 18:00:00    18         87.89
# 4     1709233200 2024-02-29 19:00:00    19          0.00
# ...          ...                 ...   ...           ...
# 5660  1729594800 2024-10-22 11:00:00    11        156.68
# 5661  1729598400 2024-10-22 12:00:00    12        152.54
# 5662  1729602000 2024-10-22 13:00:00    13        106.92
# 5663  1729605600 2024-10-22 14:00:00    14        150.97
# 5664  1729609200 2024-10-22 15:00:00    15        121.78
#
# [5665 rows x 4 columns]

# %%
df = df.drop(['ts', 'datetimes'], axis=1)

# %%
df = df[[col for col in df.columns if col != '하루전가격(원/kWh)'] + ['하루전가격(원/kWh)']]

# %%
df
# Out:
#       hour  하루전가격(원/kWh)
# 0       15        107.39
# 1       16        107.39
# 2       17         95.30
# 3       18         87.89
# 4       19          0.00
# ...    ...           ...
# 5660    11        156.68
# 5661    12        152.54
# 5662    13        106.92
# 5663    14        150.97
# 5664    15        121.78
#
# [5665 rows x 2 columns]

# %%
train_df = df[:int(len(df) * 0.8)]
vali_df = df[int(len(df) * 0.8):]

# %%
train_df
# Out:
#       hour  하루전가격(원/kWh)
# 0       15        107.39
# 1       16        107.39
# 2       17         95.30
# 3       18         87.89
# 4       19          0.00
# ...    ...           ...
# 4527     6        150.69
# 4528     7        152.93
# 4529     8        152.93
# 4530     9        160.70
# 4531    10        161.03
#
# [4532 rows x 2 columns]

# %%
input_size = 2  # feature의 개수
hidden_size = 16
num_layers = 2
output_size = 1
num_epochs = 100
window_size = 64  # 예측에 사용될 시간 윈도우 크기
batch_size = 32
learning_rate = 0.001

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import pandas as pd

class TimeSeriesDataset(Dataset):
    def __init__(self, df, window_size):
        self.df = df.values
        self.window_size = window_size

    def __len__(self):
        # 마지막에 남은 샘플이 window_size + 24보다 작으면 제외
        return len(self.df) - (self.window_size + 24) + 1

    def __getitem__(self, idx):
        x = torch.tensor(self.df[idx:idx + self.window_size, :], dtype=torch.float)
        y = torch.tensor(self.df[idx + self.window_size: idx + self.window_size + 24, -1], dtype=torch.float)
        return x, y

def create_data_loader(df, window_size, batch_size):
    dataset = TimeSeriesDataset(df, window_size)
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    return data_loader


train_loader = create_data_loader(train_df, window_size, batch_size)

# %%
import torch
import torch.nn as nn

class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size=24):
        super(LSTM, self).__init__()

        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.output_size = output_size

        # LSTM 레이어
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        
        # 24개의 출력값을 예측할 수 있도록 Linear 레이어 수정
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        # 초기 hidden state 및 cell state 생성
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device) 
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        # LSTM에 입력을 전달하고 hidden states를 가져옵니다
        out, _ = self.lstm(x, (h0, c0))
        
        # LSTM의 마지막 타임스텝의 출력만을 사용하여 예측
        out = self.fc(out[:, -1, :])

        return out

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"current device: {device}")

model = LSTM(input_size, hidden_size, num_layers, output_size=24).to(device)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# current device: cuda

# %%
for epoch in range(num_epochs):
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.to(device)
        labels = labels.unsqueeze(1).to(device)

        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, i+1, len(train_loader), loss.item()))
# Out:
# /home/jinjinjara1022/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([32, 1, 24])) that is different to the input size (torch.Size([32, 24])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /home/jinjinjara1022/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([29, 1, 24])) that is different to the input size (torch.Size([29, 24])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/100], Step [139/139], Loss: 18708.0273
# Epoch [2/100], Step [139/139], Loss: 17340.2051
# Epoch [3/100], Step [139/139], Loss: 16149.0586
# Epoch [4/100], Step [139/139], Loss: 15053.1797
# Epoch [5/100], Step [139/139], Loss: 14030.8457
# Epoch [6/100], Step [139/139], Loss: 13071.7148
# Epoch [7/100], Step [139/139], Loss: 12169.5967
# Epoch [8/100], Step [139/139], Loss: 11320.1279
# Epoch [9/100], Step [139/139], Loss: 10519.8711
# Epoch [10/100], Step [139/139], Loss: 9766.1367
# Epoch [11/100], Step [139/139], Loss: 9056.4883
# Epoch [12/100], Step [139/139], Loss: 8388.7881
# Epoch [13/100], Step [139/139], Loss: 7761.1001
# Epoch [14/100], Step [139/139], Loss: 7171.6685
# Epoch [15/100], Step [139/139], Loss: 6618.8257
# Epoch [16/100], Step [139/139], Loss: 6101.0396
# Epoch [17/100], Step [139/139], Loss: 5616.8354
# Epoch [18/100], Step [139/139], Loss: 5164.8096
# Epoch [19/100], Step [139/139], Loss: 4743.6143
# Epoch [20/100], Step [139/139], Loss: 4351.9438
# Epoch [21/100], Step [139/139], Loss: 3988.5278
# Epoch [22/100], Step [139/139], Loss: 3652.1277
# Epoch [23/100], Step [139/139], Loss: 3341.5220
# Epoch [24/100], Step [139/139], Loss: 3055.5120
# Epoch [25/100], Step [139/139], Loss: 2792.9087
# Epoch [26/100], Step [139/139], Loss: 2552.5195
# Epoch [27/100], Step [139/139], Loss: 2333.2004
# Epoch [28/100], Step [139/139], Loss: 2133.8555
# Epoch [29/100], Step [139/139], Loss: 1953.0502
# Epoch [30/100], Step [139/139], Loss: 1789.5360
# Epoch [31/100], Step [139/139], Loss: 1641.8491
# Epoch [32/100], Step [139/139], Loss: 1508.8137
# Epoch [33/100], Step [139/139], Loss: 1387.5117
# Epoch [34/100], Step [139/139], Loss: 1278.3854
# Epoch [35/100], Step [139/139], Loss: 1180.8129
# Epoch [36/100], Step [139/139], Loss: 1094.6349
# Epoch [37/100], Step [139/139], Loss: 1018.3376
# Epoch [38/100], Step [139/139], Loss: 950.2233
# Epoch [39/100], Step [139/139], Loss: 890.3214
# Epoch [40/100], Step [139/139], Loss: 834.3995
# Epoch [41/100], Step [139/139], Loss: 785.5856
# Epoch [42/100], Step [139/139], Loss: 740.9153
# Epoch [43/100], Step [139/139], Loss: 699.7373
# Epoch [44/100], Step [139/139], Loss: 664.2747
# Epoch [45/100], Step [139/139], Loss: 633.7816
# Epoch [46/100], Step [139/139], Loss: 608.1320
# Epoch [47/100], Step [139/139], Loss: 585.5027
# Epoch [48/100], Step [139/139], Loss: 566.3258
# Epoch [49/100], Step [139/139], Loss: 549.2131
# Epoch [50/100], Step [139/139], Loss: 534.5172
# Epoch [51/100], Step [139/139], Loss: 520.9339
# Epoch [52/100], Step [139/139], Loss: 509.7584
# Epoch [53/100], Step [139/139], Loss: 499.8793
# Epoch [54/100], Step [139/139], Loss: 491.8282
# Epoch [55/100], Step [139/139], Loss: 484.4352
# Epoch [56/100], Step [139/139], Loss: 478.3825
# Epoch [57/100], Step [139/139], Loss: 472.5539
# Epoch [58/100], Step [139/139], Loss: 467.7680
# Epoch [59/100], Step [139/139], Loss: 464.0864
# Epoch [60/100], Step [139/139], Loss: 460.7132
# Epoch [61/100], Step [139/139], Loss: 457.8820
# Epoch [62/100], Step [139/139], Loss: 455.4914
# Epoch [63/100], Step [139/139], Loss: 505.5040
# Epoch [64/100], Step [139/139], Loss: 490.2581
# Epoch [65/100], Step [139/139], Loss: 479.9144
# Epoch [66/100], Step [139/139], Loss: 472.3557
# Epoch [67/100], Step [139/139], Loss: 466.1147
# Epoch [68/100], Step [139/139], Loss: 460.6081
# Epoch [69/100], Step [139/139], Loss: 454.5550
# Epoch [70/100], Step [139/139], Loss: 452.4864
# Epoch [71/100], Step [139/139], Loss: 449.7951
# Epoch [72/100], Step [139/139], Loss: 448.7277
# Epoch [73/100], Step [139/139], Loss: 447.6012
# Epoch [74/100], Step [139/139], Loss: 446.4162
# Epoch [75/100], Step [139/139], Loss: 445.5953
# Epoch [76/100], Step [139/139], Loss: 444.9528
# Epoch [77/100], Step [139/139], Loss: 444.5504
# Epoch [78/100], Step [139/139], Loss: 444.4174
# Epoch [79/100], Step [139/139], Loss: 443.6470
# Epoch [80/100], Step [139/139], Loss: 442.8663
# Epoch [81/100], Step [139/139], Loss: 442.4383
# Epoch [82/100], Step [139/139], Loss: 442.0385
# Epoch [83/100], Step [139/139], Loss: 441.6041
# Epoch [84/100], Step [139/139], Loss: 440.9005
# Epoch [85/100], Step [139/139], Loss: 441.0799
# Epoch [86/100], Step [139/139], Loss: 440.2138
# Epoch [87/100], Step [139/139], Loss: 440.2269
# Epoch [88/100], Step [139/139], Loss: 440.2716
# Epoch [89/100], Step [139/139], Loss: 439.9632
# Epoch [90/100], Step [139/139], Loss: 439.6625
# Epoch [91/100], Step [139/139], Loss: 439.4319
# Epoch [92/100], Step [139/139], Loss: 439.1649
# Epoch [93/100], Step [139/139], Loss: 479.8198
# Epoch [94/100], Step [139/139], Loss: 468.0475
# Epoch [95/100], Step [139/139], Loss: 460.2763
# Epoch [96/100], Step [139/139], Loss: 455.0582
# Epoch [97/100], Step [139/139], Loss: 450.8854
# Epoch [98/100], Step [139/139], Loss: 447.5339
# Epoch [99/100], Step [139/139], Loss: 445.2422
# Epoch [100/100], Step [139/139], Loss: 441.1461

# %%
vali_df
# Out:
#       hour  하루전가격(원/kWh)
# 4532    11        161.03
# 4533    12        161.03
# 4534    13        161.03
# 4535    14        161.03
# 4536    15        140.15
# ...    ...           ...
# 5660    11        156.68
# 5661    12        152.54
# 5662    13        106.92
# 5663    14        150.97
# 5664    15        121.78
#
# [1133 rows x 2 columns]

# %%
test_loader = create_data_loader(vali_df, window_size, 1)

# %%
for idx, (i) in enumerate(test_loader):
    X = i[0].to(device)
    pred = model(X)
    
    print(pred)
    if idx % 24 == 0:
        print(i[1])
    break
# Out:
# tensor([[137.3743, 137.3662, 137.3140, 137.3891, 137.4444, 137.4504, 137.3528,
#          137.4045, 137.2832, 137.2427, 137.1811, 137.2618, 137.3139, 137.2802,
#          137.1784, 137.2173, 137.1106, 137.0659, 136.9838, 137.0069, 137.0491,
#          136.9077, 136.8401, 136.7248]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[141.3500, 143.9100, 141.3400, 143.1900, 160.3700, 160.3700, 163.5100,
#          163.5100, 163.7800, 163.7800, 162.0500, 161.3800, 160.7600, 137.2200,
#          106.8800, 106.8800, 106.8800, 106.8800, 106.8800, 139.9700, 142.4600,
#          146.3500, 151.1900, 159.5300]])

# %%
real = []
pred = []

for X, y in test_loader:
    inputs = X.to(device)
    outputs = model(inputs)
    
    tmp = outputs.detach()

    print(tmp)
    break
    real.append(list(y[0]))
    pred.append(list(tmp[0]))
# Out:
# tensor([[137.5546]], device='cuda:0')

# %%
pred
# Out:
# [[tensor(137.5546, device='cuda:0')],
#  [tensor(137.5550, device='cuda:0')],
#  [tensor(137.5544, device='cuda:0')],
#  [tensor(137.5498, device='cuda:0')],
#  [tensor(137.5451, device='cuda:0')],
#  [tensor(137.5495, device='cuda:0')],
#  [tensor(137.5449, device='cuda:0')],
#  [tensor(137.5432, device='cuda:0')],
#  [tensor(137.5392, device='cuda:0')],
#  [tensor(137.5340, device='cuda:0')],
#  [tensor(137.5272, device='cuda:0')],
#  [tensor(137.5185, device='cuda:0')],
#  [tensor(137.5061, device='cuda:0')],
#  [tensor(137.4911, device='cuda:0')],
#  [tensor(137.1811, device='cuda:0')],
#  [tensor(136.5771, device='cuda:0')],
#  [tensor(136.4743, device='cuda:0')],
#  [tensor(136.4367, device='cuda:0')],
#  [tensor(136.4121, device='cuda:0')],
#  [tensor(136.3930, device='cuda:0')],
#  [tensor(136.5305, device='cuda:0')],
#  [tensor(136.5358, device='cuda:0')],
#  [tensor(137.4976, device='cuda:0')],
#  [tensor(137.5536, device='cuda:0')],
#  [tensor(137.5592, device='cuda:0')],
#  [tensor(137.5595, device='cuda:0')],
#  [tensor(137.5569, device='cuda:0')],
#  [tensor(137.5573, device='cuda:0')],
#  [tensor(137.5557, device='cuda:0')],
#  [tensor(137.5518, device='cuda:0')],
#  [tensor(137.5471, device='cuda:0')],
#  [tensor(137.5427, device='cuda:0')],
#  [tensor(137.5455, device='cuda:0')],
#  [tensor(137.5327, device='cuda:0')],
#  [tensor(137.5249, device='cuda:0')],
#  [tensor(137.5178, device='cuda:0')],
#  [tensor(137.5028, device='cuda:0')],
#  [tensor(137.3378, device='cuda:0')],
#  [tensor(137.2943, device='cuda:0')],
#  [tensor(137.0514, device='cuda:0')],
#  [tensor(136.8407, device='cuda:0')],
#  [tensor(136.6763, device='cuda:0')],
#  [tensor(136.5894, device='cuda:0')],
#  [tensor(136.6141, device='cuda:0')],
#  [tensor(136.5749, device='cuda:0')],
#  [tensor(136.5801, device='cuda:0')],
#  [tensor(137.5029, device='cuda:0')],
#  [tensor(137.5554, device='cuda:0')],
#  [tensor(137.5602, device='cuda:0')],
#  [tensor(137.5603, device='cuda:0')],
#  [tensor(137.5595, device='cuda:0')],
#  [tensor(137.5577, device='cuda:0')],
#  [tensor(137.5548, device='cuda:0')],
#  [tensor(137.5544, device='cuda:0')],
#  [tensor(137.5517, device='cuda:0')],
#  [tensor(137.5425, device='cuda:0')],
#  [tensor(137.5381, device='cuda:0')],
#  [tensor(137.5321, device='cuda:0')],
#  [tensor(137.5180, device='cuda:0')],
#  [tensor(137.5047, device='cuda:0')],
#  [tensor(137.4896, device='cuda:0')],
#  [tensor(137.3463, device='cuda:0')],
#  [tensor(137.2654, device='cuda:0')],
#  [tensor(137.1145, device='cuda:0')],
#  [tensor(136.9928, device='cuda:0')],
#  [tensor(136.7851, device='cuda:0')],
#  [tensor(136.6694, device='cuda:0')],
#  [tensor(136.6730, device='cuda:0')],
#  [tensor(136.6127, device='cuda:0')],
#  [tensor(136.5876, device='cuda:0')],
#  [tensor(137.5007, device='cuda:0')],
#  [tensor(137.5521, device='cuda:0')],
#  [tensor(137.5558, device='cuda:0')],
#  [tensor(137.5562, device='cuda:0')],
#  [tensor(137.5553, device='cuda:0')],
#  [tensor(137.5533, device='cuda:0')],
#  [tensor(137.5500, device='cuda:0')],
#  [tensor(137.5450, device='cuda:0')],
#  [tensor(137.5402, device='cuda:0')],
#  [tensor(137.5361, device='cuda:0')],
#  [tensor(137.5463, device='cuda:0')],
#  [tensor(137.5255, device='cuda:0')],
#  [tensor(137.5136, device='cuda:0')],
#  [tensor(137.5046, device='cuda:0')],
#  [tensor(137.4172, device='cuda:0')],
#  [tensor(137.3358, device='cuda:0')],
#  [tensor(137.2869, device='cuda:0')],
#  [tensor(137.0662, device='cuda:0')],
#  [tensor(136.9289, device='cuda:0')],
#  [tensor(136.8049, device='cuda:0')],
#  [tensor(136.7084, device='cuda:0')],
#  [tensor(136.6381, device='cuda:0')],
#  [tensor(136.6249, device='cuda:0')],
#  [tensor(136.5682, device='cuda:0')],
#  [tensor(137.4990, device='cuda:0')],
#  [tensor(137.5514, device='cuda:0')],
#  [tensor(137.5547, device='cuda:0')],
#  [tensor(137.5549, device='cuda:0')],
#  [tensor(137.5538, device='cuda:0')],
#  [tensor(137.5517, device='cuda:0')],
#  [tensor(137.5495, device='cuda:0')],
#  [tensor(137.5526, device='cuda:0')],
#  [tensor(137.5457, device='cuda:0')],
#  [tensor(137.5385, device='cuda:0')],
#  [tensor(137.5337, device='cuda:0')],
#  [tensor(137.5475, device='cuda:0')],
#  [tensor(137.5215, device='cuda:0')],
#  [tensor(137.5100, device='cuda:0')],
#  [tensor(137.4884, device='cuda:0')],
#  [tensor(137.4704, device='cuda:0')],
#  [tensor(137.4234, device='cuda:0')],
#  [tensor(137.2178, device='cuda:0')],
#  [tensor(136.9515, device='cuda:0')],
#  [tensor(136.8194, device='cuda:0')],
#  [tensor(136.7211, device='cuda:0')],
#  [tensor(136.6924, device='cuda:0')],
#  [tensor(136.6512, device='cuda:0')],
#  [tensor(136.5864, device='cuda:0')],
#  [tensor(137.4998, device='cuda:0')],
#  [tensor(137.5506, device='cuda:0')],
#  [tensor(137.5547, device='cuda:0')],
#  [tensor(137.5545, device='cuda:0')],
#  [tensor(137.5535, device='cuda:0')],
#  [tensor(137.5516, device='cuda:0')],
#  [tensor(137.5485, device='cuda:0')],
#  [tensor(137.5459, device='cuda:0')],
#  [tensor(137.5424, device='cuda:0')],
#  [tensor(137.5401, device='cuda:0')],
#  [tensor(137.5488, device='cuda:0')],
#  [tensor(137.5309, device='cuda:0')],
#  [tensor(137.5232, device='cuda:0')],
#  [tensor(137.5082, device='cuda:0')],
#  [tensor(137.4946, device='cuda:0')],
#  [tensor(137.4712, device='cuda:0')],
#  [tensor(137.4955, device='cuda:0')],
#  [tensor(137.1868, device='cuda:0')],
#  [tensor(136.9438, device='cuda:0')],
#  [tensor(136.8125, device='cuda:0')],
#  [tensor(136.6720, device='cuda:0')],
#  [tensor(136.5905, device='cuda:0')],
#  [tensor(136.6364, device='cuda:0')],
#  [tensor(136.5880, device='cuda:0')],
#  [tensor(137.5009, device='cuda:0')],
#  [tensor(137.5511, device='cuda:0')],
#  [tensor(137.5531, device='cuda:0')],
#  [tensor(137.5525, device='cuda:0')],
#  [tensor(137.5507, device='cuda:0')],
#  [tensor(137.5486, device='cuda:0')],
#  [tensor(137.5451, device='cuda:0')],
#  [tensor(137.5402, device='cuda:0')],
#  [tensor(137.5343, device='cuda:0')],
#  [tensor(137.5246, device='cuda:0')],
#  [tensor(137.5329, device='cuda:0')],
#  [tensor(137.5272, device='cuda:0')],
#  [tensor(137.5191, device='cuda:0')],
#  [tensor(137.5085, device='cuda:0')],
#  [tensor(137.4199, device='cuda:0')],
#  [tensor(137.3300, device='cuda:0')],
#  [tensor(137.2692, device='cuda:0')],
#  [tensor(136.5868, device='cuda:0')],
#  [tensor(136.4748, device='cuda:0')],
#  [tensor(136.4363, device='cuda:0')],
#  [tensor(136.4119, device='cuda:0')],
#  [tensor(136.3931, device='cuda:0')],
#  [tensor(136.3761, device='cuda:0')],
#  [tensor(136.5439, device='cuda:0')],
#  [tensor(137.4938, device='cuda:0')],
#  [tensor(137.5484, device='cuda:0')],
#  [tensor(137.5521, device='cuda:0')],
#  [tensor(137.5515, device='cuda:0')],
#  [tensor(137.5514, device='cuda:0')],
#  [tensor(137.5499, device='cuda:0')],
#  [tensor(137.5465, device='cuda:0')],
#  [tensor(137.5445, device='cuda:0')],
#  [tensor(137.5385, device='cuda:0')],
#  [tensor(137.5316, device='cuda:0')],
#  [tensor(137.5514, device='cuda:0')],
#  [tensor(137.5139, device='cuda:0')],
#  [tensor(137.4862, device='cuda:0')],
#  [tensor(137.4549, device='cuda:0')],
#  [tensor(137.3627, device='cuda:0')],
#  [tensor(137.2733, device='cuda:0')],
#  [tensor(136.7521, device='cuda:0')],
#  [tensor(136.5364, device='cuda:0')],
#  [tensor(136.4678, device='cuda:0')],
#  [tensor(136.4331, device='cuda:0')],
#  [tensor(136.4082, device='cuda:0')],
#  [tensor(136.3888, device='cuda:0')],
#  [tensor(136.3735, device='cuda:0')],
#  [tensor(136.3580, device='cuda:0')],
#  [tensor(137.4507, device='cuda:0')],
#  [tensor(137.5345, device='cuda:0')],
#  [tensor(137.5594, device='cuda:0')],
#  [tensor(137.5608, device='cuda:0')],
#  [tensor(137.5594, device='cuda:0')],
#  [tensor(137.5566, device='cuda:0')],
#  [tensor(137.5536, device='cuda:0')],
#  [tensor(137.5538, device='cuda:0')],
#  [tensor(137.5466, device='cuda:0')],
#  [tensor(137.5389, device='cuda:0')],
#  [tensor(137.5290, device='cuda:0')],
#  [tensor(137.5602, device='cuda:0')],
#  [tensor(137.4996, device='cuda:0')],
#  [tensor(137.4061, device='cuda:0')],
#  [tensor(137.3355, device='cuda:0')],
#  [tensor(137.3843, device='cuda:0')],
#  [tensor(136.6633, device='cuda:0')],
#  [tensor(136.5079, device='cuda:0')],
#  [tensor(136.4364, device='cuda:0')],
#  [tensor(136.4103, device='cuda:0')],
#  [tensor(136.3922, device='cuda:0')],
#  [tensor(136.3767, device='cuda:0')],
#  [tensor(136.3694, device='cuda:0')],
#  [tensor(136.3560, device='cuda:0')],
#  [tensor(137.4557, device='cuda:0')],
#  [tensor(137.5427, device='cuda:0')],
#  [tensor(137.5464, device='cuda:0')],
#  [tensor(137.5392, device='cuda:0')],
#  [tensor(137.5264, device='cuda:0')],
#  [tensor(137.5335, device='cuda:0')],
#  [tensor(137.5177, device='cuda:0')],
#  [tensor(137.5558, device='cuda:0')],
#  [tensor(137.5475, device='cuda:0')],
#  [tensor(137.5446, device='cuda:0')],
#  [tensor(137.5666, device='cuda:0')],
#  [tensor(137.5164, device='cuda:0')],
#  [tensor(137.5163, device='cuda:0')],
#  [tensor(137.4225, device='cuda:0')],
#  [tensor(137.3013, device='cuda:0')],
#  [tensor(136.7609, device='cuda:0')],
#  [tensor(137.5475, device='cuda:0')],
#  [tensor(136.6377, device='cuda:0')],
#  [tensor(136.4905, device='cuda:0')],
#  [tensor(136.4488, device='cuda:0')],
#  [tensor(136.4235, device='cuda:0')],
#  [tensor(136.4049, device='cuda:0')],
#  [tensor(137.4139, device='cuda:0')],
#  [tensor(137.5086, device='cuda:0')],
#  [tensor(137.5737, device='cuda:0')],
#  [tensor(137.5861, device='cuda:0')],
#  [tensor(137.5856, device='cuda:0')],
#  [tensor(137.5852, device='cuda:0')],
#  [tensor(137.5828, device='cuda:0')],
#  [tensor(137.5788, device='cuda:0')],
#  [tensor(137.5730, device='cuda:0')],
#  [tensor(137.5726, device='cuda:0')],
#  [tensor(137.5671, device='cuda:0')],
#  [tensor(137.5598, device='cuda:0')],
#  [tensor(137.5827, device='cuda:0')],
#  [tensor(137.5834, device='cuda:0')],
#  [tensor(137.5211, device='cuda:0')],
#  [tensor(137.4524, device='cuda:0')],
#  [tensor(137.3029, device='cuda:0')],
#  [tensor(137.3952, device='cuda:0')],
#  [tensor(136.6774, device='cuda:0')],
#  [tensor(136.5346, device='cuda:0')],
#  [tensor(136.4789, device='cuda:0')],
#  [tensor(136.4440, device='cuda:0')],
#  [tensor(136.4196, device='cuda:0')],
#  [tensor(136.4009, device='cuda:0')],
#  [tensor(136.3856, device='cuda:0')],
#  [tensor(136.4400, device='cuda:0')],
#  [tensor(137.5088, device='cuda:0')],
#  [tensor(137.5749, device='cuda:0')],
#  [tensor(137.5802, device='cuda:0')],
#  [tensor(137.5786, device='cuda:0')],
#  [tensor(137.5771, device='cuda:0')],
#  [tensor(137.5761, device='cuda:0')],
#  [tensor(137.5724, device='cuda:0')],
#  [tensor(137.5771, device='cuda:0')],
#  [tensor(137.5687, device='cuda:0')],
#  [tensor(137.5641, device='cuda:0')],
#  [tensor(137.5595, device='cuda:0')],
#  [tensor(137.5529, device='cuda:0')],
#  [tensor(137.5046, device='cuda:0')],
#  [tensor(137.4720, device='cuda:0')],
#  [tensor(137.3749, device='cuda:0')],
#  [tensor(137.2480, device='cuda:0')],
#  [tensor(137.3953, device='cuda:0')],
#  [tensor(137.2087, device='cuda:0')],
#  [tensor(137.0810, device='cuda:0')],
#  [tensor(136.7152, device='cuda:0')],
#  [tensor(136.6306, device='cuda:0')],
#  [tensor(131.9859, device='cuda:0')],
#  [tensor(134.8740, device='cuda:0')],
#  [tensor(135.7267, device='cuda:0')],
#  [tensor(136.9196, device='cuda:0')],
#  [tensor(137.0762, device='cuda:0')],
#  [tensor(137.1189, device='cuda:0')],
#  [tensor(137.1349, device='cuda:0')],
#  [tensor(137.1386, device='cuda:0')],
#  [tensor(137.1375, device='cuda:0')],
#  [tensor(137.1360, device='cuda:0')],
#  [tensor(137.1391, device='cuda:0')],
#  [tensor(137.1235, device='cuda:0')],
#  [tensor(137.1165, device='cuda:0')],
#  [tensor(137.1087, device='cuda:0')],
#  [tensor(137.0931, device='cuda:0')],
#  [tensor(137.0803, device='cuda:0')],
#  [tensor(137.0677, device='cuda:0')],
#  [tensor(137.0416, device='cuda:0')],
#  [tensor(136.8811, device='cuda:0')],
#  [tensor(136.7285, device='cuda:0')],
#  [tensor(136.5588, device='cuda:0')],
#  [tensor(136.4577, device='cuda:0')],
#  [tensor(136.1841, device='cuda:0')],
#  [tensor(136.0956, device='cuda:0')],
#  [tensor(136.0083, device='cuda:0')],
#  [tensor(135.9172, device='cuda:0')],
#  [tensor(135.9287, device='cuda:0')],
#  [tensor(136.8885, device='cuda:0')],
#  [tensor(136.9947, device='cuda:0')],
#  [tensor(137.0249, device='cuda:0')],
#  [tensor(137.0350, device='cuda:0')],
#  [tensor(137.0378, device='cuda:0')],
#  [tensor(137.0361, device='cuda:0')],
#  [tensor(137.0285, device='cuda:0')],
#  [tensor(137.0070, device='cuda:0')],
#  [tensor(136.9939, device='cuda:0')],
#  [tensor(136.9760, device='cuda:0')],
#  [tensor(137.0009, device='cuda:0')],
#  [tensor(136.9900, device='cuda:0')],
#  [tensor(136.9719, device='cuda:0')],
#  [tensor(136.8369, device='cuda:0')],
#  [tensor(136.7959, device='cuda:0')],
#  [tensor(136.7856, device='cuda:0')],
#  [tensor(136.6048, device='cuda:0')],
#  [tensor(136.2599, device='cuda:0')],
#  [tensor(136.1388, device='cuda:0')],
#  [tensor(136.0473, device='cuda:0')],
#  [tensor(135.9529, device='cuda:0')],
#  [tensor(135.8566, device='cuda:0')],
#  [tensor(135.7561, device='cuda:0')],
#  [tensor(135.7449, device='cuda:0')],
#  [tensor(136.7343, device='cuda:0')],
#  [tensor(136.8549, device='cuda:0')],
#  [tensor(136.8945, device='cuda:0')],
#  [tensor(136.9066, device='cuda:0')],
#  [tensor(136.9162, device='cuda:0')],
#  [tensor(136.9103, device='cuda:0')],
#  [tensor(136.8919, device='cuda:0')],
#  [tensor(136.8961, device='cuda:0')],
#  [tensor(136.8558, device='cuda:0')],
#  [tensor(136.7852, device='cuda:0')],
#  [tensor(136.6348, device='cuda:0')],
#  [tensor(136.2787, device='cuda:0')],
#  [tensor(137.5655, device='cuda:0')],
#  [tensor(137.5065, device='cuda:0')],
#  [tensor(137.3879, device='cuda:0')],
#  [tensor(137.2816, device='cuda:0')],
#  [tensor(137.0564, device='cuda:0')],
#  [tensor(136.8665, device='cuda:0')],
#  [tensor(136.7490, device='cuda:0')],
#  [tensor(136.6578, device='cuda:0')],
#  [tensor(136.5838, device='cuda:0')],
#  [tensor(136.4095, device='cuda:0')],
#  [tensor(136.4595, device='cuda:0')],
#  [tensor(136.5227, device='cuda:0')],
#  [tensor(137.4953, device='cuda:0')],
#  [tensor(137.5513, device='cuda:0')],
#  [tensor(137.5554, device='cuda:0')],
#  [tensor(137.5553, device='cuda:0')],
#  [tensor(137.5539, device='cuda:0')],
#  [tensor(137.5536, device='cuda:0')],
#  [tensor(137.5533, device='cuda:0')],
#  [tensor(137.5490, device='cuda:0')],
#  [tensor(137.5451, device='cuda:0')],
#  [tensor(137.5397, device='cuda:0')],
#  [tensor(137.5325, device='cuda:0')],
#  [tensor(137.5253, device='cuda:0')],
#  [tensor(137.5148, device='cuda:0')],
#  [tensor(137.4993, device='cuda:0')],
#  [tensor(137.4905, device='cuda:0')],
#  [tensor(137.4759, device='cuda:0')],
#  [tensor(136.6714, device='cuda:0')],
#  [tensor(136.5212, device='cuda:0')],
#  [tensor(136.4610, device='cuda:0')],
#  [tensor(136.4269, device='cuda:0')],
#  [tensor(136.4039, device='cuda:0')],
#  [tensor(136.3873, device='cuda:0')],
#  [tensor(136.3709, device='cuda:0')],
#  [tensor(136.3551, device='cuda:0')],
#  [tensor(137.4789, device='cuda:0')],
#  [tensor(137.5512, device='cuda:0')],
#  [tensor(137.5576, device='cuda:0')],
#  [tensor(137.5540, device='cuda:0')],
#  [tensor(137.5511, device='cuda:0')],
#  [tensor(137.5500, device='cuda:0')],
#  [tensor(137.5468, device='cuda:0')],
#  [tensor(137.5415, device='cuda:0')],
#  [tensor(137.5433, device='cuda:0')],
#  [tensor(137.5506, device='cuda:0')],
#  [tensor(137.5504, device='cuda:0')],
#  [tensor(137.5498, device='cuda:0')],
#  [tensor(137.5493, device='cuda:0')],
#  [tensor(137.5135, device='cuda:0')],
#  [tensor(137.3516, device='cuda:0')],
#  [tensor(137.4609, device='cuda:0')],
#  [tensor(137.5621, device='cuda:0')],
#  [tensor(136.6197, device='cuda:0')],
#  [tensor(136.4738, device='cuda:0')],
#  [tensor(136.4328, device='cuda:0')],
#  [tensor(136.4085, device='cuda:0')],
#  [tensor(136.3908, device='cuda:0')],
#  [tensor(136.3769, device='cuda:0')],
#  [tensor(136.6677, device='cuda:0')],
#  [tensor(137.4981, device='cuda:0')],
#  [tensor(137.5503, device='cuda:0')],
#  [tensor(137.5544, device='cuda:0')],
#  [tensor(137.5544, device='cuda:0')],
#  [tensor(137.5523, device='cuda:0')],
#  [tensor(137.5485, device='cuda:0')],
#  [tensor(137.5460, device='cuda:0')],
#  [tensor(137.5488, device='cuda:0')],
#  [tensor(137.5460, device='cuda:0')],
#  [tensor(137.5287, device='cuda:0')],
#  [tensor(137.5419, device='cuda:0')],
#  [tensor(137.5292, device='cuda:0')],
#  [tensor(137.4525, device='cuda:0')],
#  [tensor(137.5077, device='cuda:0')],
#  [tensor(137.2957, device='cuda:0')],
#  [tensor(137.5578, device='cuda:0')],
#  [tensor(136.6802, device='cuda:0')],
#  [tensor(136.5210, device='cuda:0')],
#  [tensor(136.4652, device='cuda:0')],
#  [tensor(136.4273, device='cuda:0')],
#  [tensor(136.4076, device='cuda:0')],
#  [tensor(136.3895, device='cuda:0')],
#  [tensor(136.3723, device='cuda:0')],
#  [tensor(136.6454, device='cuda:0')],
#  [tensor(137.5024, device='cuda:0')],
#  [tensor(137.5520, device='cuda:0')],
#  [tensor(137.5568, device='cuda:0')],
#  [tensor(137.5556, device='cuda:0')],
#  [tensor(137.5543, device='cuda:0')],
#  [tensor(137.5516, device='cuda:0')],
#  [tensor(137.5461, device='cuda:0')],
#  [tensor(137.5362, device='cuda:0')],
#  [tensor(137.5297, device='cuda:0')],
#  [tensor(137.5503, device='cuda:0')],
#  [tensor(137.5166, device='cuda:0')],
#  [tensor(137.5349, device='cuda:0')],
#  [tensor(137.5308, device='cuda:0')],
#  [tensor(137.4477, device='cuda:0')],
#  [tensor(137.3495, device='cuda:0')],
#  [tensor(136.7339, device='cuda:0')],
#  [tensor(136.5763, device='cuda:0')],
#  [tensor(136.5088, device='cuda:0')],
#  [tensor(136.4638, device='cuda:0')],
#  [tensor(136.4297, device='cuda:0')],
#  [tensor(136.4057, device='cuda:0')],
#  [tensor(136.3862, device='cuda:0')],
#  [tensor(136.4626, device='cuda:0')],
#  [tensor(136.6726, device='cuda:0')],
#  [tensor(137.5133, device='cuda:0')],
#  [tensor(137.5560, device='cuda:0')],
#  [tensor(137.5607, device='cuda:0')],
#  [tensor(137.5587, device='cuda:0')],
#  [tensor(137.5539, device='cuda:0')],
#  [tensor(137.5541, device='cuda:0')],
#  [tensor(137.5527, device='cuda:0')],
#  [tensor(137.5464, device='cuda:0')],
#  [tensor(137.5339, device='cuda:0')],
#  [tensor(137.5262, device='cuda:0')],
#  [tensor(137.5369, device='cuda:0')],
#  [tensor(137.5320, device='cuda:0')],
#  [tensor(137.5244, device='cuda:0')],
#  [tensor(137.5125, device='cuda:0')],
#  [tensor(137.3349, device='cuda:0')],
#  [tensor(137.1382, device='cuda:0')],
#  [tensor(136.7287, device='cuda:0')],
#  [tensor(136.5309, device='cuda:0')],
#  [tensor(136.4701, device='cuda:0')],
#  [tensor(136.4332, device='cuda:0')],
#  [tensor(136.4068, device='cuda:0')],
#  [tensor(136.3890, device='cuda:0')],
#  [tensor(136.3721, device='cuda:0')],
#  [tensor(136.3556, device='cuda:0')],
#  [tensor(137.4475, device='cuda:0')],
#  [tensor(137.5469, device='cuda:0')],
#  [tensor(137.5563, device='cuda:0')],
#  [tensor(137.5563, device='cuda:0')],
#  [tensor(137.5557, device='cuda:0')],
#  [tensor(137.5533, device='cuda:0')],
#  [tensor(137.5569, device='cuda:0')],
#  [tensor(137.5439, device='cuda:0')],
#  [tensor(137.5383, device='cuda:0')],
#  [tensor(137.5558, device='cuda:0')],
#  [tensor(137.5221, device='cuda:0')],
#  [tensor(137.4997, device='cuda:0')],
#  [tensor(137.4761, device='cuda:0')],
#  [tensor(137.4244, device='cuda:0')],
#  [tensor(137.5597, device='cuda:0')],
#  [tensor(136.7693, device='cuda:0')],
#  [tensor(136.5789, device='cuda:0')],
#  [tensor(136.4338, device='cuda:0')],
#  [tensor(136.4039, device='cuda:0')],
#  [tensor(136.3872, device='cuda:0')],
#  [tensor(136.3727, device='cuda:0')],
#  [tensor(136.3596, device='cuda:0')],
#  [tensor(136.3466, device='cuda:0')],
#  [tensor(136.3448, device='cuda:0')],
#  [tensor(137.4460, device='cuda:0')],
#  [tensor(137.5389, device='cuda:0')],
#  [tensor(137.5435, device='cuda:0')],
#  [tensor(137.5357, device='cuda:0')],
#  [tensor(137.5211, device='cuda:0')],
#  [tensor(137.5006, device='cuda:0')],
#  [tensor(137.4725, device='cuda:0')],
#  [tensor(137.4879, device='cuda:0')],
#  [tensor(137.4607, device='cuda:0')],
#  [tensor(137.5453, device='cuda:0')],
#  [tensor(137.5417, device='cuda:0')],
#  [tensor(137.5281, device='cuda:0')],
#  [tensor(137.4891, device='cuda:0')],
#  [tensor(137.1284, device='cuda:0')],
#  [tensor(136.8100, device='cuda:0')],
#  [tensor(136.6851, device='cuda:0')],
#  [tensor(136.5915, device='cuda:0')],
#  [tensor(136.4462, device='cuda:0')],
#  [tensor(136.4139, device='cuda:0')],
#  [tensor(136.3959, device='cuda:0')],
#  [tensor(136.3818, device='cuda:0')],
#  [tensor(136.3686, device='cuda:0')],
#  [tensor(136.3727, device='cuda:0')],
#  [tensor(136.3595, device='cuda:0')],
#  [tensor(137.5040, device='cuda:0')],
#  [tensor(137.5774, device='cuda:0')],
#  [tensor(137.5856, device='cuda:0')],
#  [tensor(137.5868, device='cuda:0')],
#  [tensor(137.5840, device='cuda:0')],
#  [tensor(137.5830, device='cuda:0')],
#  [tensor(137.5794, device='cuda:0')],
#  [tensor(137.5747, device='cuda:0')],
#  [tensor(137.5696, device='cuda:0')],
#  [tensor(137.5574, device='cuda:0')],
#  [tensor(137.5827, device='cuda:0')],
#  [tensor(137.5372, device='cuda:0')],
#  [tensor(137.5126, device='cuda:0')],
#  [tensor(137.4375, device='cuda:0')],
#  [tensor(137.4021, device='cuda:0')],
#  [tensor(137.4074, device='cuda:0')],
#  [tensor(136.6674, device='cuda:0')],
#  [tensor(136.4638, device='cuda:0')],
#  [tensor(136.4249, device='cuda:0')],
#  [tensor(136.3997, device='cuda:0')],
#  [tensor(136.3914, device='cuda:0')],
#  [tensor(136.3794, device='cuda:0')],
#  [tensor(136.3803, device='cuda:0')],
#  [tensor(136.4735, device='cuda:0')],
#  [tensor(137.5117, device='cuda:0')],
#  [tensor(137.5752, device='cuda:0')],
#  [tensor(137.5809, device='cuda:0')],
#  [tensor(137.5815, device='cuda:0')],
#  [tensor(137.5808, device='cuda:0')],
#  [tensor(137.5776, device='cuda:0')],
#  [tensor(137.5678, device='cuda:0')],
#  [tensor(137.5617, device='cuda:0')],
#  [tensor(137.5526, device='cuda:0')],
#  [tensor(137.5393, device='cuda:0')],
#  [tensor(137.5251, device='cuda:0')],
#  [tensor(137.5039, device='cuda:0')],
#  [tensor(137.4584, device='cuda:0')],
#  [tensor(137.4096, device='cuda:0')],
#  [tensor(137.2314, device='cuda:0')],
#  [tensor(136.7316, device='cuda:0')],
#  [tensor(136.5692, device='cuda:0')],
#  [tensor(136.4579, device='cuda:0')],
#  [tensor(136.4214, device='cuda:0')],
#  [tensor(136.3986, device='cuda:0')],
#  [tensor(136.3800, device='cuda:0')],
#  [tensor(136.3726, device='cuda:0')],
#  [tensor(136.3598, device='cuda:0')],
#  [tensor(136.4069, device='cuda:0')],
#  [tensor(137.4839, device='cuda:0')],
#  [tensor(137.5528, device='cuda:0')],
#  [tensor(137.5593, device='cuda:0')],
#  [tensor(137.5555, device='cuda:0')],
#  [tensor(137.5506, device='cuda:0')],
#  [tensor(137.5476, device='cuda:0')],
#  [tensor(137.5431, device='cuda:0')],
#  [tensor(137.5391, device='cuda:0')],
#  [tensor(137.5305, device='cuda:0')],
#  [tensor(137.5201, device='cuda:0')],
#  [tensor(137.5131, device='cuda:0')],
#  [tensor(137.4968, device='cuda:0')],
#  [tensor(137.4228, device='cuda:0')],
#  [tensor(137.2890, device='cuda:0')],
#  [tensor(137.1852, device='cuda:0')],
#  [tensor(136.8145, device='cuda:0')],
#  [tensor(136.4763, device='cuda:0')],
#  [tensor(136.4231, device='cuda:0')],
#  [tensor(136.3999, device='cuda:0')],
#  [tensor(136.3766, device='cuda:0')],
#  [tensor(136.3687, device='cuda:0')],
#  [tensor(136.3560, device='cuda:0')],
#  [tensor(136.3423, device='cuda:0')],
#  [tensor(136.3362, device='cuda:0')],
#  [tensor(137.4691, device='cuda:0')],
#  [tensor(137.5516, device='cuda:0')],
#  [tensor(137.5592, device='cuda:0')],
#  [tensor(137.5602, device='cuda:0')],
#  [tensor(137.5562, device='cuda:0')],
#  [tensor(137.5523, device='cuda:0')],
#  [tensor(137.5452, device='cuda:0')],
#  [tensor(137.5347, device='cuda:0')],
#  [tensor(137.5064, device='cuda:0')],
#  [tensor(137.4408, device='cuda:0')],
#  [tensor(137.3956, device='cuda:0')],
#  [tensor(137.1149, device='cuda:0')],
#  [tensor(136.9594, device='cuda:0')],
#  [tensor(136.7401, device='cuda:0')],
#  [tensor(136.6326, device='cuda:0')],
#  [tensor(136.5626, device='cuda:0')],
#  [tensor(136.5039, device='cuda:0')],
#  [tensor(136.3902, device='cuda:0')],
#  [tensor(136.3710, device='cuda:0')],
#  [tensor(136.3577, device='cuda:0')],
#  [tensor(136.3443, device='cuda:0')],
#  [tensor(136.3309, device='cuda:0')],
#  [tensor(136.3301, device='cuda:0')],
#  [tensor(136.3302, device='cuda:0')],
#  [tensor(137.4695, device='cuda:0')],
#  [tensor(137.5558, device='cuda:0')],
#  [tensor(137.5661, device='cuda:0')],
#  [tensor(137.5667, device='cuda:0')],
#  [tensor(137.5570, device='cuda:0')],
#  [tensor(137.5498, device='cuda:0')],
#  [tensor(137.5446, device='cuda:0')],
#  [tensor(137.5346, device='cuda:0')],
#  [tensor(137.5409, device='cuda:0')],
#  [tensor(137.5305, device='cuda:0')],
#  [tensor(137.5063, device='cuda:0')],
#  [tensor(137.4279, device='cuda:0')],
#  [tensor(137.0188, device='cuda:0')],
#  [tensor(136.7530, device='cuda:0')],
#  [tensor(136.6380, device='cuda:0')],
#  [tensor(136.5704, device='cuda:0')],
#  [tensor(136.5084, device='cuda:0')],
#  [tensor(136.4418, device='cuda:0')],
#  [tensor(136.4047, device='cuda:0')],
#  [tensor(136.3750, device='cuda:0')],
#  [tensor(136.3737, device='cuda:0')],
#  [tensor(136.3593, device='cuda:0')],
#  [tensor(136.3486, device='cuda:0')],
#  [tensor(136.3327, device='cuda:0')],
#  [tensor(137.4433, device='cuda:0')],
#  [tensor(137.5435, device='cuda:0')],
#  [tensor(137.5460, device='cuda:0')],
#  [tensor(137.5847, device='cuda:0')],
#  [tensor(137.5153, device='cuda:0')],
#  [tensor(137.4834, device='cuda:0')],
#  [tensor(137.4435, device='cuda:0')],
#  [tensor(137.3935, device='cuda:0')],
#  [tensor(137.3261, device='cuda:0')],
#  [tensor(137.2453, device='cuda:0')],
#  [tensor(137.2151, device='cuda:0')],
#  [tensor(137.1127, device='cuda:0')],
#  [tensor(136.9861, device='cuda:0')],
#  [tensor(136.8555, device='cuda:0')],
#  [tensor(136.6826, device='cuda:0')],
#  [tensor(136.6039, device='cuda:0')],
#  [tensor(136.4420, device='cuda:0')],
#  [tensor(136.4053, device='cuda:0')],
#  [tensor(136.3884, device='cuda:0')],
#  [tensor(136.3747, device='cuda:0')],
#  [tensor(136.3629, device='cuda:0')],
#  [tensor(136.3530, device='cuda:0')],
#  [tensor(136.3419, device='cuda:0')],
#  [tensor(136.3262, device='cuda:0')],
#  [tensor(137.3343, device='cuda:0')],
#  [tensor(137.5089, device='cuda:0')],
#  [tensor(137.5829, device='cuda:0')],
#  [tensor(137.5715, device='cuda:0')],
#  [tensor(137.5460, device='cuda:0')],
#  [tensor(137.5671, device='cuda:0')],
#  [tensor(137.5375, device='cuda:0')],
#  [tensor(137.4867, device='cuda:0')],
#  [tensor(137.4225, device='cuda:0')],
#  [tensor(137.3434, device='cuda:0')],
#  [tensor(137.2390, device='cuda:0')],
#  [tensor(137.1138, device='cuda:0')],
#  [tensor(136.9780, device='cuda:0')],
#  [tensor(136.8425, device='cuda:0')],
#  [tensor(136.6255, device='cuda:0')],
#  [tensor(136.5604, device='cuda:0')],
#  [tensor(136.5114, device='cuda:0')],
#  [tensor(136.4809, device='cuda:0')],
#  [tensor(136.4581, device='cuda:0')],
#  [tensor(136.4408, device='cuda:0')],
#  [tensor(136.4279, device='cuda:0')],
#  [tensor(136.4165, device='cuda:0')],
#  [tensor(136.4125, device='cuda:0')],
#  [tensor(136.4062, device='cuda:0')],
#  [tensor(137.6025, device='cuda:0')],
#  [tensor(137.6783, device='cuda:0')],
#  [tensor(137.6812, device='cuda:0')],
#  [tensor(137.6799, device='cuda:0')],
#  [tensor(137.6767, device='cuda:0')],
#  [tensor(137.6745, device='cuda:0')],
#  [tensor(137.6704, device='cuda:0')],
#  [tensor(137.6644, device='cuda:0')],
#  [tensor(137.6563, device='cuda:0')],
#  [tensor(137.6451, device='cuda:0')],
#  [tensor(137.6290, device='cuda:0')],
#  [tensor(137.6085, device='cuda:0')],
#  [tensor(137.5735, device='cuda:0')],
#  [tensor(137.4939, device='cuda:0')],
#  [tensor(137.1990, device='cuda:0')],
#  [tensor(136.9248, device='cuda:0')],
#  [tensor(136.6525, device='cuda:0')],
#  [tensor(136.5581, device='cuda:0')],
#  [tensor(136.5108, device='cuda:0')],
#  [tensor(136.4754, device='cuda:0')],
#  [tensor(136.4530, device='cuda:0')],
#  [tensor(136.4352, device='cuda:0')],
#  [tensor(136.4207, device='cuda:0')],
#  [tensor(136.4775, device='cuda:0')],
#  [tensor(137.5789, device='cuda:0')],
#  [tensor(137.6479, device='cuda:0')],
#  [tensor(137.6519, device='cuda:0')],
#  [tensor(137.6510, device='cuda:0')],
#  [tensor(137.6359, device='cuda:0')],
#  [tensor(137.6436, device='cuda:0')],
#  [tensor(137.6389, device='cuda:0')],
#  [tensor(137.6369, device='cuda:0')],
#  [tensor(137.6288, device='cuda:0')],
#  [tensor(137.6174, device='cuda:0')],
#  [tensor(137.6021, device='cuda:0')],
#  [tensor(137.5579, device='cuda:0')],
#  [tensor(137.4680, device='cuda:0')],
#  [tensor(137.3752, device='cuda:0')],
#  [tensor(137.1346, device='cuda:0')],
#  [tensor(136.8600, device='cuda:0')],
#  [tensor(136.5499, device='cuda:0')],
#  [tensor(136.4708, device='cuda:0')],
#  [tensor(136.4312, device='cuda:0')],
#  [tensor(136.3959, device='cuda:0')],
#  [tensor(136.3830, device='cuda:0')],
#  [tensor(136.3675, device='cuda:0')],
#  [tensor(136.3533, device='cuda:0')],
#  [tensor(136.3379, device='cuda:0')],
#  [tensor(137.4662, device='cuda:0')],
#  [tensor(137.5488, device='cuda:0')],
#  [tensor(137.5558, device='cuda:0')],
#  [tensor(137.5571, device='cuda:0')],
#  [tensor(137.5538, device='cuda:0')],
#  [tensor(137.5497, device='cuda:0')],
#  [tensor(137.5454, device='cuda:0')],
#  [tensor(137.5504, device='cuda:0')],
#  [tensor(137.5305, device='cuda:0')],
#  [tensor(137.5173, device='cuda:0')],
#  [tensor(137.5028, device='cuda:0')],
#  [tensor(137.4811, device='cuda:0')],
#  [tensor(137.4181, device='cuda:0')],
#  [tensor(137.3070, device='cuda:0')],
#  [tensor(137.1759, device='cuda:0')],
#  [tensor(136.6948, device='cuda:0')],
#  [tensor(136.5349, device='cuda:0')],
#  [tensor(136.4286, device='cuda:0')],
#  [tensor(136.4019, device='cuda:0')],
#  [tensor(136.3657, device='cuda:0')],
#  [tensor(136.3533, device='cuda:0')],
#  [tensor(136.3556, device='cuda:0')],
#  [tensor(136.3451, device='cuda:0')],
#  [tensor(136.3359, device='cuda:0')],
#  [tensor(137.4740, device='cuda:0')],
#  [tensor(137.5536, device='cuda:0')],
#  [tensor(137.5618, device='cuda:0')],
#  [tensor(137.5626, device='cuda:0')],
#  [tensor(137.5573, device='cuda:0')],
#  [tensor(137.5563, device='cuda:0')],
#  [tensor(137.5515, device='cuda:0')],
#  [tensor(137.5448, device='cuda:0')],
#  [tensor(137.5368, device='cuda:0')],
#  [tensor(137.5262, device='cuda:0')],
#  [tensor(137.5443, device='cuda:0')],
#  [tensor(137.5381, device='cuda:0')],
#  [tensor(137.4283, device='cuda:0')],
#  [tensor(137.3068, device='cuda:0')],
#  [tensor(137.1272, device='cuda:0')],
#  [tensor(136.7740, device='cuda:0')],
#  [tensor(136.5727, device='cuda:0')],
#  [tensor(136.5002, device='cuda:0')],
#  [tensor(136.4576, device='cuda:0')],
#  [tensor(136.4253, device='cuda:0')],
#  [tensor(136.4032, device='cuda:0')],
#  [tensor(136.3851, device='cuda:0')],
#  [tensor(136.3677, device='cuda:0')],
#  [tensor(136.3529, device='cuda:0')],
#  [tensor(137.4836, device='cuda:0')],
#  [tensor(137.5551, device='cuda:0')],
#  [tensor(137.5614, device='cuda:0')],
#  [tensor(137.5614, device='cuda:0')],
#  [tensor(137.5595, device='cuda:0')],
#  [tensor(137.5560, device='cuda:0')],
#  [tensor(137.5181, device='cuda:0')],
#  [tensor(137.5535, device='cuda:0')],
#  [tensor(137.5528, device='cuda:0')],
#  [tensor(137.5202, device='cuda:0')],
#  [tensor(137.5012, device='cuda:0')],
#  [tensor(137.4585, device='cuda:0')],
#  [tensor(137.4167, device='cuda:0')],
#  [tensor(137.3860, device='cuda:0')],
#  [tensor(137.1824, device='cuda:0')],
#  [tensor(136.7043, device='cuda:0')],
#  [tensor(136.5659, device='cuda:0')],
#  [tensor(136.4856, device='cuda:0')],
#  [tensor(136.4471, device='cuda:0')],
#  [tensor(136.4192, device='cuda:0')],
#  [tensor(136.3975, device='cuda:0')],
#  [tensor(136.3791, device='cuda:0')],
#  [tensor(136.3660, device='cuda:0')],
#  [tensor(136.3439, device='cuda:0')],
#  [tensor(137.4340, device='cuda:0')],
#  [tensor(137.5316, device='cuda:0')],
#  [tensor(137.5444, device='cuda:0')],
#  [tensor(137.5369, device='cuda:0')],
#  [tensor(137.5222, device='cuda:0')],
#  [tensor(137.4975, device='cuda:0')],
#  [tensor(137.4270, device='cuda:0')],
#  [tensor(137.4244, device='cuda:0')],
#  [tensor(137.3754, device='cuda:0')],
#  [tensor(137.3148, device='cuda:0')],
#  [tensor(137.2377, device='cuda:0')],
#  [tensor(137.1328, device='cuda:0')],
#  [tensor(137.0086, device='cuda:0')],
#  [tensor(136.8678, device='cuda:0')],
#  [tensor(136.7509, device='cuda:0')],
#  [tensor(136.6672, device='cuda:0')],
#  [tensor(136.5536, device='cuda:0')],
#  [tensor(136.4738, device='cuda:0')],
#  [tensor(136.4142, device='cuda:0')],
#  [tensor(136.3817, device='cuda:0')],
#  [tensor(136.3788, device='cuda:0')],
#  [tensor(136.3867, device='cuda:0')],
#  [tensor(136.3763, device='cuda:0')],
#  [tensor(136.3565, device='cuda:0')],
#  [tensor(137.4329, device='cuda:0')],
#  [tensor(137.5478, device='cuda:0')],
#  [tensor(137.5444, device='cuda:0')],
#  [tensor(137.5234, device='cuda:0')],
#  [tensor(137.4921, device='cuda:0')],
#  [tensor(137.4514, device='cuda:0')],
#  [tensor(137.3931, device='cuda:0')],
#  [tensor(137.3218, device='cuda:0')],
#  [tensor(137.2284, device='cuda:0')],
#  [tensor(137.2742, device='cuda:0')],
#  [tensor(137.2632, device='cuda:0')],
#  [tensor(137.1637, device='cuda:0')],
#  [tensor(137.0351, device='cuda:0')],
#  [tensor(136.8515, device='cuda:0')],
#  [tensor(136.7319, device='cuda:0')],
#  [tensor(136.6393, device='cuda:0')],
#  [tensor(136.5608, device='cuda:0')],
#  [tensor(136.4687, device='cuda:0')],
#  [tensor(136.4293, device='cuda:0')],
#  [tensor(136.4142, device='cuda:0')],
#  [tensor(136.4021, device='cuda:0')],
#  [tensor(136.3918, device='cuda:0')],
#  [tensor(136.3878, device='cuda:0')],
#  [tensor(136.3902, device='cuda:0')],
#  [tensor(137.5627, device='cuda:0')],
#  [tensor(137.6436, device='cuda:0')],
#  [tensor(137.6483, device='cuda:0')],
#  [tensor(137.6490, device='cuda:0')],
#  [tensor(137.6460, device='cuda:0')],
#  [tensor(137.6434, device='cuda:0')],
#  [tensor(137.6385, device='cuda:0')],
#  [tensor(137.6449, device='cuda:0')],
#  [tensor(137.6421, device='cuda:0')],
#  [tensor(137.6368, device='cuda:0')],
#  [tensor(137.6028, device='cuda:0')],
#  [tensor(137.5688, device='cuda:0')],
#  [tensor(137.5315, device='cuda:0')],
#  [tensor(137.4797, device='cuda:0')],
#  [tensor(137.3310, device='cuda:0')],
#  [tensor(136.7630, device='cuda:0')],
#  [tensor(136.6106, device='cuda:0')],
#  [tensor(136.5328, device='cuda:0')],
#  [tensor(136.4885, device='cuda:0')],
#  [tensor(136.4452, device='cuda:0')],
#  [tensor(136.4238, device='cuda:0')],
#  [tensor(136.4156, device='cuda:0')],
#  [tensor(136.4014, device='cuda:0')],
#  [tensor(136.4166, device='cuda:0')],
#  [tensor(137.5440, device='cuda:0')],
#  [tensor(137.6140, device='cuda:0')],
#  [tensor(137.6194, device='cuda:0')],
#  [tensor(137.6228, device='cuda:0')],
#  [tensor(137.5999, device='cuda:0')],
#  [tensor(137.6204, device='cuda:0')],
#  [tensor(137.6197, device='cuda:0')],
#  [tensor(137.6174, device='cuda:0')],
#  [tensor(137.6147, device='cuda:0')],
#  [tensor(137.6098, device='cuda:0')],
#  [tensor(137.6039, device='cuda:0')],
#  [tensor(137.5933, device='cuda:0')],
#  [tensor(137.5818, device='cuda:0')],
#  [tensor(137.4412, device='cuda:0')],
#  [tensor(137.3575, device='cuda:0')],
#  [tensor(137.1659, device='cuda:0')],
#  [tensor(136.5877, device='cuda:0')],
#  [tensor(136.4439, device='cuda:0')],
#  [tensor(136.4115, device='cuda:0')],
#  [tensor(136.3919, device='cuda:0')],
#  [tensor(136.3758, device='cuda:0')],
#  [tensor(136.3813, device='cuda:0')],
#  [tensor(136.3653, device='cuda:0')],
#  [tensor(136.3661, device='cuda:0')],
#  [tensor(137.4795, device='cuda:0')],
#  [tensor(137.5486, device='cuda:0')],
#  [tensor(137.5581, device='cuda:0')],
#  [tensor(137.5542, device='cuda:0')],
#  [tensor(137.5487, device='cuda:0')],
#  [tensor(137.5486, device='cuda:0')],
#  [tensor(137.5439, device='cuda:0')],
#  [tensor(137.5371, device='cuda:0')],
#  [tensor(137.5459, device='cuda:0')],
#  [tensor(137.5430, device='cuda:0')],
#  [tensor(137.5381, device='cuda:0')],
#  [tensor(137.5304, device='cuda:0')],
#  [tensor(137.5101, device='cuda:0')],
#  [tensor(137.4944, device='cuda:0')],
#  [tensor(137.4735, device='cuda:0')],
#  [tensor(136.7540, device='cuda:0')],
#  [tensor(136.5316, device='cuda:0')],
#  [tensor(136.4283, device='cuda:0')],
#  [tensor(136.4019, device='cuda:0')],
#  [tensor(136.3855, device='cuda:0')],
#  [tensor(136.3717, device='cuda:0')],
#  [tensor(136.3695, device='cuda:0')],
#  [tensor(136.3555, device='cuda:0')],
#  [tensor(136.3921, device='cuda:0')],
#  [tensor(137.4820, device='cuda:0')],
#  [tensor(137.5520, device='cuda:0')],
#  [tensor(137.5591, device='cuda:0')],
#  [tensor(137.5605, device='cuda:0')],
#  [tensor(137.5595, device='cuda:0')],
#  [tensor(137.5564, device='cuda:0')],
#  [tensor(137.5526, device='cuda:0')],
#  [tensor(137.5513, device='cuda:0')],
#  [tensor(137.5480, device='cuda:0')],
#  [tensor(137.5429, device='cuda:0')],
#  [tensor(137.5374, device='cuda:0')],
#  [tensor(137.5296, device='cuda:0')],
#  [tensor(137.5192, device='cuda:0')],
#  [tensor(137.5050, device='cuda:0')],
#  [tensor(136.8046, device='cuda:0')],
#  [tensor(136.6345, device='cuda:0')],
#  [tensor(136.6879, device='cuda:0')],
#  [tensor(136.5074, device='cuda:0')],
#  [tensor(136.4527, device='cuda:0')],
#  [tensor(136.4039, device='cuda:0')],
#  [tensor(136.3976, device='cuda:0')],
#  [tensor(136.3798, device='cuda:0')],
#  [tensor(136.3634, device='cuda:0')],
#  [tensor(136.3487, device='cuda:0')],
#  [tensor(137.4799, device='cuda:0')],
#  [tensor(137.5522, device='cuda:0')],
#  [tensor(137.5595, device='cuda:0')],
#  [tensor(137.5601, device='cuda:0')],
#  [tensor(137.5528, device='cuda:0')],
#  [tensor(137.5566, device='cuda:0')],
#  [tensor(137.5530, device='cuda:0')],
#  [tensor(137.5480, device='cuda:0')],
#  [tensor(137.5434, device='cuda:0')],
#  [tensor(137.5377, device='cuda:0')],
#  [tensor(137.5313, device='cuda:0')],
#  [tensor(137.5317, device='cuda:0')],
#  [tensor(137.5241, device='cuda:0')],
#  [tensor(136.9077, device='cuda:0')],
#  [tensor(136.7117, device='cuda:0')],
#  [tensor(136.6206, device='cuda:0')],
#  [tensor(136.5109, device='cuda:0')],
#  [tensor(136.4260, device='cuda:0')],
#  [tensor(136.3981, device='cuda:0')],
#  [tensor(136.3696, device='cuda:0')],
#  [tensor(136.3558, device='cuda:0')],
#  [tensor(136.3490, device='cuda:0')],
#  [tensor(136.7195, device='cuda:0')],
#  [tensor(136.3529, device='cuda:0')],
#  [tensor(137.4358, device='cuda:0')],
#  [tensor(137.5418, device='cuda:0')],
#  [tensor(137.5482, device='cuda:0')],
#  [tensor(137.5432, device='cuda:0')],
#  [tensor(137.5301, device='cuda:0')],
#  [tensor(137.4707, device='cuda:0')],
#  [tensor(137.4258, device='cuda:0')],
#  [tensor(137.3758, device='cuda:0')],
#  [tensor(137.3095, device='cuda:0')],
#  [tensor(137.2339, device='cuda:0')],
#  [tensor(137.4993, device='cuda:0')],
#  [tensor(137.5003, device='cuda:0')],
#  [tensor(136.9680, device='cuda:0')],
#  [tensor(136.7208, device='cuda:0')],
#  [tensor(136.5490, device='cuda:0')],
#  [tensor(136.4987, device='cuda:0')],
#  [tensor(136.4578, device='cuda:0')],
#  [tensor(136.4294, device='cuda:0')],
#  ...]

# %%
plt.plot(real[0])
plt.plot(pred[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 2
#       1 plt.plot(real[0])
# ----> 2 plt.plot(pred[0:24])
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:491, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     489     y = _check_1d(xy[1])
#     490 else:
# --> 491     x, y = index_of(xy[-1])
#     493 if axes.xaxis is not None:
#     494     axes.xaxis.update_units(x)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/cbook.py:1666, in index_of(y)
#    1664     pass
#    1665 try:
# -> 1666     y = _check_1d(y)
#    1667 except (VisibleDeprecationWarning, ValueError):
#    1668     # NumPy 1.19 will warn on ragged input, and we can't actually use it.
#    1669     pass
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/cbook.py:1358, in _check_1d(x)
#    1352 # plot requires `shape` and `ndim`.  If passed an
#    1353 # object that doesn't provide them, then force to numpy array.
#    1354 # Note this will strip unit information.
#    1355 if (not hasattr(x, 'shape') or
#    1356         not hasattr(x, 'ndim') or
#    1357         len(x.shape) < 1):
# -> 1358     return np.atleast_1d(x)
#    1359 else:
#    1360     return x
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/shape_base.py:65, in atleast_1d(*arys)
#      63 res = []
#      64 for ary in arys:
# ---> 65     ary = asanyarray(ary)
#      66     if ary.ndim == 0:
#      67         result = ary.reshape(1)
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/torch/_tensor.py:970, in Tensor.__array__(self, dtype)
#     968     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#     969 if dtype is None:
# --> 970     return self.numpy()
#     971 else:
#     972     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
