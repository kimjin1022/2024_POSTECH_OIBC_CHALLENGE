# %% [markdown]
# # Import

# %%
import sys
import sktime
import tqdm as tq
import xgboost as xgb
import matplotlib
import seaborn as sns
import sklearn as skl
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from tqdm import tqdm
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.utils.plotting import plot_series
from xgboost import XGBRegressor

from evaluate import calculate_measure
from datetime import datetime, timedelta
import requests
import json 

API_KEY = """eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJlcXpORXlBR1ZiNDdadUNpN2RLZ1hqIiwiaWF0IjoxNzMwMDcyODI2LCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.zsJAvYixxcUwz4ad-y2cWwi6oWdc1hmegSTFSbeMuzk"""

# %% [markdown]
# # Data Preprocess

# %%
base_path = "/home/jinjinjara1022/"

weather_forecast_data_1 = pd.read_csv(base_path + "OBIC/data2/기상예측데이터_1_11-7.csv")
jeju_power_market_day_ahead = pd.read_csv(base_path + "OBIC/data2/제주전력시장_시장전기가격_하루전가격_11-7.csv")

# %%
weather_forecast_data_1 = weather_forecast_data_1[weather_forecast_data_1['location'] != 'location']
weather_forecast_data_1['ts'] =  pd.to_datetime(weather_forecast_data_1['ts'], unit='s')
weather_forecast_data_1['base_ts'] = pd.to_datetime(weather_forecast_data_1['base_ts'], unit='s')
# Out:
# /tmp/ipykernel_1297964/796732019.py:2: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   weather_forecast_data_1['ts'] =  pd.to_datetime(weather_forecast_data_1['ts'], unit='s')
# /tmp/ipykernel_1297964/796732019.py:3: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   weather_forecast_data_1['base_ts'] = pd.to_datetime(weather_forecast_data_1['base_ts'], unit='s')

# %%
# 평균을 구할 열 리스트
columns_to_average = [
    'temp', 'real_feel_temp', 'wet_bulb_temp', 'dew_point', 
    'wind_dir', 'wind_spd', 'wind_gust_spd', 'rel_hum', 'vis', 
    'ceiling', 'uv_idx', 'precip_prob', 'rain_prob', 'snow_prob', 
    'ice_prob', 'total_liq', 'rain', 'snow', 'ice', 'cld_cvr'
]

# 숫자형으로 변환할 수 있는 값만 변환
weather_forecast_data_1[columns_to_average] = weather_forecast_data_1[columns_to_average].apply(pd.to_numeric, errors='coerce')

# %%
# 'ts'로 그룹화하여 각 열의 평균 계산
average_df = weather_forecast_data_1.groupby('ts', as_index=False)[columns_to_average].mean()

weather_df = average_df

ahead_df = jeju_power_market_day_ahead

ahead_df['ts'] = pd.to_datetime(ahead_df['ts'], unit='s')

# %%
df = pd.merge(weather_df, ahead_df, on='ts')

# %%
df['hour'] = df['ts'].dt.hour
df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)

df['month'] = df['ts'].dt.month
df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)

df['day_of_week'] = df['ts'].dt.dayofweek
df['day_of_week_sin'] = np.sin(2 * np.pi * df['day_of_week'] / 7)
df['day_of_week_cos'] = np.cos(2 * np.pi * df['day_of_week'] / 7)

# %%
df.rename(columns={
    '하루전가격(원/kWh)': 'previous_price_kwh'
}, inplace=True)

# %%
df = df.drop(['ts','hour', 'month', 'day_of_week'], axis=1)

# %%
df['previous_day_price'] = df['previous_price_kwh'].shift(24)
df['previous_2day_price'] = df['previous_price_kwh'].shift(48)
df['previous_3day_price'] = df['previous_price_kwh'].shift(72)

# %%
df = df[72:]
df = df[[ 
    'previous_day_price', 'previous_2day_price', 'previous_3day_price', 
    'uv_idx', 'month_cos', 'month_sin','day_of_week_cos',
    'day_of_week_sin', 'rel_hum', 'hour_cos', 'wind_spd', 'cld_cvr',
    'hour_sin', 'wind_gust_spd', 'dew_point', 'real_feel_temp', 'ceiling',
    'wind_dir', 'wet_bulb_temp', 'temp', 'precip_prob', 'vis', 'rain_prob',
    'rain', 'total_liq', 'previous_price_kwh'
    ]]

# %%
y = df['previous_price_kwh']
x = df.drop(['previous_price_kwh'], axis=1)

# %%
y_train, y_valid, x_train, x_valid = temporal_train_test_split(y = y, X = x, test_size = int(len(y) * 0.1))
print('train data shape\nx:{}, y:{}'.format(x_train.shape, y_train.shape))
# Out:
# train data shape
# x:(5337, 25), y:(5337,)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# 스케일링할 열 선택
columns_to_scale = ['uv_idx', 'rel_hum', 'wind_spd', 'cld_cvr',
                        'wind_gust_spd', 'dew_point', 'real_feel_temp', 'ceiling',
                        'wind_dir', 'wet_bulb_temp', 'temp', 'precip_prob', 'vis', 
                    'rain_prob', 'rain', 'total_liq']

# %%
scaler1 = StandardScaler()

x_train[columns_to_scale] = scaler1.fit_transform(x_train[columns_to_scale])
x_valid[columns_to_scale] = scaler1.transform(x_valid[columns_to_scale])

# scaler2 = StandardScaler()

# x_train[columns_to_scale] = scaler2.fit_transform(x_train[columns_to_scale])
# x_valid[columns_to_scale] = scaler2.transform(x_valid[columns_to_scale])

# %% [markdown]
# # Train

# %%
import xgboost as xgb
print(xgb.__version__)
# Out:
# 2.1.1

# %%
xgb_reg = XGBRegressor(
    n_estimators=900,
    learning_rate=0.01, 
    min_child_weight=0.5,
    max_depth=6,
    colsample_bytree=0.8,
    subsample=0.8,
    tree_method='hist',
    device='cuda:0',
    seed=0,
    early_stopping_rounds=500 
)

xgb_reg.fit(
    x_train, y_train, 
    eval_set=[(x_train, y_train), (x_valid, y_valid)], 
    verbose=False
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda:0', early_stopping_rounds=500,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=0.5, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=900, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
def SMAPE(true, pred):
    return np.mean((np.abs(true-pred))/(np.abs(true) + np.abs(pred))) * 100

pred = xgb_reg.predict(x_valid)
pred = pd.Series(pred)
pred.index = np.arange(y_valid.index[0], y_valid.index[-1]+1)

plot_series(y_train, y_valid, pd.Series(pred), markers=[',' , ',', ','])

print('SMAPE : {}'.format(SMAPE(y_valid, pred)))
# Out:
# /home/jinjinjara1022/.local/lib/python3.10/site-packages/xgboost/core.py:158: UserWarning: [10:40:12] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# SMAPE : 12.022158434677067

# %%
plt.figure(figsize=(20, 5))
pred.plot(label='predict_price')
y_valid.plot()
plt.legend()
plt.show()

# %%
# 피쳐 중요도 시각화
xgb.plot_importance(xgb_reg, importance_type='weight')
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# # Parameter Tuning

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

def objective(trial):
    # 파라미터 제안 범위 설정
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1.0),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'tree_method': 'hist',
        'device': 'cuda:0',
        'seed': 0,
        'early_stopping_rounds' : 50
    }
    
    model = XGBRegressor(**param)
    
    eval_set = [(x_train, y_train), (x_valid, y_valid)]  # 학습 데이터와 검증 데이터 설정
    model.fit(x_train, y_train, 
              eval_set=eval_set,  # eval_set 사용
              verbose=False)
    
    preds = model.predict(x_valid)
    mse = SMAPE(y_valid, preds)
    return mse

# Optuna 스터디 생성
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2024-11-07 15:33:31,545] A new study created in memory with name: no-name-cd1c89f3-444d-4c5b-9822-13cd4c50cbe5
# [I 2024-11-07 15:33:31,707] Trial 0 finished with value: 12.865211092971302 and parameters: {'n_estimators': 694, 'learning_rate': 0.23396711478898502, 'max_depth': 3, 'min_child_weight': 3, 'colsample_bytree': 0.38118440258108993, 'subsample': 0.54526670665963}. Best is trial 0 with value: 12.865211092971302.
# [I 2024-11-07 15:33:31,969] Trial 1 finished with value: 12.935682693925607 and parameters: {'n_estimators': 869, 'learning_rate': 0.2952636518997939, 'max_depth': 9, 'min_child_weight': 4, 'colsample_bytree': 0.721376969192604, 'subsample': 0.6265852022848857}. Best is trial 0 with value: 12.865211092971302.
# [I 2024-11-07 15:33:32,169] Trial 2 finished with value: 12.77694075033295 and parameters: {'n_estimators': 834, 'learning_rate': 0.2717053992624272, 'max_depth': 7, 'min_child_weight': 2, 'colsample_bytree': 0.3880562613713664, 'subsample': 0.606812951576791}. Best is trial 2 with value: 12.77694075033295.
# [I 2024-11-07 15:33:32,439] Trial 3 finished with value: 12.21184617671013 and parameters: {'n_estimators': 989, 'learning_rate': 0.14022783002204295, 'max_depth': 5, 'min_child_weight': 10, 'colsample_bytree': 0.9551133509963456, 'subsample': 0.7398798355230753}. Best is trial 3 with value: 12.21184617671013.
# [I 2024-11-07 15:33:32,642] Trial 4 finished with value: 12.408581991687036 and parameters: {'n_estimators': 689, 'learning_rate': 0.20176332105035394, 'max_depth': 5, 'min_child_weight': 7, 'colsample_bytree': 0.8224515010998352, 'subsample': 0.8845085987401452}. Best is trial 3 with value: 12.21184617671013.
# [I 2024-11-07 15:33:32,931] Trial 5 finished with value: 12.252384778951114 and parameters: {'n_estimators': 565, 'learning_rate': 0.29062970388260184, 'max_depth': 7, 'min_child_weight': 4, 'colsample_bytree': 0.7676429139402607, 'subsample': 0.9417511822693261}. Best is trial 3 with value: 12.21184617671013.
# [I 2024-11-07 15:33:33,313] Trial 6 finished with value: 13.29686418419784 and parameters: {'n_estimators': 400, 'learning_rate': 0.2418336448396716, 'max_depth': 9, 'min_child_weight': 3, 'colsample_bytree': 0.315784263840834, 'subsample': 0.6030708140859107}. Best is trial 3 with value: 12.21184617671013.
# [I 2024-11-07 15:33:33,786] Trial 7 finished with value: 12.275358847063947 and parameters: {'n_estimators': 500, 'learning_rate': 0.13197910111507183, 'max_depth': 6, 'min_child_weight': 2, 'colsample_bytree': 0.7245052391803453, 'subsample': 0.5640007302012373}. Best is trial 3 with value: 12.21184617671013.
# [I 2024-11-07 15:33:34,178] Trial 8 finished with value: 12.546508119895686 and parameters: {'n_estimators': 145, 'learning_rate': 0.1329066503533875, 'max_depth': 8, 'min_child_weight': 4, 'colsample_bytree': 0.5360819720657717, 'subsample': 0.9113398500519957}. Best is trial 3 with value: 12.21184617671013.
# [I 2024-11-07 15:33:34,484] Trial 9 finished with value: 12.791839598016102 and parameters: {'n_estimators': 292, 'learning_rate': 0.2255256225058012, 'max_depth': 8, 'min_child_weight': 3, 'colsample_bytree': 0.871426041804835, 'subsample': 0.5772486391747907}. Best is trial 3 with value: 12.21184617671013.
# [I 2024-11-07 15:33:34,821] Trial 10 finished with value: 11.981452583463081 and parameters: {'n_estimators': 986, 'learning_rate': 0.046048158067050635, 'max_depth': 3, 'min_child_weight': 10, 'colsample_bytree': 0.9979408128542184, 'subsample': 0.7342087857732126}. Best is trial 10 with value: 11.981452583463081.
# [I 2024-11-07 15:33:35,287] Trial 11 finished with value: 11.846129932359316 and parameters: {'n_estimators': 953, 'learning_rate': 0.038366157847542506, 'max_depth': 3, 'min_child_weight': 10, 'colsample_bytree': 0.9990099131606119, 'subsample': 0.7533439000771409}. Best is trial 11 with value: 11.846129932359316.
# [I 2024-11-07 15:33:35,817] Trial 12 finished with value: 11.964498547479847 and parameters: {'n_estimators': 996, 'learning_rate': 0.026832556987957373, 'max_depth': 3, 'min_child_weight': 10, 'colsample_bytree': 0.9894449009667529, 'subsample': 0.7618929449757169}. Best is trial 11 with value: 11.846129932359316.
# [I 2024-11-07 15:33:36,828] Trial 13 finished with value: 11.794431639079287 and parameters: {'n_estimators': 823, 'learning_rate': 0.012174639819666738, 'max_depth': 4, 'min_child_weight': 8, 'colsample_bytree': 0.927715797517337, 'subsample': 0.8114640619853408}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:37,246] Trial 14 finished with value: 12.285099523598536 and parameters: {'n_estimators': 806, 'learning_rate': 0.07499900048993503, 'max_depth': 4, 'min_child_weight': 8, 'colsample_bytree': 0.5483539702522742, 'subsample': 0.8067347708549845}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:37,622] Trial 15 finished with value: 12.083295165029922 and parameters: {'n_estimators': 710, 'learning_rate': 0.08084566264462463, 'max_depth': 4, 'min_child_weight': 8, 'colsample_bytree': 0.8981105772917739, 'subsample': 0.8532329351678666}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:38,833] Trial 16 finished with value: 11.951186381994935 and parameters: {'n_estimators': 875, 'learning_rate': 0.018425305409752034, 'max_depth': 5, 'min_child_weight': 7, 'colsample_bytree': 0.6287098405828833, 'subsample': 0.6785234850675266}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:39,141] Trial 17 finished with value: 11.81354275262883 and parameters: {'n_estimators': 553, 'learning_rate': 0.08943816529270313, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.8996957124623268, 'subsample': 0.9963098110824272}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:39,543] Trial 18 finished with value: 12.345557392730406 and parameters: {'n_estimators': 578, 'learning_rate': 0.08934785987774264, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.8405064263584121, 'subsample': 0.9952776091081006}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:39,777] Trial 19 finished with value: 11.872345538023074 and parameters: {'n_estimators': 304, 'learning_rate': 0.0997182940596143, 'max_depth': 4, 'min_child_weight': 6, 'colsample_bytree': 0.9278682373362612, 'subsample': 0.9643475044931908}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:40,398] Trial 20 finished with value: 12.023345866035484 and parameters: {'n_estimators': 467, 'learning_rate': 0.05049424551794015, 'max_depth': 10, 'min_child_weight': 9, 'colsample_bytree': 0.7804972709574317, 'subsample': 0.8094840079342335}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:41,527] Trial 21 finished with value: 11.810876039605644 and parameters: {'n_estimators': 733, 'learning_rate': 0.010619192713023032, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.9041097881276162, 'subsample': 0.7070083769332416}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:42,332] Trial 22 finished with value: 11.90939090915323 and parameters: {'n_estimators': 764, 'learning_rate': 0.016785820623354104, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.9128075977274118, 'subsample': 0.6839006810845147}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:42,562] Trial 23 finished with value: 12.50621244010832 and parameters: {'n_estimators': 619, 'learning_rate': 0.17342577334333684, 'max_depth': 5, 'min_child_weight': 6, 'colsample_bytree': 0.8282769029997019, 'subsample': 0.6786150823274507}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:42,924] Trial 24 finished with value: 11.923530850926454 and parameters: {'n_estimators': 639, 'learning_rate': 0.0688695016821656, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.6672794113005843, 'subsample': 0.8456398168920374}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:43,173] Trial 25 finished with value: 12.092783539434071 and parameters: {'n_estimators': 764, 'learning_rate': 0.11345012290831626, 'max_depth': 5, 'min_child_weight': 7, 'colsample_bytree': 0.882669474840369, 'subsample': 0.5020937431064125}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:44,331] Trial 26 finished with value: 11.824824006446025 and parameters: {'n_estimators': 499, 'learning_rate': 0.010887725520636942, 'max_depth': 6, 'min_child_weight': 9, 'colsample_bytree': 0.7847564888097004, 'subsample': 0.7940428502932101}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:44,713] Trial 27 finished with value: 11.813489283860475 and parameters: {'n_estimators': 905, 'learning_rate': 0.048093908687059414, 'max_depth': 4, 'min_child_weight': 8, 'colsample_bytree': 0.9484226768538004, 'subsample': 0.7120594959372631}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:45,052] Trial 28 finished with value: 12.035632782571643 and parameters: {'n_estimators': 906, 'learning_rate': 0.0541935820968293, 'max_depth': 3, 'min_child_weight': 5, 'colsample_bytree': 0.9486946668206347, 'subsample': 0.7045688097618421}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:45,573] Trial 29 finished with value: 12.048098903328293 and parameters: {'n_estimators': 717, 'learning_rate': 0.03500929467925585, 'max_depth': 3, 'min_child_weight': 8, 'colsample_bytree': 0.8582177616449016, 'subsample': 0.648666250131343}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:46,092] Trial 30 finished with value: 12.077667218349683 and parameters: {'n_estimators': 801, 'learning_rate': 0.0619518341354704, 'max_depth': 6, 'min_child_weight': 7, 'colsample_bytree': 0.9506575662063187, 'subsample': 0.7133989893887687}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:46,343] Trial 31 finished with value: 11.854471193295689 and parameters: {'n_estimators': 900, 'learning_rate': 0.10760343585307985, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.9225832200825728, 'subsample': 0.7845403108333658}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:46,963] Trial 32 finished with value: 11.885804715286593 and parameters: {'n_estimators': 670, 'learning_rate': 0.030608104140506718, 'max_depth': 4, 'min_child_weight': 8, 'colsample_bytree': 0.87242100230106, 'subsample': 0.8523411333930887}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:47,388] Trial 33 finished with value: 11.875176082803188 and parameters: {'n_estimators': 753, 'learning_rate': 0.06110784948586302, 'max_depth': 5, 'min_child_weight': 9, 'colsample_bytree': 0.8074397231223851, 'subsample': 0.6392407517653605}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:47,594] Trial 34 finished with value: 12.110041105960631 and parameters: {'n_estimators': 844, 'learning_rate': 0.16423761872725728, 'max_depth': 3, 'min_child_weight': 6, 'colsample_bytree': 0.7263062477076003, 'subsample': 0.9979495241375462}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:48,149] Trial 35 finished with value: 11.839242116961556 and parameters: {'n_estimators': 927, 'learning_rate': 0.03847319040138727, 'max_depth': 5, 'min_child_weight': 10, 'colsample_bytree': 0.960128880657539, 'subsample': 0.9075499212269204}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:49,027] Trial 36 finished with value: 11.80226421818301 and parameters: {'n_estimators': 857, 'learning_rate': 0.01311015117757175, 'max_depth': 4, 'min_child_weight': 7, 'colsample_bytree': 0.9047011480100929, 'subsample': 0.7148636579123061}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:50,372] Trial 37 finished with value: 11.985794055404401 and parameters: {'n_estimators': 834, 'learning_rate': 0.01242110795809451, 'max_depth': 5, 'min_child_weight': 7, 'colsample_bytree': 0.42806041089088476, 'subsample': 0.7187478953805118}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:52,317] Trial 38 finished with value: 11.906477445859046 and parameters: {'n_estimators': 862, 'learning_rate': 0.012493117422055501, 'max_depth': 7, 'min_child_weight': 5, 'colsample_bytree': 0.6744478664592898, 'subsample': 0.6574710224574483}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:52,876] Trial 39 finished with value: 11.833780747419045 and parameters: {'n_estimators': 951, 'learning_rate': 0.029095095031360665, 'max_depth': 4, 'min_child_weight': 1, 'colsample_bytree': 0.7540492361779239, 'subsample': 0.6047515591721618}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:53,116] Trial 40 finished with value: 12.30703663892099 and parameters: {'n_estimators': 797, 'learning_rate': 0.190073460661125, 'max_depth': 6, 'min_child_weight': 8, 'colsample_bytree': 0.9634492649116221, 'subsample': 0.7608329244138442}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:53,606] Trial 41 finished with value: 11.935610655009947 and parameters: {'n_estimators': 377, 'learning_rate': 0.0471775509176484, 'max_depth': 4, 'min_child_weight': 7, 'colsample_bytree': 0.9060419260757044, 'subsample': 0.6978470856770617}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:53,888] Trial 42 finished with value: 12.112425965663768 and parameters: {'n_estimators': 606, 'learning_rate': 0.08763041626668981, 'max_depth': 3, 'min_child_weight': 8, 'colsample_bytree': 0.8458736227818511, 'subsample': 0.7337193189000832}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:54,170] Trial 43 finished with value: 11.817872095240114 and parameters: {'n_estimators': 120, 'learning_rate': 0.0286210064083914, 'max_depth': 5, 'min_child_weight': 9, 'colsample_bytree': 0.8107099483498796, 'subsample': 0.9359285881014572}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:54,435] Trial 44 finished with value: 11.991040471310468 and parameters: {'n_estimators': 675, 'learning_rate': 0.1208655919235046, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.9335721101032515, 'subsample': 0.7753249581520082}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:55,029] Trial 45 finished with value: 11.927495804046343 and parameters: {'n_estimators': 532, 'learning_rate': 0.044759120829938645, 'max_depth': 3, 'min_child_weight': 7, 'colsample_bytree': 0.8833106717026737, 'subsample': 0.8292628779471278}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:55,325] Trial 46 finished with value: 12.578825078641367 and parameters: {'n_estimators': 740, 'learning_rate': 0.1484987576657792, 'max_depth': 8, 'min_child_weight': 8, 'colsample_bytree': 0.97117190920446, 'subsample': 0.6203322495970411}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:55,693] Trial 47 finished with value: 12.00440127395378 and parameters: {'n_estimators': 885, 'learning_rate': 0.0695287944161192, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.8986671987786733, 'subsample': 0.8836633225032972}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:56,437] Trial 48 finished with value: 11.848227154697089 and parameters: {'n_estimators': 950, 'learning_rate': 0.022389052640981656, 'max_depth': 5, 'min_child_weight': 6, 'colsample_bytree': 0.5629120685075764, 'subsample': 0.7336851466722094}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:56,916] Trial 49 finished with value: 12.117520393781238 and parameters: {'n_estimators': 808, 'learning_rate': 0.057601418098884034, 'max_depth': 3, 'min_child_weight': 8, 'colsample_bytree': 0.9840503243518992, 'subsample': 0.5771489999963626}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:57,365] Trial 50 finished with value: 12.872175313044904 and parameters: {'n_estimators': 389, 'learning_rate': 0.27766734603289706, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.4513096706433678, 'subsample': 0.9616905220321558}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:57,724] Trial 51 finished with value: 11.80534685892107 and parameters: {'n_estimators': 140, 'learning_rate': 0.026890126091244502, 'max_depth': 5, 'min_child_weight': 9, 'colsample_bytree': 0.8140459899204712, 'subsample': 0.9309238921437193}. Best is trial 13 with value: 11.794431639079287.
# [I 2024-11-07 15:33:58,179] Trial 52 finished with value: 11.781970801555703 and parameters: {'n_estimators': 218, 'learning_rate': 0.03659281307357843, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.8561193746814381, 'subsample': 0.9584902630272228}. Best is trial 52 with value: 11.781970801555703.
# [I 2024-11-07 15:33:58,637] Trial 53 finished with value: 11.935728783286102 and parameters: {'n_estimators': 203, 'learning_rate': 0.0416726322828457, 'max_depth': 5, 'min_child_weight': 8, 'colsample_bytree': 0.8632750869200192, 'subsample': 0.8760696941951421}. Best is trial 52 with value: 11.781970801555703.
# [I 2024-11-07 15:33:59,178] Trial 54 finished with value: 11.715039458344767 and parameters: {'n_estimators': 222, 'learning_rate': 0.026610995199936475, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.8132041948598722, 'subsample': 0.9702138151204043}. Best is trial 54 with value: 11.715039458344767.
# [I 2024-11-07 15:33:59,559] Trial 55 finished with value: 11.67811517579572 and parameters: {'n_estimators': 210, 'learning_rate': 0.025243158198516566, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7967084026792156, 'subsample': 0.9308314299805929}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:33:59,891] Trial 56 finished with value: 12.612964657475159 and parameters: {'n_estimators': 202, 'learning_rate': 0.22470246291618715, 'max_depth': 3, 'min_child_weight': 10, 'colsample_bytree': 0.7573089432263486, 'subsample': 0.9213481923875197}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:00,229] Trial 57 finished with value: 11.742032938299133 and parameters: {'n_estimators': 187, 'learning_rate': 0.023013768747548603, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7987698325080583, 'subsample': 0.9644796765461356}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:01,235] Trial 58 finished with value: 12.105787856915125 and parameters: {'n_estimators': 249, 'learning_rate': 0.0366189193247797, 'max_depth': 10, 'min_child_weight': 10, 'colsample_bytree': 0.6951665156254179, 'subsample': 0.9701828444524274}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:01,958] Trial 59 finished with value: 12.269383671587654 and parameters: {'n_estimators': 185, 'learning_rate': 0.07564271503596973, 'max_depth': 9, 'min_child_weight': 10, 'colsample_bytree': 0.7741586899363866, 'subsample': 0.9554649912445994}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:02,721] Trial 60 finished with value: 11.724636397734121 and parameters: {'n_estimators': 317, 'learning_rate': 0.018881236417696186, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7324604473308637, 'subsample': 0.976918432860842}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:03,435] Trial 61 finished with value: 11.782710135182514 and parameters: {'n_estimators': 308, 'learning_rate': 0.025066057281769548, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7342859218064524, 'subsample': 0.9810449157447436}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:03,932] Trial 62 finished with value: 11.842193779834794 and parameters: {'n_estimators': 299, 'learning_rate': 0.022230270804893273, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.6250062343118998, 'subsample': 0.9792609196563696}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:04,351] Trial 63 finished with value: 12.025412383989302 and parameters: {'n_estimators': 275, 'learning_rate': 0.024439027990685237, 'max_depth': 3, 'min_child_weight': 10, 'colsample_bytree': 0.7311381471188879, 'subsample': 0.9036429762040614}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:04,885] Trial 64 finished with value: 11.896882481024342 and parameters: {'n_estimators': 362, 'learning_rate': 0.03745147579999689, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7006495642381886, 'subsample': 0.9804375617297961}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:05,285] Trial 65 finished with value: 11.680585730262294 and parameters: {'n_estimators': 232, 'learning_rate': 0.05350252353495471, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7940512664034151, 'subsample': 0.9537361194369904}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:05,659] Trial 66 finished with value: 11.980910559384231 and parameters: {'n_estimators': 235, 'learning_rate': 0.052143359830244845, 'max_depth': 3, 'min_child_weight': 10, 'colsample_bytree': 0.7854201279953158, 'subsample': 0.9489819902176028}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:06,058] Trial 67 finished with value: 11.954506500922191 and parameters: {'n_estimators': 335, 'learning_rate': 0.06481160482509171, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7464373731254144, 'subsample': 0.9811992725620247}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:06,417] Trial 68 finished with value: 11.903181333991405 and parameters: {'n_estimators': 177, 'learning_rate': 0.05517057200983453, 'max_depth': 5, 'min_child_weight': 9, 'colsample_bytree': 0.7959209042892489, 'subsample': 0.9447123787529139}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:06,651] Trial 69 finished with value: 12.423021532944725 and parameters: {'n_estimators': 103, 'learning_rate': 0.020273697718716274, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.8373024605753253, 'subsample': 0.9196841919968752}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:07,239] Trial 70 finished with value: 12.075642676800042 and parameters: {'n_estimators': 430, 'learning_rate': 0.043833735573096166, 'max_depth': 3, 'min_child_weight': 10, 'colsample_bytree': 0.6404041578576514, 'subsample': 0.8921794543422026}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:07,903] Trial 71 finished with value: 11.861064929497699 and parameters: {'n_estimators': 241, 'learning_rate': 0.031142313847611427, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.7075555486402167, 'subsample': 0.9693699819521422}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:08,737] Trial 72 finished with value: 11.721977239339006 and parameters: {'n_estimators': 330, 'learning_rate': 0.019314138067984602, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.8247201333222022, 'subsample': 0.9845859070443441}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:09,495] Trial 73 finished with value: 11.967375506533145 and parameters: {'n_estimators': 336, 'learning_rate': 0.03439665165410285, 'max_depth': 5, 'min_child_weight': 10, 'colsample_bytree': 0.8188554990390916, 'subsample': 0.9895276617974709}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:10,161] Trial 74 finished with value: 11.793748434696047 and parameters: {'n_estimators': 257, 'learning_rate': 0.01840000396789447, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7414453995242476, 'subsample': 0.9331434939636101}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:10,778] Trial 75 finished with value: 11.727883360342304 and parameters: {'n_estimators': 220, 'learning_rate': 0.021540562780994282, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7957379450256153, 'subsample': 0.9543765098058488}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:11,752] Trial 76 finished with value: 12.02832005643835 and parameters: {'n_estimators': 218, 'learning_rate': 0.04379597378500197, 'max_depth': 7, 'min_child_weight': 10, 'colsample_bytree': 0.8487315702283931, 'subsample': 0.955698388642091}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:12,417] Trial 77 finished with value: 12.128370025388907 and parameters: {'n_estimators': 178, 'learning_rate': 0.015791139726550774, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.7686657544896158, 'subsample': 0.9438217276803924}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:13,092] Trial 78 finished with value: 11.873253102656605 and parameters: {'n_estimators': 156, 'learning_rate': 0.03373255966277041, 'max_depth': 5, 'min_child_weight': 10, 'colsample_bytree': 0.7994757103163233, 'subsample': 0.9976928823150372}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:13,589] Trial 79 finished with value: 12.286860397777087 and parameters: {'n_estimators': 274, 'learning_rate': 0.2529624820721116, 'max_depth': 3, 'min_child_weight': 3, 'colsample_bytree': 0.3005512412835397, 'subsample': 0.8689049611855973}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:14,225] Trial 80 finished with value: 11.69804672890455 and parameters: {'n_estimators': 152, 'learning_rate': 0.04990684866141108, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.8344902947610142, 'subsample': 0.9178777177255366}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:14,781] Trial 81 finished with value: 11.862751659788188 and parameters: {'n_estimators': 154, 'learning_rate': 0.05354597861930492, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.8276456722776052, 'subsample': 0.919096141979389}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:15,404] Trial 82 finished with value: 11.911970140082682 and parameters: {'n_estimators': 227, 'learning_rate': 0.07864120306330734, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.795108450160421, 'subsample': 0.8989142902788888}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:15,954] Trial 83 finished with value: 12.15112106712795 and parameters: {'n_estimators': 125, 'learning_rate': 0.019583345410644097, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.8823195500378895, 'subsample': 0.9593329303207863}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:16,682] Trial 84 finished with value: 12.205413453247477 and parameters: {'n_estimators': 206, 'learning_rate': 0.01078933073846803, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.8571904593213, 'subsample': 0.9694950696203731}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:17,529] Trial 85 finished with value: 11.84889031107518 and parameters: {'n_estimators': 323, 'learning_rate': 0.039784184814995, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.8292710107245953, 'subsample': 0.9289103003510929}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:18,235] Trial 86 finished with value: 11.947693962906362 and parameters: {'n_estimators': 280, 'learning_rate': 0.06939304780738638, 'max_depth': 3, 'min_child_weight': 10, 'colsample_bytree': 0.7895867757454378, 'subsample': 0.9447236023067345}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:18,870] Trial 87 finished with value: 11.862539276182185 and parameters: {'n_estimators': 165, 'learning_rate': 0.028049428195380893, 'max_depth': 5, 'min_child_weight': 10, 'colsample_bytree': 0.7595895824264677, 'subsample': 0.9162792437924404}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:19,596] Trial 88 finished with value: 11.972734845442416 and parameters: {'n_estimators': 259, 'learning_rate': 0.04957684899211105, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.8422467763515742, 'subsample': 0.9857539887517234}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:20,289] Trial 89 finished with value: 11.974211008805268 and parameters: {'n_estimators': 191, 'learning_rate': 0.06114008236704854, 'max_depth': 5, 'min_child_weight': 4, 'colsample_bytree': 0.8097287746434727, 'subsample': 0.9713722207004536}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:20,821] Trial 90 finished with value: 12.012368377850507 and parameters: {'n_estimators': 133, 'learning_rate': 0.0858748745350797, 'max_depth': 3, 'min_child_weight': 10, 'colsample_bytree': 0.8708612946536436, 'subsample': 0.9512346342167948}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:21,755] Trial 91 finished with value: 11.754576959116882 and parameters: {'n_estimators': 418, 'learning_rate': 0.0247923845031007, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7801314581128469, 'subsample': 0.9878713182922768}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:22,598] Trial 92 finished with value: 11.814520384407736 and parameters: {'n_estimators': 431, 'learning_rate': 0.03345269263811779, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7743832061571868, 'subsample': 0.9996441998864418}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:23,178] Trial 93 finished with value: 11.73101004088421 and parameters: {'n_estimators': 219, 'learning_rate': 0.019326352763435722, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.8233111003031236, 'subsample': 0.9357784415610217}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:23,798] Trial 94 finished with value: 11.744158034837744 and parameters: {'n_estimators': 364, 'learning_rate': 0.02194665397773196, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.8260791609492959, 'subsample': 0.9377383034803284}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:24,035] Trial 95 finished with value: 12.707430717805638 and parameters: {'n_estimators': 108, 'learning_rate': 0.01625158383967596, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.8208155633734076, 'subsample': 0.9371656683788483}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:24,666] Trial 96 finished with value: 11.776167820413322 and parameters: {'n_estimators': 315, 'learning_rate': 0.02051280062777729, 'max_depth': 4, 'min_child_weight': 9, 'colsample_bytree': 0.8043110578169561, 'subsample': 0.9275369198914601}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:25,359] Trial 97 finished with value: 11.900285502774407 and parameters: {'n_estimators': 353, 'learning_rate': 0.029353930064332737, 'max_depth': 5, 'min_child_weight': 9, 'colsample_bytree': 0.8330979679248588, 'subsample': 0.9093946940311531}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:25,840] Trial 98 finished with value: 12.72810484790045 and parameters: {'n_estimators': 231, 'learning_rate': 0.010616705507163308, 'max_depth': 3, 'min_child_weight': 10, 'colsample_bytree': 0.7158029629628203, 'subsample': 0.8885679952361016}. Best is trial 55 with value: 11.67811517579572.
# [I 2024-11-07 15:34:26,592] Trial 99 finished with value: 11.96509483922376 and parameters: {'n_estimators': 290, 'learning_rate': 0.04664174994689358, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.6794803618371824, 'subsample': 0.9669968744331919}. Best is trial 55 with value: 11.67811517579572.

# %%
print("Best parameters:", study.best_params)
print("Best MSE:", study.best_value)
# Out:
# Best parameters: {'n_estimators': 210, 'learning_rate': 0.025243158198516566, 'max_depth': 4, 'min_child_weight': 10, 'colsample_bytree': 0.7967084026792156, 'subsample': 0.9308314299805929}
# Best MSE: 11.67811517579572

# %%
xgb_reg = XGBRegressor(n_estimators= 210, 
                       learning_rate= 0.025243158198516566, 
                       max_depth= 4, 
                       min_child_weight= 10, 
                       colsample_bytree= 0.7967084026792156, 
                       subsample= 0.9308314299805929, 
                       tree_method='hist',
                       device='cuda:0',
                       seed=0,
                       early_stopping_rounds=50)

xgb_reg.fit(
    x_train, y_train, 
    eval_set=[(x_train, y_train), (x_valid, y_valid)], 
    verbose=False
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7967084026792156, device='cuda:0',
#              early_stopping_rounds=50, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.025243158198516566, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=10, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=210, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
pred = xgb_reg.predict(x_valid)
pred = pd.Series(pred)
pred.index = np.arange(y_valid.index[0], y_valid.index[-1]+1)

plot_series(y_train, y_valid, pd.Series(pred), markers=[',' , ',', ','])

print('SMAPE : {}'.format(SMAPE(y_valid, pred)))
# Out:
# SMAPE : 11.67811517579572

# %%
plt.figure(figsize=(20, 5))
pred.plot(label='predict_price')
y_valid.plot()
plt.legend()
plt.show()

# %%
# 피쳐 중요도 시각화
xgb.plot_importance(xgb_reg, importance_type='weight')
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# # SUBMIT DATA

# %%
def submit_df(date): #2024-11-05 <- str # 제출하는 날짜 입력
    year, month, day = map(int, date.split('-'))
    date_object = datetime(year, month, day)

    
    API_KEY = """eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJlcXpORXlBR1ZiNDdadUNpN2RLZ1hqIiwiaWF0IjoxNzMwMDcyODI2LCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.zsJAvYixxcUwz4ad-y2cWwi6oWdc1hmegSTFSbeMuzk"""
    
    columns = [
    'previous_day_price', 'previous_2day_price', 'previous_3day_price',
    'uv_idx', 'month_cos', 'month_sin','day_of_week_cos',
    'day_of_week_sin', 'rel_hum', 'hour_cos', 'wind_spd', 'cld_cvr',
    'hour_sin', 'wind_gust_spd', 'dew_point', 'real_feel_temp', 'ceiling',
    'wind_dir', 'wet_bulb_temp', 'temp', 'precip_prob', 'vis', 'rain_prob',
    'rain', 'total_liq'
    ]

    none_dataframe = pd.DataFrame(columns=columns)
    none_dataframe = none_dataframe.reindex(range(24))

    
    none_dataframe['hour_cos'] = [np.cos(2 * np.pi * hour / 24) for hour in range(1, 25)]
    none_dataframe['hour_sin'] = [np.sin(2 * np.pi * hour / 24) for hour in range(1, 25)]

    none_dataframe['month_sin'] = np.sin(2 * np.pi * int(date.split('-')[1]) / 12)
    none_dataframe['month_cos'] = np.cos(2 * np.pi * int(date.split('-')[1]) / 12)

    none_dataframe['day_of_week_sin'] = np.sin(2 * np.pi * int(date.split('-')[2]) / 7)
    none_dataframe['day_of_week_cos'] = np.cos(2 * np.pi * int(date.split('-')[2]) / 7)

    forecast_date = date
    weather_forecast = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/weather-forecast/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()

    weather_forecast_df = pd.DataFrame(weather_forecast['weather_forecast_1'])
    weather_forecast_df = weather_forecast_df.drop(['location'], axis=1)

    weather_forecast_df_grouped = weather_forecast_df.groupby('ts').mean().reset_index()
    weather_forecast_df_grouped = weather_forecast_df_grouped.drop(index=0).reset_index(drop=True)


    weather_col = [
        'uv_idx', 'rel_hum',  'wind_spd', 'cld_cvr',
        'wind_gust_spd', 'dew_point', 'real_feel_temp', 'ceiling',
        'wind_dir', 'wet_bulb_temp', 'temp', 'precip_prob', 
        'vis', 'rain_prob', 'rain', 'total_liq'
        ]    

    for col in weather_col:
        none_dataframe[col] = weather_forecast_df_grouped[col]

    smp_preday_1 = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                                'Authorization': f'Bearer {API_KEY}'
                            }).json()
    
    none_dataframe['previous_day_price'] = pd.DataFrame(smp_preday_1)['smp_da']
    
    
    previous_day = date_object - timedelta(days=1)
    date = f"{previous_day.year}-{previous_day.month:02d}-{previous_day.day:02d}"

    
    smp_preday_2 = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                                'Authorization': f'Bearer {API_KEY}'
                            }).json()

    none_dataframe['previous_2day_price'] = pd.DataFrame(smp_preday_2)['smp_da']


    previous_day = date_object - timedelta(days=2)
    date = f"{previous_day.year}-{previous_day.month:02d}-{previous_day.day:02d}"

    smp_preday_3 = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                                'Authorization': f'Bearer {API_KEY}'
                            }).json()

    none_dataframe['previous_3day_price'] = pd.DataFrame(smp_preday_3)['smp_da']

     
    return none_dataframe

# %%
submit_data = submit_df('2024-11-14')

# %%
submit_data[columns_to_scale] = scaler1.transform(submit_data[columns_to_scale])
#submit_data[columns_to_scale] = scaler2.transform(submit_data[columns_to_scale])

# %%
pred = xgb_reg.predict(submit_data)
pred_float = list(map(float, pred))

# %%
result = {
    'submit_result' : pred_float
}
success = requests.post('https://research-api.solarkim.com/submissions/cmpt-2024',
                    data=json.dumps(result),
                    headers={
                        'Authorization': f'Bearer {API_KEY}'
                    }).json()
print(success)
# Out:
# True

# %%
pred_float
# Out:
# [128.5513916015625,
#  122.45344543457031,
#  121.56964111328125,
#  121.81269073486328,
#  122.21732330322266,
#  127.33370208740234,
#  133.87530517578125,
#  138.60153198242188,
#  150.34698486328125,
#  146.88131713867188,
#  143.95018005371094,
#  141.00173950195312,
#  137.41053771972656,
#  132.96173095703125,
#  135.2912139892578,
#  135.15455627441406,
#  133.0587615966797,
#  131.60739135742188,
#  127.23209381103516,
#  120.55962371826172,
#  122.1727294921875,
#  125.06366729736328,
#  124.34739685058594,
#  124.48560333251953]

# %% [markdown]
# # CHECK

# %%
submit_data = submit_df('2024-11-06') # 제출일
submit_data[columns_to_scale] = scaler1.transform(submit_data[columns_to_scale])
#submit_data[columns_to_scale] = scaler2.transform(submit_data[columns_to_scale])
pred = xgb_reg.predict(submit_data)
pred_float = list(map(float, pred))

# %%
date = '2024-11-07'
smp_da = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()
real = []

for i in smp_da:
    real.append(i['smp_da'])

# %%
plt.plot(real, label='real')
plt.plot(pred, label='pred')
#plt.ylim(-100, 200)

plt.legend()
plt.title(f"score : {calculate_measure(real, pred)}")
plt.show()
